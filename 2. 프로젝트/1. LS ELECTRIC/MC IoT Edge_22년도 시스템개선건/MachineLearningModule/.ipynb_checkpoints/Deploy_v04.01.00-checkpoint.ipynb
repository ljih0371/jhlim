# %% [markdown]
# ## 추가해야하는 내용

# %%
# Check core SDK version number
import azureml.core
import os

print("SDK version:", azureml.core.VERSION)
# Out:
# SDK version: 1.24.0

# %% [markdown]
# # 1. Azure ML Service 작업 영업에 연결

# %% [markdown]
# #### Notebook이 실행되는 경로 내 Azure ML Service Workspace 접속 정보를 가진 config 파일이 있어야한다.

# %% [markdown]
#  - 테스트 배포 시에는 'data/config_dev.json' 사용
#  - 실제 배포 시에는 'data/config.json' 사용

# %%
from azureml.core import Workspace

ws = Workspace.from_config('config/config_dev_test.json')
print('기계학습이름:'+ws.name, '리소스그룹이름:'+ws.resource_group, '리전이름:'+ws.location, '구독ID:'+ws.subscription_id, sep = '\n')
# Out:
# 기계학습이름:mltest21
# 리소스그룹이름:bigdatateam
# 리전이름:koreacentral
# 구독ID:245d9749-ca17-42f2-ae5e-2aefd9de113b

# %%
from azureml.core.authentication import InteractiveLoginAuthentication

interactive_auth = InteractiveLoginAuthentication(tenant_id="c8b9cf2c-f80b-4c36-912f-74979c640070")

ws = Workspace(subscription_id="1f154107-bef0-481f-a741-68e7ba34affe",
               resource_group="lsmc-prd-rg",
               workspace_name="lsmc-dev-mlws",
               auth=interactive_auth)
# Out:
# Performing interactive authentication. Please follow the instructions on the terminal.
# Note, we have launched a browser for you to login. For old experience with device code, use "az login --use-device-code"
# You have logged in. Now let us find all the subscriptions to which you have access...
# Interactive authentication successfully completed.

# %%
from azureml.core.authentication import InteractiveLoginAuthentication

interactive_auth = InteractiveLoginAuthentication(tenant_id="54af7187-79bd-47bd-aea7-8fb194e64cdd")

ws = Workspace(subscription_id="245d9749-ca17-42f2-ae5e-2aefd9de113b",
               resource_group="bigdatateam",
               workspace_name="mltest21",
               auth=interactive_auth)

# %% [markdown]
# # 2. 모델 등록

# %% [markdown]
# #### 등록할 모델의 버전을 명시해준다.

# %%
model_version = "03_051_01"
file_name = '{}.pickle'.format(model_version)
print(file_name)
# Out:
# 03_051_01.pickle

# %% [markdown]
# ## Description 수정해아함!!!

# %% [markdown]
# #### 모델을 등록해준다. description에 현재 모델에 대한 간단한 설명을 추가할 수 있다.

# %% [markdown]
#  - 실행하면, [Azure Portal > 기계 학습 > 기계학습이름(위에서 확인) > 모델] 에서 확인 가능함

# %%
from azureml.core.model import Model

#library_version = "DL"+sklearn.__version__.replace(".","x")
model = Model.register(model_path = "data/pkl/{}".format(file_name),
                       model_name = model_version,
                       tags = {'area': "IoT Edge", 'type': "azureml-automl"},
                       description = "ML=03_051_01, Sys=04.01.00",
                       workspace = ws)
# Out:
# Registering model 03_051_01

# %% [markdown]
# # 3. 이미지 등록

# %% [markdown]
# #### 등록 된 모델 이름을 사용 하 여 모델 파일에 대 한 경로를 반환

# %%
from azureml.core.model import Model
model = Model.get_model_path(model_version, _workspace=ws)
model
# Out:
# 'azureml-models\\03_051_01\\27\\03_051_01.pickle'

# %% [markdown]
# #### 사용되는 package 선언. Edge 환경에서 해당 package를 사용되기 때문에 channel 과 필요한 package명을 선언 해주어야 한다.

# %%
pip_packages = ["azureml-defaults",
                "azureml==0.2.7",
                "azureml-core==1.24.0",
                "azureml-sdk==1.24.0",
                "azureml-automl-core==1.24.0",
                "azureml-automl-runtime==1.24.0",
                "azure-storage-blob==12.6.0",
                "numpy==1.18.5",
                "pandas==0.25.3",
                "sqlalchemy==1.3.21",
                "h5py==2.10.0",
                "tqdm==4.54.0",
                "obspy==1.2.2",
                "mysql-connector-python==8.0.18",
                "joblib==0.14.1",
                "packaging==20.7",
                "xgboost==0.90",
                "noisereduce==1.1.0"]

lib_config_load = ['pyyaml']
lib_clfs = ["gxx_linux-64",
            "gcc_linux-64",
            "librosa==0.8.0"]
#lib_clfs = ['tensorflow==1.1']
conda_packages = lib_clfs + lib_config_load

print('pip packages:', pip_packages)
print('conda packasges:', conda_packages)
# Out:
# pip packages: ['azureml-defaults', 'azureml==0.2.7', 'azureml-core==1.24.0', 'azureml-sdk==1.24.0', 'azureml-automl-core==1.24.0', 'azureml-automl-runtime==1.24.0', 'azure-storage-blob==12.6.0', 'numpy==1.18.5', 'pandas==0.25.3', 'sqlalchemy==1.3.21', 'h5py==2.10.0', 'tqdm==4.54.0', 'obspy==1.2.2', 'mysql-connector-python==8.0.18', 'joblib==0.14.1', 'packaging==20.7', 'xgboost==0.90', 'noisereduce==1.1.0']
# conda packasges: ['gxx_linux-64', 'gcc_linux-64', 'librosa==0.8.0', 'pyyaml']

# %%
from azureml.core.conda_dependencies import CondaDependencies 
from azureml.core import Environment

conda_deps  = CondaDependencies.create(conda_packages=conda_packages, pip_packages=pip_packages)
conda_deps.add_channel('conda-forge')
conda_deps.add_channel('defaults')

myenv = Environment(name='myenv')
myenv.python.conda_dependencies = conda_deps

# myenv.docker.base_image = 'mcr.microsoft.com/azureml/intelmpi2018.3-ubuntu16.04'


#myenv.docker.base_image = 'mcr.microsoft.com/azureml/base:intelmpi2018.3-ubuntu16.04'
# myenv.docker.base_image = 'mcr.microsoft.com/azureml/base:openmpi3.1.2-ubuntu18.04'


# with open("data/myenv.yml","w") as f:
#     f.write(myenv.serialize_to_string())

# %% [markdown]
# # 4. score_iot.py 파일(전처리 및 ML 판정 수행 로직 실행 스크립트) 생성

# %% [markdown]
#  ### 아래 cell 이 실행되면 score_iot.py에 실행 스크립트가 생성됨

# %% [markdown]
# ### score_iot_test.ipynb에 해당 스크립트의 내용을 복사하여, 실행 시 에러가 발생하지 않는지 꼭 확인!

# %%
import _locale
_locale._getdefaultlocale = (lambda *args: ['en_US', 'utf8'])

# %%
# %%writefile ../src/score_iot.py

# For Edge
import json
import yaml
import time
import os
import re
import pickle
import shutil
from datetime import datetime
from datetime import timedelta
from time import sleep
from azureml.core.model import Model

# For Clf
import h5py
import pandas as pd
from classify import Classifier
from preprocess_signal_data import Run_
from pkgs.pipelines import FeatureDeployed as Featurizing
from pkgs.utils import read_json

def read_data(input_path, attempt):
    print("Attempt: " + str(attempt + 1) + "  Time: " + str(datetime.now()))
    with h5py.File(input_path, "r") as f:
        tmp = f["Raw"][:]
    input_raw = pd.DataFrame(tmp, columns=[0, 1, 2])
    print("\n", "hdf loaded")
    
    return input_raw
# --------------------------------------------------------------------

def init_preprocessor(feature_params, Featurizing, test_no, input_type="ReadData"):
    # set preprocess class
    preproc = Run_(
        feature_params=feature_params, Featurizing=Featurizing, test_no=test_no
    )
    if input_type == "ReadData":
        preproc.pl.steps = [
            (step_name, step)
            for step_name, step in preproc.pl.steps
            if step.name != "ReadData"
        ]

    return preproc


def score(
    preproc,
    input_values,
    feature_names,
    column_names,
    cut_off,
    rule_model_params,
    mode,
    input_name="ReadData",
    parallel=1,
    verbose=0,
):
    # Preprocess
    df = preproc.pl.run(
        input_name=input_name,
        input_values=[input_values],
        feature_names=feature_names,
        parallel=parallel,
        verbose=verbose,
    )
    df = pd.DataFrame(df[0])
    df["TEST_NO"] = [0,1,2]
    df_features = df[column_names]

    # Predict
    df["PROB"] = loaded_model.predict_proba(df_features)[:,1]
    
    # Classify
    df["ML_R"] = df.PROB >= cut_off
    df["ML_R"] = df.ML_R.astype(int)
    
    df_classified = Classifier.classify_all(
        df=df[df.TEST_NO.isin(preproc.featurizer.params["test_no"])],
        rule_cutoffs=rule_model_params,
        mode=mode,
    )
    return df_classified, df


def init():
    global preproc, loaded_model, model_version, column_names, line, cut_off, rule_model_params, ml_model_params, model_path, error_dir
    # 수정필요  --------------------------------------------------------
    model_version = "03_051_01"  # model_name 입력
    file_name = "{}.pickle".format(model_version)
    edge_config = "/home/data/edge_config.yml"
    feature_params = read_json("src/config/feature051_parameters.json")
    column_names = read_json("src/config/model_03_051_01_features.json")["feature_names"]
    # ----------------------------------------------------------------

    # load line info
    with open(edge_config, "r") as stream:
        try:
            edge_config = yaml.load(stream, Loader=yaml.BaseLoader)
            line = edge_config["config"]["line"]["name"]
            cut_off = float(edge_config["config"]["param"]["cutoff"])
            rule_model_params = edge_config["config"]["param"]["rule_model"]
            ml_model_params = edge_config["config"]["param"]["ml_model"]

        except yaml.YAMLError as exc:
            print("line config error: ", exc)

    # set preprocess class
    for param_, dic_ in ml_model_params.items():
        for key_, value_ in dic_.items():
            feature_params[param_][key_] = float(value_)
    preproc = init_preprocessor(
        feature_params=feature_params, Featurizing=Featurizing, test_no=[0, 1, 2]
    )

    # load model
    model_path = Model.get_model_path(file_name)
    with open(model_path, "rb") as f:
        loaded_model = pickle.load(f)
    
    error_dir = "/home/data/error_file/"
    try:
        os.makedirs(error_dir, mode=777)
    except:
        pass


def run(input_json):
    print("\n", "mlmodule start")
    print("\n", datetime.now() + timedelta(hours=9), "\n")
    # for test#
    input_json = json.loads(input_json)
    print("\n", "json loaded", "\n")
    print(input_json, "\n")
    mltime = datetime.now() + timedelta(hours=9)
    chtime = input_json["chtime"]
    print("chtime : ", chtime)
    ct = datetime.strptime(
        chtime.replace("T", " ").split("+")[0][:-1], "%Y-%m-%d %H:%M:%S.%f"
    )
    diff = mltime - ct
    input_json["chtime"] = str(ct)
    input_json["mltime"] = str(mltime)
    input_json["etime_ch"] = diff.seconds + diff.microseconds / 1e6

    # file load
    init_time = time.time()
    # input_json = json.loads(input_json)
    input_path = input_json["path"]
    print("\n", input_path)

    for attempt in range(3):
        try:
            input_raw = read_data(input_path, attempt)

        except Exception as ex:
            if attempt == 2:
                ex_message = str(ex)

            sleep(0.02)
            continue

        break

    else:
        input_json["b"] = 2
        input_json["prob"] = 2
        input_json["error"] = ex_message
        input_json["etime"] = time.time() - init_time

        result_json = [json.dumps(input_json)]
        print("*" * 5, " ", "LOAD ERROR", " ", "*" * 5)
        print(result_json)
        try:
            shutil.copy(input_path, error_dir)
        except:
            pass

    # for test#
    # diff = (datetime.now()+ timedelta(hours=9))-mltime
    # input_json['etime_load'] = diff.seconds + diff.microseconds/1E6
    input_json["etime_load"] = time.time() - init_time

    ### json insert
    input_json["cutoff"] = cut_off
    input_json["FTUR_ENRG_TRHD"] = float(rule_model_params["FTUR_ENRG"])
    input_json["FTUR_WVFM_STDDEV_TRHD"] = float(rule_model_params["FTUR_WVFM_STDDEV"])
    input_json["FTUR_TRGER_TRHD"] = float(rule_model_params["FTUR_TRGER"])
    
    input_json["TRHD_NM_SET"] = "/".join([key for key in rule_model_params.keys()] + [f"{key_}-{param}" for key_, dict_ in ml_model_params.items() for param, value in dict_.items()])
    input_json["TRHD_VAL_SET"] = "/".join(
        [str(value) for value in rule_model_params.values()]+[str(value) for key_, dict_ in ml_model_params.items() for param, value in dict_.items()]
    )
    input_json["FTUR_NM_SET"] = "/".join(
        [
            "/".join([col + "_TEST_N1" for col in preproc.featurizer.params["feature_names"]]),
            "/".join([col + "_TEST_N2" for col in preproc.featurizer.params["feature_names"]]),
            "/".join([col + "_TEST_N3" for col in preproc.featurizer.params["feature_names"]]),
        ]
    )
    input_json["lid"] = line
    
    ##시스템 변수 반드시 수정 필요
    input_json["v"] = "04.01.00"
    ##############################

    try:
        filename = input_path.split("/")[-1]
        filename = filename.strip("Data\\").split("_")
        input_json["bc"] = "_".join(filename[0:2])
        input_json["dtfull"] = filename[2][:-3]

    except Exception as ex:  # 에러 종류
        input_json["bc"] = "ERROR"
        input_json["dtfull"] = str(datetime.now())
        input_json["r"] = 2
        input_json["prob"] = 2
        input_json["error"] = str(ex)
        input_json["etime"] = time.time() - init_time

        result_json = [json.dumps(input_json)]
        print("*" * 5, " ", "FILENAME ERROR", " ", "*" * 5)
        print(result_json)
        try:
            cmd = "cp " + input_json["path"] + " " + error_dir
            os.system(cmd)
        except:
            pass

    try:
        df, df_all = score(
            preproc=preproc,
            input_values=input_raw,
            feature_names=preproc.featurizer.params["feature_names"],
            column_names=column_names,
            cut_off=cut_off,
            rule_model_params=rule_model_params,
            mode="or",
            input_name="ReadData",
            parallel=1,
            verbose=0,
        )
        df_max = df_all.max()
        
        input_json["r"] = int(df.R.values[0])
        input_json["prob"] = float(df.PROB.values[0])
        input_json["error"] = str(df.TEST_NG_R.values[0])
        input_json["etime"] = time.time() - init_time
        input_json["FTUR_VAL_SET"] = "/".join(
            [str(value) for value in df_all[preproc.featurizer.params["feature_names"]].values.flatten()]
        )
        input_json["ML_R"] = int(df.ML_R.values[0])
        input_json["RULE_R"] = int(df.RULE_R.values[0])
        input_json["TEST_NG_R"] = int(df.TEST_NG_R.values[0])
        input_json["FTUR_ENRG"] = float(df_max.FTUR_ENRG)
        input_json["FTUR_WVFM_STDDEV"] = float(df_max.FTUR_WVFM_STDDEV)
        input_json["FTUR_TRGER"] = float(df_max.FTUR_TRGER)

        result_json = [json.dumps(input_json)]
        print(result_json)

    except Exception as ex:  # 에러 종류
        input_json["r"] = 2
        input_json["prob"] = 2
        input_json["error"] = str(ex)
        input_json["etime"] = time.time() - init_time
        input_json["FTUR_VAL_SET"] = ""
        input_json["ML_R"] = 2
        input_json["RULE_R"] = 2
        input_json["TEST_NG_R"] = 2
        input_json["FTUR_ENRG"] = -1
        input_json["FTUR_WVFM_STDDEV"] = -1
        input_json["FTUR_TRGER"] = -1
        

        result_json = [json.dumps(input_json)]
        print("*" * 5, " ", "ERROR", " ", "*" * 5)
        print(result_json)
        try:
            cmd = "cp " + input_json["path"] + " " + error_dir
            os.system(cmd)
        except:
            pass

    return result_json
# Out:
# Overwriting ../src/score_iot.py

# %%
import os
os.getcwd()
# Out:
# 'C:\\Users\\limjh\\MC_IoTEdge\\MC_QIS\\MachineLearningModule\\deployment'

# %% [markdown]
# # 5. Azure MLWS에 이미지 업로드

# %%
from azureml.core.model import InferenceConfig

inference_config = InferenceConfig(entry_script="score_iot.py", environment=myenv, source_directory="../src")
package_service = Model.package(workspace=ws,
                                models=[model],
                                image_name="mc-mlmodule",
                                image_label='30',
                                inference_config=inference_config)
# Out:
# ModelNotFound: Model with id azureml-models\03_051_01\27\03_051_01.pickle not found in provided workspace
# Registering model 03_051_01.pickle

# %%
package_service.wait_for_creation(show_output=True)
# Out:
# 2021/05/14 06:22:06 Downloading source code...
# 2021/05/14 06:22:07 Finished downloading source code
# 2021/05/14 06:22:08 Creating Docker network: acb_default_network, driver: 'bridge'
# 2021/05/14 06:22:09 Successfully set up Docker network: acb_default_network
# 2021/05/14 06:22:09 Setting up Docker configuration...
# 2021/05/14 06:22:10 Successfully set up Docker configuration
# 2021/05/14 06:22:10 Logging in to registry: 328b44081e0a40338b99edcaa606d991.azurecr.io
# 2021/05/14 06:22:11 Successfully logged into 328b44081e0a40338b99edcaa606d991.azurecr.io
# 2021/05/14 06:22:11 Executing step ID: acb_step_0. Timeout(sec): 5400, Working directory: '', Network: 'acb_default_network'
# 2021/05/14 06:22:11 Scanning for dependencies...
# 2021/05/14 06:22:11 Successfully scanned dependencies
# 2021/05/14 06:22:11 Launching container with name: acb_step_0
# Sending build context to Docker daemon  67.07kB
# Step 1/18 : FROM mcr.microsoft.com/azureml/intelmpi2018.3-ubuntu16.04:20210220.v1@sha256:45f047999ab2ced61a2fd0cf8d8421f796ca05b8423c1a0ac652791a321bff9a
# mcr.microsoft.com/azureml/intelmpi2018.3-ubuntu16.04:20210220.v1@sha256:45f047999ab2ced61a2fd0cf8d8421f796ca05b8423c1a0ac652791a321bff9a: Pulling from azureml/intelmpi2018.3-ubuntu16.04
# 4007a89234b4: Already exists
# 5dfa26c6b9c9: Already exists
# 0ba7bf18aa40: Already exists
# 4c6ec688ebe3: Already exists
# a2874ccdee09: Pulling fs layer
# 84e6fa394f53: Pulling fs layer
# cde35e537c55: Pulling fs layer
# 08224915e098: Pulling fs layer
# 3e72e2b08f2a: Pulling fs layer
# 503a95eb7b7f: Pulling fs layer
# cac267f3f656: Pulling fs layer
# 9c9189719fce: Pulling fs layer
# 3e72e2b08f2a: Waiting
# 503a95eb7b7f: Waiting
# cac267f3f656: Waiting
# 9c9189719fce: Waiting
# 08224915e098: Waiting
# 84e6fa394f53: Verifying Checksum
# 84e6fa394f53: Download complete
# cde35e537c55: Verifying Checksum
# cde35e537c55: Download complete
# a2874ccdee09: Verifying Checksum
# a2874ccdee09: Download complete
# 08224915e098: Verifying Checksum
# 08224915e098: Download complete
# 503a95eb7b7f: Verifying Checksum
# 503a95eb7b7f: Download complete
# cac267f3f656: Verifying Checksum
# cac267f3f656: Download complete
# 9c9189719fce: Verifying Checksum
# 9c9189719fce: Download complete
# 3e72e2b08f2a: Verifying Checksum
# 3e72e2b08f2a: Download complete
# a2874ccdee09: Pull complete
# 84e6fa394f53: Pull complete
# cde35e537c55: Pull complete
# 08224915e098: Pull complete
# 3e72e2b08f2a: Pull complete
# 503a95eb7b7f: Pull complete
# cac267f3f656: Pull complete
# 9c9189719fce: Pull complete
# Digest: sha256:45f047999ab2ced61a2fd0cf8d8421f796ca05b8423c1a0ac652791a321bff9a
# Status: Downloaded newer image for mcr.microsoft.com/azureml/intelmpi2018.3-ubuntu16.04:20210220.v1@sha256:45f047999ab2ced61a2fd0cf8d8421f796ca05b8423c1a0ac652791a321bff9a
#  ---> b79635653e9e
# Step 2/18 : USER root
#  ---> Running in 7289df62f21f
# Removing intermediate container 7289df62f21f
#  ---> 9c1aa3182405
# Step 3/18 : RUN mkdir -p $HOME/.cache
#  ---> Running in 2c55c22f80f6
# Removing intermediate container 2c55c22f80f6
#  ---> dda13db3a02f
# Step 4/18 : WORKDIR /
#  ---> Running in e9279052cc09
# Removing intermediate container e9279052cc09
#  ---> 037d3ab20659
# Step 5/18 : COPY azureml-environment-setup/99brokenproxy /etc/apt/apt.conf.d/
#  ---> c032ef4800e2
# Step 6/18 : RUN if dpkg --compare-versions `conda --version | grep -oE '[^ ]+$'` lt 4.4.11; then conda install conda==4.4.11; fi
#  ---> Running in f9ed240bfc5f
# Removing intermediate container f9ed240bfc5f
#  ---> 75e8d7b802c7
# Step 7/18 : COPY azureml-environment-setup/mutated_conda_dependencies.yml azureml-environment-setup/mutated_conda_dependencies.yml
#  ---> ea408f5ce097
# Step 8/18 : RUN ldconfig /usr/local/cuda/lib64/stubs && conda env create -p /azureml-envs/azureml_20c402732d5823ad8d6d590fb2eba6c0 -f azureml-environment-setup/mutated_conda_dependencies.yml && rm -rf "$HOME/.cache/pip" && conda clean -aqy && CONDA_ROOT_DIR=$(conda info --root) && rm -rf "$CONDA_ROOT_DIR/pkgs" && find "$CONDA_ROOT_DIR" -type d -name __pycache__ -exec rm -rf {} + && ldconfig
#  ---> Running in 53e9f20dbb0a
# Warning: you have pip-installed dependencies in your environment file, but you do not list pip itself as one of your conda dependencies.  Conda may not use the correct pip to install your packages, and they may end up in the wrong place.  Please add an explicit pip dependency.  I'm adding one for you, but still nagging you.
# Collecting package metadata (repodata.json): ...working...
# done
# Solving environment: ...working...
# done
#
# Downloading and Extracting Packages
# requests-2.24.0      | 54 KB     | ########## | 100%
# joblib-0.17.0        | 205 KB    | ########## | 100%
# tornado-6.0.4        | 650 KB    | ########## | 100%
# libedit-3.1          | 171 KB    | ########## | 100%
# libstdcxx-ng-9.1.0   | 4.0 MB    | ########## | 100%
# blas-1.0             | 6 KB      | ########## | 100%
# threadpoolctl-2.1.0  | 16 KB     | ########## | 100%
# pooch-1.3.0          | 40 KB     | ########## | 100%
# cycler-0.10.0        | 13 KB     | ########## | 100%
# packaging-20.4       | 35 KB     | ########## | 100%
# llvmlite-0.34.0      | 319 KB    | ########## | 100%
# mkl_random-1.1.0     | 369 KB    | ########## | 100%
# pysoundfile-0.10.3.p | 23 KB     | ########## | 100%
# gxx_impl_linux-64-7. | 19.1 MB   | ########## | 100%
# libopus-1.3.1        | 570 KB    | ########## | 100%
# libvorbis-1.3.7      | 549 KB    | ########## | 100%
# gcc_linux-64-7.3.0   | 25 KB     | ########## | 100%
# gmp-6.1.2            | 744 KB    | ########## | 100%
# libgfortran-ng-7.3.0 | 1.3 MB    | ########## | 100%
# urllib3-1.25.11      | 93 KB     | ########## | 100%
# pysocks-1.7.1        | 30 KB     | ########## | 100%
# ffmpeg-4.2.2         | 80.5 MB   | ########## | 100%
# binutils_impl_linux- | 8.6 MB    | ########## | 100%
# mkl_fft-1.2.0        | 164 KB    | ########## | 100%
# libvpx-1.7.0         | 2.4 MB    | ########## | 100%
# tbb-2020.3           | 1.4 MB    | ########## | 100%
# nettle-3.4.1         | 6.7 MB    | ########## | 100%
# zlib-1.2.11          | 120 KB    | ########## | 100%
# resampy-0.2.2        | 332 KB    | ########## | 100%
# six-1.15.0           | 13 KB     | ########## | 100%
# libogg-1.3.2         | 205 KB    | ########## | 100%
# chardet-3.0.4        | 197 KB    | ########## | 100%
# libsndfile-1.0.29    | 534 KB    | ########## | 100%
# yaml-0.2.5           | 87 KB     | ########## | 100%
# kiwisolver-1.2.0     | 91 KB     | ########## | 100%
# brotlipy-0.7.0       | 348 KB    | ########## | 100%
# pip-20.2.4           | 2.0 MB    | ########## | 100%
# matplotlib-base-3.2. | 7.2 MB    | ########## | 100%
# scikit-learn-0.23.2  | 6.9 MB    | ########## | 100%
# pycparser-2.20       | 94 KB     | ########## | 100%
# gnutls-3.6.5         | 1.9 MB    | ########## | 100%
# python-3.6.2         | 27.0 MB   | ########## | 100%
# certifi-2020.6.20    | 160 KB    | ########## | 100%
# python_abi-3.6       | 4 KB      | ########## | 100%
# scipy-1.5.2          | 18.5 MB   | ########## | 100%
# numpy-1.19.1         | 20 KB     | ########## | 100%
# ca-certificates-2020 | 128 KB    | ########## | 100%
# pyyaml-5.3.1         | 191 KB    | ########## | 100%
# openssl-1.0.2u       | 3.1 MB    | ########## | 100%
# gcc_impl_linux-64-7. | 70.6 MB   | ########## | 100%
# idna-2.10            | 56 KB     | ########## | 100%
# gxx_linux-64-7.3.0   | 25 KB     | ########## | 100%
# python-dateutil-2.8. | 224 KB    | ########## | 100%
# audioread-2.1.9      | 32 KB     | ########## | 100%
# libpng-1.6.37        | 364 KB    | ########## | 100%
# binutils_linux-64-2. | 24 KB     | ########## | 100%
# libgcc-ng-9.1.0      | 8.1 MB    | ########## | 100%
# openh264-2.1.0       | 1.5 MB    | ########## | 100%
# tk-8.6.10            | 3.2 MB    | ########## | 100%
# asn1crypto-1.4.0     | 77 KB     | ########## | 100%
# mkl-2019.4           | 204.1 MB  | #########9 | 100%
# mkl-2019.4           | 204.1 MB  | ########## | 100%
# icu-58.2             | 22.7 MB   | ########## | 100%
# ld_impl_linux-64-2.3 | 645 KB    | ########## | 100%
# gettext-0.19.8.1     | 3.7 MB    | ########## | 100%
# setuptools-50.3.0    | 891 KB    | ########## | 100%
# pyparsing-2.4.7      | 64 KB     | ########## | 100%
# librosa-0.8.0        | 145 KB    | ########## | 100%
# ncurses-6.0          | 907 KB    | ########## | 100%
# wheel-0.35.1         | 36 KB     | ########## | 100%
# appdirs-1.4.4        | 13 KB     | ########## | 100%
# _libgcc_mutex-0.1    | 3 KB      | ########## | 100%
# decorator-4.4.2      | 14 KB     | ########## | 100%
# cffi-1.14.0          | 225 KB    | ########## | 100%
# numba-0.51.2         | 3.7 MB    | ########## | 100%
# libllvm10-10.0.1     | 26.5 MB   | ########## | 100%
# libflac-1.3.3        | 517 KB    | ########## | 100%
# xz-5.2.5             | 438 KB    | ########## | 100%
# readline-7.0         | 387 KB    | ########## | 100%
# libgomp-9.2.0        | 816 KB    | ########## | 100%
# mkl-service-2.3.0    | 208 KB    | ########## | 100%
# numpy-base-1.19.1    | 5.2 MB    | ########## | 100%
# sqlite-3.23.1        | 1.5 MB    | ########## | 100%
# lame-3.100           | 502 KB    | ########## | 100%
# freetype-2.10.4      | 901 KB    | ########## | 100%
# pyopenssl-19.0.0     | 82 KB     | ########## | 100%
# cryptography-2.3.1   | 585 KB    | ########## | 100%
# x264-1!157.20191217  | 2.5 MB    | ########## | 100%
# bzip2-1.0.8          | 105 KB    | ########## | 100%
# intel-openmp-2020.2  | 947 KB    | ########## | 100%
# libffi-3.2.1         | 52 KB     | ########## | 100%
# Preparing transaction: ...working... done
# Verifying transaction: ...working... done
# Executing transaction: ...working... done
# Ran pip subprocess with arguments:
# ['/azureml-envs/azureml_20c402732d5823ad8d6d590fb2eba6c0/bin/python', '-m', 'pip', 'install', '-U', '-r', '/azureml-environment-setup/condaenv.umic08na.requirements.txt']
# Pip subprocess output:
# Collecting azureml-defaults~=1.24.0
#   Downloading azureml_defaults-1.24.0-py3-none-any.whl (3.1 kB)
# Collecting azureml==0.2.7
#   Downloading azureml-0.2.7-py2.py3-none-any.whl (23 kB)
# Collecting azureml-core~=1.24.0
#   Downloading azureml_core-1.24.0.post2-py3-none-any.whl (2.2 MB)
# Collecting azureml-sdk~=1.24.0
#   Downloading azureml_sdk-1.24.0-py3-none-any.whl (4.4 kB)
# Collecting azureml-automl-core~=1.24.0
#   Downloading azureml_automl_core-1.24.0-py3-none-any.whl (195 kB)
# Collecting azureml-automl-runtime~=1.24.0
#   Downloading azureml_automl_runtime-1.24.0-py3-none-any.whl (2.0 MB)
# Collecting azure-storage-blob==12.6.0
#   Downloading azure_storage_blob-12.6.0-py2.py3-none-any.whl (328 kB)
# Collecting numpy==1.18.5
#   Downloading numpy-1.18.5-cp36-cp36m-manylinux1_x86_64.whl (20.1 MB)
# Collecting pandas==0.25.3
#   Downloading pandas-0.25.3-cp36-cp36m-manylinux1_x86_64.whl (10.4 MB)
# Collecting sqlalchemy==1.3.21
#   Downloading SQLAlchemy-1.3.21-cp36-cp36m-manylinux2010_x86_64.whl (1.3 MB)
# Collecting h5py==2.10.0
#   Downloading h5py-2.10.0-cp36-cp36m-manylinux1_x86_64.whl (2.9 MB)
# Collecting tqdm==4.54.0
#   Downloading tqdm-4.54.0-py2.py3-none-any.whl (69 kB)
# Collecting obspy==1.2.2
#   Downloading obspy-1.2.2.zip (24.7 MB)
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: finished with status 'done'
#   Installing backend dependencies: started
#   Installing backend dependencies: finished with status 'done'
#     Preparing wheel metadata: started
#     Preparing wheel metadata: finished with status 'done'
# Collecting mysql-connector-python==8.0.18
#   Downloading mysql_connector_python-8.0.18-cp36-cp36m-manylinux1_x86_64.whl (16.1 MB)
# Collecting joblib==0.14.1
#   Downloading joblib-0.14.1-py2.py3-none-any.whl (294 kB)
# Collecting packaging==20.7
#   Downloading packaging-20.7-py2.py3-none-any.whl (35 kB)
# Collecting xgboost==0.90
#   Downloading xgboost-0.90-py2.py3-none-manylinux1_x86_64.whl (142.8 MB)
# Collecting noisereduce==1.1.0
#   Downloading noisereduce-1.1.0.tar.gz (6.3 kB)
# Collecting azureml-dataset-runtime[fuse]~=1.24.0
#   Downloading azureml_dataset_runtime-1.24.0-py3-none-any.whl (3.4 kB)
# Collecting applicationinsights>=0.11.7
#   Downloading applicationinsights-0.11.10-py2.py3-none-any.whl (55 kB)
# Collecting werkzeug<=1.0.1,>=0.16.1
#   Downloading Werkzeug-1.0.1-py2.py3-none-any.whl (298 kB)
# Collecting gunicorn==19.9.0
#   Downloading gunicorn-19.9.0-py2.py3-none-any.whl (112 kB)
# Collecting configparser==3.7.4
#   Downloading configparser-3.7.4-py2.py3-none-any.whl (22 kB)
# Collecting flask==1.0.3
#   Downloading Flask-1.0.3-py2.py3-none-any.whl (92 kB)
# Collecting json-logging-py==0.2
#   Downloading json-logging-py-0.2.tar.gz (3.6 kB)
# Collecting azureml-model-management-sdk==1.0.1b6.post1
#   Downloading azureml_model_management_sdk-1.0.1b6.post1-py2.py3-none-any.whl (130 kB)
# Requirement already satisfied, skipping upgrade: python-dateutil in /azureml-envs/azureml_20c402732d5823ad8d6d590fb2eba6c0/lib/python3.6/site-packages (from azureml==0.2.7->-r /azureml-environment-setup/condaenv.umic08na.requirements.txt (line 2)) (2.8.1)
# Requirement already satisfied, skipping upgrade: requests in /azureml-envs/azureml_20c402732d5823ad8d6d590fb2eba6c0/lib/python3.6/site-packages (from azureml==0.2.7->-r /azureml-environment-setup/condaenv.umic08na.requirements.txt (line 2)) (2.24.0)
# Requirement already satisfied, skipping upgrade: urllib3>=1.23 in /azureml-envs/azureml_20c402732d5823ad8d6d590fb2eba6c0/lib/python3.6/site-packages (from azureml-core~=1.24.0->-r /azureml-environment-setup/condaenv.umic08na.requirements.txt (line 3)) (1.25.11)
# Collecting azure-mgmt-resource<15.0.0,>=1.2.1
#   Downloading azure_mgmt_resource-13.0.0-py2.py3-none-any.whl (1.3 MB)
# Collecting msrestazure>=0.4.33
#   Downloading msrestazure-0.6.4-py2.py3-none-any.whl (40 kB)
# Collecting azure-mgmt-storage<16.0.0,>=1.5.0
#   Downloading azure_mgmt_storage-11.2.0-py2.py3-none-any.whl (547 kB)
# Collecting PyJWT<3.0.0
#   Downloading PyJWT-2.1.0-py3-none-any.whl (16 kB)
# Collecting pathspec
#   Downloading pathspec-0.8.1-py2.py3-none-any.whl (28 kB)
# Collecting ndg-httpsclient
#   Downloading ndg_httpsclient-0.5.1-py3-none-any.whl (34 kB)
# Requirement already satisfied, skipping upgrade: pyopenssl<21.0.0 in /azureml-envs/azureml_20c402732d5823ad8d6d590fb2eba6c0/lib/python3.6/site-packages (from azureml-core~=1.24.0->-r /azureml-environment-setup/condaenv.umic08na.requirements.txt (line 3)) (19.0.0)
# Collecting ruamel.yaml>=0.15.35
#   Downloading ruamel.yaml-0.17.4-py3-none-any.whl (101 kB)
# Collecting adal>=1.2.0
#   Downloading adal-1.2.7-py2.py3-none-any.whl (55 kB)
# Requirement already satisfied, skipping upgrade: cryptography!=1.9,!=2.0.*,!=2.1.*,!=2.2.*,<4.0.0 in /azureml-envs/azureml_20c402732d5823ad8d6d590fb2eba6c0/lib/python3.6/site-packages (from azureml-core~=1.24.0->-r /azureml-environment-setup/condaenv.umic08na.requirements.txt (line 3)) (2.3.1)
# Collecting pytz
#   Downloading pytz-2021.1-py2.py3-none-any.whl (510 kB)
# Collecting docker
#   Downloading docker-5.0.0-py2.py3-none-any.whl (146 kB)
# Collecting msrest>=0.5.1
#   Downloading msrest-0.6.21-py2.py3-none-any.whl (85 kB)
# Collecting azure-graphrbac<1.0.0,>=0.40.0
#   Downloading azure_graphrbac-0.61.1-py2.py3-none-any.whl (141 kB)
# Collecting backports.tempfile
#   Downloading backports.tempfile-1.0-py2.py3-none-any.whl (4.4 kB)
# Collecting azure-common>=1.1.12
#   Downloading azure_common-1.1.27-py2.py3-none-any.whl (12 kB)
# Collecting jsonpickle
#   Downloading jsonpickle-2.0.0-py2.py3-none-any.whl (37 kB)
# Collecting SecretStorage
#   Downloading SecretStorage-3.3.1-py3-none-any.whl (15 kB)
# Collecting jmespath
#   Downloading jmespath-0.10.0-py2.py3-none-any.whl (24 kB)
# Collecting azure-mgmt-authorization<1.0.0,>=0.40.0
#   Downloading azure_mgmt_authorization-0.61.0-py2.py3-none-any.whl (94 kB)
# Collecting azure-mgmt-containerregistry>=2.0.0
#   Downloading azure_mgmt_containerregistry-2.8.0-py2.py3-none-any.whl (718 kB)
# Collecting contextlib2
#   Downloading contextlib2-0.6.0.post1-py2.py3-none-any.whl (9.8 kB)
# Collecting azure-mgmt-keyvault<7.0.0,>=0.40.0
#   Downloading azure_mgmt_keyvault-2.2.0-py2.py3-none-any.whl (89 kB)
# Collecting azureml-train~=1.24.0
#   Downloading azureml_train-1.24.0-py3-none-any.whl (3.3 kB)
# Collecting azureml-train-automl-client~=1.24.0
#   Downloading azureml_train_automl_client-1.24.0-py3-none-any.whl (118 kB)
# Collecting azureml-pipeline~=1.24.0
#   Downloading azureml_pipeline-1.24.0-py3-none-any.whl (3.7 kB)
# Collecting azureml-telemetry~=1.24.0
#   Downloading azureml_telemetry-1.24.0-py3-none-any.whl (30 kB)
# Collecting dill<0.4.0,>=0.2.8
#   Downloading dill-0.3.3-py2.py3-none-any.whl (81 kB)
# Collecting onnxconverter-common<=1.6.0,>=1.4.2
#   Downloading onnxconverter_common-1.6.0-py2.py3-none-any.whl (43 kB)
# Collecting skl2onnx==1.4.9
#   Downloading skl2onnx-1.4.9-py2.py3-none-any.whl (114 kB)
# Requirement already satisfied, skipping upgrade: scipy<=1.5.2,>=1.0.0 in /azureml-envs/azureml_20c402732d5823ad8d6d590fb2eba6c0/lib/python3.6/site-packages (from azureml-automl-runtime~=1.24.0->-r /azureml-environment-setup/condaenv.umic08na.requirements.txt (line 6)) (1.5.2)
# Collecting py-cpuinfo==5.0.0
#   Downloading py-cpuinfo-5.0.0.tar.gz (82 kB)
# Collecting botocore<=1.18.18
#   Downloading botocore-1.18.18-py2.py3-none-any.whl (6.7 MB)
# Collecting onnxmltools==1.4.1
#   Downloading onnxmltools-1.4.1-py2.py3-none-any.whl (371 kB)
# Collecting smart-open<=1.9.0
#   Downloading smart_open-1.9.0.tar.gz (70 kB)
# Collecting nimbusml<=1.8.0,>=1.7.1
#   Downloading nimbusml-1.8.0-cp36-none-manylinux1_x86_64.whl (114.1 MB)
# Collecting keras2onnx<=1.6.0,>=1.4.0
#   Downloading keras2onnx-1.6.0-py3-none-any.whl (219 kB)
# Collecting statsmodels<=0.10.2,>=0.9.0
#   Downloading statsmodels-0.10.2-cp36-cp36m-manylinux1_x86_64.whl (8.1 MB)
# Collecting lightgbm<=2.3.0,>=2.0.11
#   Downloading lightgbm-2.3.0-py2.py3-none-manylinux1_x86_64.whl (1.3 MB)
# Collecting psutil<6.0.0,>=5.2.2
#   Downloading psutil-5.8.0-cp36-cp36m-manylinux2010_x86_64.whl (291 kB)
# Collecting boto3<=1.15.18
#   Downloading boto3-1.15.18-py2.py3-none-any.whl (129 kB)
# Collecting pmdarima==1.1.1
#   Downloading pmdarima-1.1.1-cp36-cp36m-manylinux1_x86_64.whl (682 kB)
# Collecting gensim<3.9.0
#   Downloading gensim-3.8.3-cp36-cp36m-manylinux1_x86_64.whl (24.2 MB)
# Collecting onnxruntime<=1.6.0,>=1.3.0
#   Downloading onnxruntime-1.6.0-cp36-cp36m-manylinux2014_x86_64.whl (4.1 MB)
# Collecting onnx<=1.7.0,>=1.5.0
#   Downloading onnx-1.7.0-cp36-cp36m-manylinux1_x86_64.whl (7.4 MB)
# Collecting scikit-learn<0.23.0,>=0.19.0
#   Downloading scikit_learn-0.22.2.post1-cp36-cp36m-manylinux1_x86_64.whl (7.1 MB)
# Collecting sklearn-pandas<=1.7.0,>=1.4.0
#   Downloading sklearn_pandas-1.7.0-py2.py3-none-any.whl (10 kB)
# Collecting azure-core<2.0.0,>=1.9.0
#   Downloading azure_core-1.14.0-py2.py3-none-any.whl (136 kB)
# Requirement already satisfied, skipping upgrade: six in /azureml-envs/azureml_20c402732d5823ad8d6d590fb2eba6c0/lib/python3.6/site-packages (from h5py==2.10.0->-r /azureml-environment-setup/condaenv.umic08na.requirements.txt (line 11)) (1.15.0)
# Requirement already satisfied, skipping upgrade: setuptools in /azureml-envs/azureml_20c402732d5823ad8d6d590fb2eba6c0/lib/python3.6/site-packages (from obspy==1.2.2->-r /azureml-environment-setup/condaenv.umic08na.requirements.txt (line 13)) (50.3.0.post20201006)
# Collecting future>=0.12.4
#   Downloading future-0.18.2.tar.gz (829 kB)
# Collecting lxml
#   Downloading lxml-4.6.3-cp36-cp36m-manylinux2014_x86_64.whl (6.3 MB)
# Requirement already satisfied, skipping upgrade: matplotlib>=1.1.0 in /azureml-envs/azureml_20c402732d5823ad8d6d590fb2eba6c0/lib/python3.6/site-packages (from obspy==1.2.2->-r /azureml-environment-setup/condaenv.umic08na.requirements.txt (line 13)) (3.2.2)
# Requirement already satisfied, skipping upgrade: decorator in /azureml-envs/azureml_20c402732d5823ad8d6d590fb2eba6c0/lib/python3.6/site-packages (from obspy==1.2.2->-r /azureml-environment-setup/condaenv.umic08na.requirements.txt (line 13)) (4.4.2)
# Collecting protobuf>=3.0.0
#   Downloading protobuf-3.17.0-cp36-cp36m-manylinux_2_5_x86_64.manylinux1_x86_64.whl (1.0 MB)
# Requirement already satisfied, skipping upgrade: pyparsing>=2.0.2 in /azureml-envs/azureml_20c402732d5823ad8d6d590fb2eba6c0/lib/python3.6/site-packages (from packaging==20.7->-r /azureml-environment-setup/condaenv.umic08na.requirements.txt (line 16)) (2.4.7)
# Requirement already satisfied, skipping upgrade: librosa in /azureml-envs/azureml_20c402732d5823ad8d6d590fb2eba6c0/lib/python3.6/site-packages (from noisereduce==1.1.0->-r /azureml-environment-setup/condaenv.umic08na.requirements.txt (line 18)) (0.8.0)
# Collecting azureml-dataprep<2.12.0a,>=2.11.0a
#   Downloading azureml_dataprep-2.11.2-py3-none-any.whl (39.4 MB)
# Collecting pyarrow<2.0.0,>=0.17.0
#   Downloading pyarrow-1.0.1-cp36-cp36m-manylinux2014_x86_64.whl (17.3 MB)
# Collecting fusepy<4.0.0,>=3.0.1; extra == "fuse"
#   Downloading fusepy-3.0.1.tar.gz (11 kB)
# Collecting itsdangerous>=0.24
#   Downloading itsdangerous-2.0.0-py3-none-any.whl (18 kB)
# Collecting Jinja2>=2.10
#   Downloading Jinja2-3.0.0-py3-none-any.whl (133 kB)
# Collecting click>=5.1
#   Downloading click-8.0.0-py3-none-any.whl (96 kB)
# Collecting liac-arff>=2.1.1
#   Downloading liac-arff-2.5.0.tar.gz (13 kB)
# Requirement already satisfied, skipping upgrade: idna<3,>=2.5 in /azureml-envs/azureml_20c402732d5823ad8d6d590fb2eba6c0/lib/python3.6/site-packages (from requests->azureml==0.2.7->-r /azureml-environment-setup/condaenv.umic08na.requirements.txt (line 2)) (2.10)
# Requirement already satisfied, skipping upgrade: chardet<4,>=3.0.2 in /azureml-envs/azureml_20c402732d5823ad8d6d590fb2eba6c0/lib/python3.6/site-packages (from requests->azureml==0.2.7->-r /azureml-environment-setup/condaenv.umic08na.requirements.txt (line 2)) (3.0.4)
# Requirement already satisfied, skipping upgrade: certifi>=2017.4.17 in /azureml-envs/azureml_20c402732d5823ad8d6d590fb2eba6c0/lib/python3.6/site-packages (from requests->azureml==0.2.7->-r /azureml-environment-setup/condaenv.umic08na.requirements.txt (line 2)) (2020.6.20)
# Collecting pyasn1>=0.1.1
#   Downloading pyasn1-0.4.8-py2.py3-none-any.whl (77 kB)
# Collecting ruamel.yaml.clib>=0.1.2; platform_python_implementation == "CPython" and python_version < "3.10"
#   Downloading ruamel.yaml.clib-0.2.2-cp36-cp36m-manylinux1_x86_64.whl (549 kB)
# Requirement already satisfied, skipping upgrade: asn1crypto>=0.21.0 in /azureml-envs/azureml_20c402732d5823ad8d6d590fb2eba6c0/lib/python3.6/site-packages (from cryptography!=1.9,!=2.0.*,!=2.1.*,!=2.2.*,<4.0.0->azureml-core~=1.24.0->-r /azureml-environment-setup/condaenv.umic08na.requirements.txt (line 3)) (1.4.0)
# Requirement already satisfied, skipping upgrade: cffi!=1.11.3,>=1.7 in /azureml-envs/azureml_20c402732d5823ad8d6d590fb2eba6c0/lib/python3.6/site-packages (from cryptography!=1.9,!=2.0.*,!=2.1.*,!=2.2.*,<4.0.0->azureml-core~=1.24.0->-r /azureml-environment-setup/condaenv.umic08na.requirements.txt (line 3)) (1.14.0)
# Collecting websocket-client>=0.32.0
#   Downloading websocket_client-0.59.0-py2.py3-none-any.whl (67 kB)
# Collecting requests-oauthlib>=0.5.0
#   Downloading requests_oauthlib-1.3.0-py2.py3-none-any.whl (23 kB)
# Collecting isodate>=0.6.0
#   Downloading isodate-0.6.0-py2.py3-none-any.whl (45 kB)
# Collecting backports.weakref
#   Downloading backports.weakref-1.0.post1-py2.py3-none-any.whl (5.2 kB)
# Collecting importlib-metadata; python_version < "3.8"
#   Downloading importlib_metadata-4.0.1-py3-none-any.whl (16 kB)
# Collecting jeepney>=0.6
#   Downloading jeepney-0.6.0-py3-none-any.whl (45 kB)
# Collecting azureml-train-core~=1.24.0
#   Downloading azureml_train_core-1.24.0-py3-none-any.whl (8.6 MB)
# Collecting azureml-pipeline-steps~=1.24.0
#   Downloading azureml_pipeline_steps-1.24.0-py3-none-any.whl (67 kB)
# Collecting azureml-pipeline-core~=1.24.0
#   Downloading azureml_pipeline_core-1.24.0-py3-none-any.whl (308 kB)
# Collecting boto>=2.32
#   Downloading boto-2.49.0-py2.py3-none-any.whl (1.4 MB)
# Collecting dotnetcore2>=2.1.2
#   Downloading dotnetcore2-2.1.20-py3-none-manylinux1_x86_64.whl (28.7 MB)
# Collecting fire
#   Downloading fire-0.4.0.tar.gz (87 kB)
# Collecting patsy>=0.4.0
#   Downloading patsy-0.5.1-py2.py3-none-any.whl (231 kB)
# Collecting s3transfer<0.4.0,>=0.3.0
#   Downloading s3transfer-0.3.7-py2.py3-none-any.whl (73 kB)
# Collecting Cython>=0.29
#   Downloading Cython-0.29.23-cp36-cp36m-manylinux1_x86_64.whl (2.0 MB)
# Collecting typing-extensions>=3.6.2.1
#   Downloading typing_extensions-3.10.0.0-py3-none-any.whl (26 kB)
# Requirement already satisfied, skipping upgrade: kiwisolver>=1.0.1 in /azureml-envs/azureml_20c402732d5823ad8d6d590fb2eba6c0/lib/python3.6/site-packages (from matplotlib>=1.1.0->obspy==1.2.2->-r /azureml-environment-setup/condaenv.umic08na.requirements.txt (line 13)) (1.2.0)
# Requirement already satisfied, skipping upgrade: cycler>=0.10 in /azureml-envs/azureml_20c402732d5823ad8d6d590fb2eba6c0/lib/python3.6/site-packages (from matplotlib>=1.1.0->obspy==1.2.2->-r /azureml-environment-setup/condaenv.umic08na.requirements.txt (line 13)) (0.10.0)
# Requirement already satisfied, skipping upgrade: pooch>=1.0 in /azureml-envs/azureml_20c402732d5823ad8d6d590fb2eba6c0/lib/python3.6/site-packages (from librosa->noisereduce==1.1.0->-r /azureml-environment-setup/condaenv.umic08na.requirements.txt (line 18)) (1.3.0)
# Requirement already satisfied, skipping upgrade: audioread>=2.0.0 in /azureml-envs/azureml_20c402732d5823ad8d6d590fb2eba6c0/lib/python3.6/site-packages (from librosa->noisereduce==1.1.0->-r /azureml-environment-setup/condaenv.umic08na.requirements.txt (line 18)) (2.1.9)
# Requirement already satisfied, skipping upgrade: numba>=0.43.0 in /azureml-envs/azureml_20c402732d5823ad8d6d590fb2eba6c0/lib/python3.6/site-packages (from librosa->noisereduce==1.1.0->-r /azureml-environment-setup/condaenv.umic08na.requirements.txt (line 18)) (0.51.2)
# Requirement already satisfied, skipping upgrade: resampy>=0.2.2 in /azureml-envs/azureml_20c402732d5823ad8d6d590fb2eba6c0/lib/python3.6/site-packages (from librosa->noisereduce==1.1.0->-r /azureml-environment-setup/condaenv.umic08na.requirements.txt (line 18)) (0.2.2)
# Requirement already satisfied, skipping upgrade: soundfile>=0.9.0 in /azureml-envs/azureml_20c402732d5823ad8d6d590fb2eba6c0/lib/python3.6/site-packages (from librosa->noisereduce==1.1.0->-r /azureml-environment-setup/condaenv.umic08na.requirements.txt (line 18)) (0.10.3.post1)
# Collecting azureml-dataprep-rslex<1.10.0a,>=1.9.0dev0
#   Downloading azureml_dataprep_rslex-1.9.1-cp36-cp36m-manylinux2010_x86_64.whl (9.0 MB)
# Collecting azure-identity<1.5.0,>=1.2.0
#   Downloading azure_identity-1.4.1-py2.py3-none-any.whl (86 kB)
# Collecting azureml-dataprep-native<31.0.0,>=30.0.0
#   Downloading azureml_dataprep_native-30.0.0-cp36-cp36m-manylinux1_x86_64.whl (1.3 MB)
# Collecting cloudpickle<2.0.0,>=1.1.0
#   Downloading cloudpickle-1.6.0-py3-none-any.whl (23 kB)
# Collecting MarkupSafe>=2.0.0rc2
#   Downloading MarkupSafe-2.0.0-cp36-cp36m-manylinux2010_x86_64.whl (30 kB)
# Requirement already satisfied, skipping upgrade: pycparser in /azureml-envs/azureml_20c402732d5823ad8d6d590fb2eba6c0/lib/python3.6/site-packages (from cffi!=1.11.3,>=1.7->cryptography!=1.9,!=2.0.*,!=2.1.*,!=2.2.*,<4.0.0->azureml-core~=1.24.0->-r /azureml-environment-setup/condaenv.umic08na.requirements.txt (line 3)) (2.20)
# Collecting oauthlib>=3.0.0
#   Downloading oauthlib-3.1.0-py2.py3-none-any.whl (147 kB)
# Collecting zipp>=0.5
#   Downloading zipp-3.4.1-py3-none-any.whl (5.2 kB)
# Collecting azureml-train-restclients-hyperdrive~=1.24.0
#   Downloading azureml_train_restclients_hyperdrive-1.24.0-py3-none-any.whl (19 kB)
# Collecting distro>=1.2.0
#   Downloading distro-1.5.0-py2.py3-none-any.whl (18 kB)
# Collecting termcolor
#   Downloading termcolor-1.1.0.tar.gz (3.9 kB)
# Requirement already satisfied, skipping upgrade: appdirs in /azureml-envs/azureml_20c402732d5823ad8d6d590fb2eba6c0/lib/python3.6/site-packages (from pooch>=1.0->librosa->noisereduce==1.1.0->-r /azureml-environment-setup/condaenv.umic08na.requirements.txt (line 18)) (1.4.4)
# Requirement already satisfied, skipping upgrade: llvmlite<0.35,>=0.34.0.dev0 in /azureml-envs/azureml_20c402732d5823ad8d6d590fb2eba6c0/lib/python3.6/site-packages (from numba>=0.43.0->librosa->noisereduce==1.1.0->-r /azureml-environment-setup/condaenv.umic08na.requirements.txt (line 18)) (0.34.0)
# Collecting msal-extensions~=0.2.2
#   Downloading msal_extensions-0.2.2-py2.py3-none-any.whl (15 kB)
# Collecting msal<2.0.0,>=1.3.0
#   Downloading msal-1.11.0-py2.py3-none-any.whl (63 kB)
# Collecting portalocker~=1.0; platform_system != "Windows"
#   Downloading portalocker-1.7.1-py2.py3-none-any.whl (10 kB)
# Building wheels for collected packages: obspy, noisereduce, json-logging-py, py-cpuinfo, smart-open, future, fusepy, liac-arff, fire, termcolor
#   Building wheel for obspy (PEP 517): started
#   Building wheel for obspy (PEP 517): finished with status 'error'
#   Building wheel for noisereduce (setup.py): started
#   Building wheel for noisereduce (setup.py): finished with status 'done'
#   Created wheel for noisereduce: filename=noisereduce-1.1.0-py3-none-any.whl size=7607 sha256=5c4eb46ea9ccf98f69b2663a7da191529e92efcbbfd5218c152c943d642a2947
#   Stored in directory: /root/.cache/pip/wheels/a9/d4/51/49c94295d30569d64c83dc11dce56166173635c85d060c9859
#   Building wheel for json-logging-py (setup.py): started
#   Building wheel for json-logging-py (setup.py): finished with status 'done'
#   Created wheel for json-logging-py: filename=json_logging_py-0.2-py3-none-any.whl size=3924 sha256=4e43282d21a671b435d21131f69dcc5233b3cc1513f04a7c56189f62e2639846
#   Stored in directory: /root/.cache/pip/wheels/e2/1d/52/535a274b9c2ce7d4064838f2bdb62013801281ef7d7f21e2ee
#   Building wheel for py-cpuinfo (setup.py): started
#   Building wheel for py-cpuinfo (setup.py): finished with status 'done'
#   Created wheel for py-cpuinfo: filename=py_cpuinfo-5.0.0-py3-none-any.whl size=18683 sha256=5146d48a94fad27ec5cbee25e98689bb0be2d07c7d8c7e518c76406a3adc46cd
#   Stored in directory: /root/.cache/pip/wheels/e6/54/db/65176a1697a583d8ec5f90510f6faab11cda739d0e4f0ba2ea
#   Building wheel for smart-open (setup.py): started
#   Building wheel for smart-open (setup.py): finished with status 'done'
#   Created wheel for smart-open: filename=smart_open-1.9.0-py3-none-any.whl size=73087 sha256=77624b4397f60a002f244f392dc0577b7883b8d28af1102892411391dd3acb87
#   Stored in directory: /root/.cache/pip/wheels/8e/9f/cd/dbf5c1362c59abb699a218c1151679033b8ccb5b6db559d512
#   Building wheel for future (setup.py): started
#   Building wheel for future (setup.py): finished with status 'done'
#   Created wheel for future: filename=future-0.18.2-py3-none-any.whl size=491059 sha256=8affa55a978f44b76f88598e08ebf567bc9a5f91abb6dce106e50c89b5402bcd
#   Stored in directory: /root/.cache/pip/wheels/6e/9c/ed/4499c9865ac1002697793e0ae05ba6be33553d098f3347fb94
#   Building wheel for fusepy (setup.py): started
#   Building wheel for fusepy (setup.py): finished with status 'done'
#   Created wheel for fusepy: filename=fusepy-3.0.1-py3-none-any.whl size=10504 sha256=98348b9614055ada21e9e908add3d5ddc86c44f9f6fc7881d603e87aa2d69e25
#   Stored in directory: /root/.cache/pip/wheels/21/5c/83/1dd7e8a232d12227e5410120f4374b33adeb4037473105b079
#   Building wheel for liac-arff (setup.py): started
#   Building wheel for liac-arff (setup.py): finished with status 'done'
#   Created wheel for liac-arff: filename=liac_arff-2.5.0-py3-none-any.whl size=11730 sha256=feb8b544b08d14343655255da895119b0367bf98fe761d508c95dc9fa7bb59a6
#   Stored in directory: /root/.cache/pip/wheels/53/ba/da/8562a6a6dbb428fd1ecc21053106df3948645cd991958f669b
#   Building wheel for fire (setup.py): started
#   Building wheel for fire (setup.py): finished with status 'done'
#   Created wheel for fire: filename=fire-0.4.0-py2.py3-none-any.whl size=115928 sha256=202f69f4bf762e8d0e9b39208ba5168e7ca70c4c04d2c272d2b1f38a21f77cea
#   Stored in directory: /root/.cache/pip/wheels/a6/12/74/ce0728e3990845862240349a12d7179a262e388ec73938024b
#   Building wheel for termcolor (setup.py): started
#   Building wheel for termcolor (setup.py): finished with status 'done'
#   Created wheel for termcolor: filename=termcolor-1.1.0-py3-none-any.whl size=4830 sha256=dd7450827e46987c698314b2cf93fe892efc30b2279e9e25c3708c12fa1f0634
#   Stored in directory: /root/.cache/pip/wheels/93/2a/eb/e58dbcbc963549ee4f065ff80a59f274cc7210b6eab962acdc
# Successfully built noisereduce json-logging-py py-cpuinfo smart-open future fusepy liac-arff fire termcolor
# Failed to build obspy
#
#
# ==> WARNING: A newer version of conda exists. <==
#   current version: 4.7.12
#   latest version: 4.10.1
#
# Please update conda by running
#
#     $ conda update -n base -c defaults conda
#
#
# Pip subprocess error:
#   ERROR: Command errored out with exit status 1:
#    command: /azureml-envs/azureml_20c402732d5823ad8d6d590fb2eba6c0/bin/python /azureml-envs/azureml_20c402732d5823ad8d6d590fb2eba6c0/lib/python3.6/site-packages/pip/_vendor/pep517/_in_process.py build_wheel /tmp/tmpvcd2rag1
#        cwd: /tmp/pip-install-18ho7l5e/obspy
#   Complete output (705 lines):
#   running bdist_wheel
#   running build
#   running config_cc
#   unifing config_cc, config, build_clib, build_ext, build commands --compiler options
#   running config_fc
#   unifing config_fc, config, build_clib, build_ext, build commands --fcompiler options
#   running build_src
#   build_src
#   building extension "libgse2_Linux_64bit_py36" sources
#   building extension "libmseed_Linux_64bit_py36" sources
#   building extension "libsegy_Linux_64bit_py36" sources
#   building extension "libsignal_Linux_64bit_py36" sources
#   building extension "libevresp_Linux_64bit_py36" sources
#   building extension "libtau_Linux_64bit_py36" sources
#   building data_files sources
#   build_src: building npy-pkg config files
#   running build_py
#   creating build
#   creating build/lib.linux-x86_64-3.6
#   creating build/lib.linux-x86_64-3.6/obspy
#   copying obspy/__init__.py -> build/lib.linux-x86_64-3.6/obspy
#   creating build/lib.linux-x86_64-3.6/obspy/signal
#   copying obspy/signal/interpolation.py -> build/lib.linux-x86_64-3.6/obspy/signal
#   copying obspy/signal/spectral_estimation.py -> build/lib.linux-x86_64-3.6/obspy/signal
#   copying obspy/signal/trigger.py -> build/lib.linux-x86_64-3.6/obspy/signal
#   copying obspy/signal/konnoohmachismoothing.py -> build/lib.linux-x86_64-3.6/obspy/signal
#   copying obspy/signal/regression.py -> build/lib.linux-x86_64-3.6/obspy/signal
#   copying obspy/signal/evrespwrapper.py -> build/lib.linux-x86_64-3.6/obspy/signal
#   copying obspy/signal/detrend.py -> build/lib.linux-x86_64-3.6/obspy/signal
#   copying obspy/signal/freqattributes.py -> build/lib.linux-x86_64-3.6/obspy/signal
#   copying obspy/signal/filter.py -> build/lib.linux-x86_64-3.6/obspy/signal
#   copying obspy/signal/calibration.py -> build/lib.linux-x86_64-3.6/obspy/signal
#   copying obspy/signal/util.py -> build/lib.linux-x86_64-3.6/obspy/signal
#   copying obspy/signal/polarization.py -> build/lib.linux-x86_64-3.6/obspy/signal
#   copying obspy/signal/tf_misfit.py -> build/lib.linux-x86_64-3.6/obspy/signal
#   copying obspy/signal/array_analysis.py -> build/lib.linux-x86_64-3.6/obspy/signal
#   copying obspy/signal/hoctavbands.py -> build/lib.linux-x86_64-3.6/obspy/signal
#   copying obspy/signal/headers.py -> build/lib.linux-x86_64-3.6/obspy/signal
#   copying obspy/signal/rotate.py -> build/lib.linux-x86_64-3.6/obspy/signal
#   copying obspy/signal/_sosfilt.py -> build/lib.linux-x86_64-3.6/obspy/signal
#   copying obspy/signal/invsim.py -> build/lib.linux-x86_64-3.6/obspy/signal
#   copying obspy/signal/quality_control.py -> build/lib.linux-x86_64-3.6/obspy/signal
#   copying obspy/signal/cpxtrace.py -> build/lib.linux-x86_64-3.6/obspy/signal
#   copying obspy/signal/cross_correlation.py -> build/lib.linux-x86_64-3.6/obspy/signal
#   copying obspy/signal/differentiate_and_integrate.py -> build/lib.linux-x86_64-3.6/obspy/signal
#   copying obspy/signal/__init__.py -> build/lib.linux-x86_64-3.6/obspy/signal
#   creating build/lib.linux-x86_64-3.6/obspy/signal/tests
#   copying obspy/signal/tests/test_array_analysis.py -> build/lib.linux-x86_64-3.6/obspy/signal/tests
#   copying obspy/signal/tests/test_filter.py -> build/lib.linux-x86_64-3.6/obspy/signal/tests
#   copying obspy/signal/tests/test_detrend.py -> build/lib.linux-x86_64-3.6/obspy/signal/tests
#   copying obspy/signal/tests/test_hoctavbands.py -> build/lib.linux-x86_64-3.6/obspy/signal/tests
#   copying obspy/signal/tests/test_freqattributes.py -> build/lib.linux-x86_64-3.6/obspy/signal/tests
#   copying obspy/signal/tests/test_trigger.py -> build/lib.linux-x86_64-3.6/obspy/signal/tests
#   copying obspy/signal/tests/test_interpolation.py -> build/lib.linux-x86_64-3.6/obspy/signal/tests
#   copying obspy/signal/tests/test_quality_control.py -> build/lib.linux-x86_64-3.6/obspy/signal/tests
#   copying obspy/signal/tests/test_invsim.py -> build/lib.linux-x86_64-3.6/obspy/signal/tests
#   copying obspy/signal/tests/test_regression.py -> build/lib.linux-x86_64-3.6/obspy/signal/tests
#   copying obspy/signal/tests/test_tf_misfit.py -> build/lib.linux-x86_64-3.6/obspy/signal/tests
#   copying obspy/signal/tests/test_differentiate_and_integrate.py -> build/lib.linux-x86_64-3.6/obspy/signal/tests
#   copying obspy/signal/tests/test_polarization.py -> build/lib.linux-x86_64-3.6/obspy/signal/tests
#   copying obspy/signal/tests/test_trace.py -> build/lib.linux-x86_64-3.6/obspy/signal/tests
#   copying obspy/signal/tests/test_konnoohmachi.py -> build/lib.linux-x86_64-3.6/obspy/signal/tests
#   copying obspy/signal/tests/test_spectral_estimation.py -> build/lib.linux-x86_64-3.6/obspy/signal/tests
#   copying obspy/signal/tests/test_cross_correlation.py -> build/lib.linux-x86_64-3.6/obspy/signal/tests
#   copying obspy/signal/tests/test_rotate.py -> build/lib.linux-x86_64-3.6/obspy/signal/tests
#   copying obspy/signal/tests/test_calibration.py -> build/lib.linux-x86_64-3.6/obspy/signal/tests
#   copying obspy/signal/tests/test_stream.py -> build/lib.linux-x86_64-3.6/obspy/signal/tests
#   copying obspy/signal/tests/test_cpxtrace.py -> build/lib.linux-x86_64-3.6/obspy/signal/tests
#   copying obspy/signal/tests/test_sonic.py -> build/lib.linux-x86_64-3.6/obspy/signal/tests
#   copying obspy/signal/tests/__init__.py -> build/lib.linux-x86_64-3.6/obspy/signal/tests
#   creating build/lib.linux-x86_64-3.6/obspy/scripts
#   copying obspy/scripts/flinnengdahl.py -> build/lib.linux-x86_64-3.6/obspy/scripts
#   copying obspy/scripts/_print.py -> build/lib.linux-x86_64-3.6/obspy/scripts
#   copying obspy/scripts/print.py -> build/lib.linux-x86_64-3.6/obspy/scripts
#   copying obspy/scripts/runtests.py -> build/lib.linux-x86_64-3.6/obspy/scripts
#   copying obspy/scripts/reftekrescue.py -> build/lib.linux-x86_64-3.6/obspy/scripts
#   copying obspy/scripts/__init__.py -> build/lib.linux-x86_64-3.6/obspy/scripts
#   copying obspy/scripts/sds_html_report.py -> build/lib.linux-x86_64-3.6/obspy/scripts
#   creating build/lib.linux-x86_64-3.6/obspy/scripts/tests
#   copying obspy/scripts/tests/test_print.py -> build/lib.linux-x86_64-3.6/obspy/scripts/tests
#   copying obspy/scripts/tests/__init__.py -> build/lib.linux-x86_64-3.6/obspy/scripts/tests
#   creating build/lib.linux-x86_64-3.6/obspy/clients
#   copying obspy/clients/httpproxy.py -> build/lib.linux-x86_64-3.6/obspy/clients
#   copying obspy/clients/base.py -> build/lib.linux-x86_64-3.6/obspy/clients
#   copying obspy/clients/__init__.py -> build/lib.linux-x86_64-3.6/obspy/clients
#   creating build/lib.linux-x86_64-3.6/obspy/clients/filesystem
#   copying obspy/clients/filesystem/sds.py -> build/lib.linux-x86_64-3.6/obspy/clients/filesystem
#   copying obspy/clients/filesystem/miniseed.py -> build/lib.linux-x86_64-3.6/obspy/clients/filesystem
#   copying obspy/clients/filesystem/msriterator.py -> build/lib.linux-x86_64-3.6/obspy/clients/filesystem
#   copying obspy/clients/filesystem/tsindex.py -> build/lib.linux-x86_64-3.6/obspy/clients/filesystem
#   copying obspy/clients/filesystem/db.py -> build/lib.linux-x86_64-3.6/obspy/clients/filesystem
#   copying obspy/clients/filesystem/__init__.py -> build/lib.linux-x86_64-3.6/obspy/clients/filesystem
#   creating build/lib.linux-x86_64-3.6/obspy/clients/filesystem/tests
#   copying obspy/clients/filesystem/tests/test_tsindex.py -> build/lib.linux-x86_64-3.6/obspy/clients/filesystem/tests
#   copying obspy/clients/filesystem/tests/test_sds.py -> build/lib.linux-x86_64-3.6/obspy/clients/filesystem/tests
#   copying obspy/clients/filesystem/tests/__init__.py -> build/lib.linux-x86_64-3.6/obspy/clients/filesystem/tests
#   creating build/lib.linux-x86_64-3.6/obspy/clients/iris
#   copying obspy/clients/iris/client.py -> build/lib.linux-x86_64-3.6/obspy/clients/iris
#   copying obspy/clients/iris/__init__.py -> build/lib.linux-x86_64-3.6/obspy/clients/iris
#   creating build/lib.linux-x86_64-3.6/obspy/clients/iris/tests
#   copying obspy/clients/iris/tests/test_client.py -> build/lib.linux-x86_64-3.6/obspy/clients/iris/tests
#   copying obspy/clients/iris/tests/__init__.py -> build/lib.linux-x86_64-3.6/obspy/clients/iris/tests
#   creating build/lib.linux-x86_64-3.6/obspy/clients/earthworm
#   copying obspy/clients/earthworm/waveserver.py -> build/lib.linux-x86_64-3.6/obspy/clients/earthworm
#   copying obspy/clients/earthworm/client.py -> build/lib.linux-x86_64-3.6/obspy/clients/earthworm
#   copying obspy/clients/earthworm/__init__.py -> build/lib.linux-x86_64-3.6/obspy/clients/earthworm
#   creating build/lib.linux-x86_64-3.6/obspy/clients/earthworm/tests
#   copying obspy/clients/earthworm/tests/test_client.py -> build/lib.linux-x86_64-3.6/obspy/clients/earthworm/tests
#   copying obspy/clients/earthworm/tests/__init__.py -> build/lib.linux-x86_64-3.6/obspy/clients/earthworm/tests
#   creating build/lib.linux-x86_64-3.6/obspy/clients/seedlink
#   copying obspy/clients/seedlink/basic_client.py -> build/lib.linux-x86_64-3.6/obspy/clients/seedlink
#   copying obspy/clients/seedlink/seedlinkexception.py -> build/lib.linux-x86_64-3.6/obspy/clients/seedlink
#   copying obspy/clients/seedlink/slpacket.py -> build/lib.linux-x86_64-3.6/obspy/clients/seedlink
#   copying obspy/clients/seedlink/slclient.py -> build/lib.linux-x86_64-3.6/obspy/clients/seedlink
#   copying obspy/clients/seedlink/easyseedlink.py -> build/lib.linux-x86_64-3.6/obspy/clients/seedlink
#   copying obspy/clients/seedlink/__init__.py -> build/lib.linux-x86_64-3.6/obspy/clients/seedlink
#   creating build/lib.linux-x86_64-3.6/obspy/clients/seedlink/tests
#   copying obspy/clients/seedlink/tests/test_slclient.py -> build/lib.linux-x86_64-3.6/obspy/clients/seedlink/tests
#   copying obspy/clients/seedlink/tests/test_slpacket.py -> build/lib.linux-x86_64-3.6/obspy/clients/seedlink/tests
#   copying obspy/clients/seedlink/tests/test_seedlinkconnection.py -> build/lib.linux-x86_64-3.6/obspy/clients/seedlink/tests
#   copying obspy/clients/seedlink/tests/test_slstate.py -> build/lib.linux-x86_64-3.6/obspy/clients/seedlink/tests
#   copying obspy/clients/seedlink/tests/example_SL_RTTrace.py -> build/lib.linux-x86_64-3.6/obspy/clients/seedlink/tests
#   copying obspy/clients/seedlink/tests/test_basic_client.py -> build/lib.linux-x86_64-3.6/obspy/clients/seedlink/tests
#   copying obspy/clients/seedlink/tests/example_SL_Hello.py -> build/lib.linux-x86_64-3.6/obspy/clients/seedlink/tests
#   copying obspy/clients/seedlink/tests/test_slnetstation.py -> build/lib.linux-x86_64-3.6/obspy/clients/seedlink/tests
#   copying obspy/clients/seedlink/tests/__init__.py -> build/lib.linux-x86_64-3.6/obspy/clients/seedlink/tests
#   creating build/lib.linux-x86_64-3.6/obspy/clients/seedlink/client
#   copying obspy/clients/seedlink/client/slstate.py -> build/lib.linux-x86_64-3.6/obspy/clients/seedlink/client
#   copying obspy/clients/seedlink/client/seedlinkconnection.py -> build/lib.linux-x86_64-3.6/obspy/clients/seedlink/client
#   copying obspy/clients/seedlink/client/slnetstation.py -> build/lib.linux-x86_64-3.6/obspy/clients/seedlink/client
#   copying obspy/clients/seedlink/client/__init__.py -> build/lib.linux-x86_64-3.6/obspy/clients/seedlink/client
#   creating build/lib.linux-x86_64-3.6/obspy/clients/seishub
#   copying obspy/clients/seishub/client.py -> build/lib.linux-x86_64-3.6/obspy/clients/seishub
#   copying obspy/clients/seishub/__init__.py -> build/lib.linux-x86_64-3.6/obspy/clients/seishub
#   creating build/lib.linux-x86_64-3.6/obspy/clients/seishub/tests
#   copying obspy/clients/seishub/tests/test_client.py -> build/lib.linux-x86_64-3.6/obspy/clients/seishub/tests
#   copying obspy/clients/seishub/tests/__init__.py -> build/lib.linux-x86_64-3.6/obspy/clients/seishub/tests
#   creating build/lib.linux-x86_64-3.6/obspy/clients/neic
#   copying obspy/clients/neic/util.py -> build/lib.linux-x86_64-3.6/obspy/clients/neic
#   copying obspy/clients/neic/client.py -> build/lib.linux-x86_64-3.6/obspy/clients/neic
#   copying obspy/clients/neic/__init__.py -> build/lib.linux-x86_64-3.6/obspy/clients/neic
#   creating build/lib.linux-x86_64-3.6/obspy/clients/neic/tests
#   copying obspy/clients/neic/tests/test_client.py -> build/lib.linux-x86_64-3.6/obspy/clients/neic/tests
#   copying obspy/clients/neic/tests/__init__.py -> build/lib.linux-x86_64-3.6/obspy/clients/neic/tests
#   creating build/lib.linux-x86_64-3.6/obspy/clients/syngine
#   copying obspy/clients/syngine/client.py -> build/lib.linux-x86_64-3.6/obspy/clients/syngine
#   copying obspy/clients/syngine/__init__.py -> build/lib.linux-x86_64-3.6/obspy/clients/syngine
#   creating build/lib.linux-x86_64-3.6/obspy/clients/syngine/tests
#   copying obspy/clients/syngine/tests/test_client.py -> build/lib.linux-x86_64-3.6/obspy/clients/syngine/tests
#   copying obspy/clients/syngine/tests/__init__.py -> build/lib.linux-x86_64-3.6/obspy/clients/syngine/tests
#   creating build/lib.linux-x86_64-3.6/obspy/clients/fdsn
#   copying obspy/clients/fdsn/header.py -> build/lib.linux-x86_64-3.6/obspy/clients/fdsn
#   copying obspy/clients/fdsn/wadl_parser.py -> build/lib.linux-x86_64-3.6/obspy/clients/fdsn
#   copying obspy/clients/fdsn/client.py -> build/lib.linux-x86_64-3.6/obspy/clients/fdsn
#   copying obspy/clients/fdsn/__init__.py -> build/lib.linux-x86_64-3.6/obspy/clients/fdsn
#   creating build/lib.linux-x86_64-3.6/obspy/clients/fdsn/tests
#   copying obspy/clients/fdsn/tests/test_base_routing_client.py -> build/lib.linux-x86_64-3.6/obspy/clients/fdsn/tests
#   copying obspy/clients/fdsn/tests/test_wadl_parser.py -> build/lib.linux-x86_64-3.6/obspy/clients/fdsn/tests
#   copying obspy/clients/fdsn/tests/test_client.py -> build/lib.linux-x86_64-3.6/obspy/clients/fdsn/tests
#   copying obspy/clients/fdsn/tests/test_federator_routing_client.py -> build/lib.linux-x86_64-3.6/obspy/clients/fdsn/tests
#   copying obspy/clients/fdsn/tests/test_eidaws_routing_client.py -> build/lib.linux-x86_64-3.6/obspy/clients/fdsn/tests
#   copying obspy/clients/fdsn/tests/test_mass_downloader.py -> build/lib.linux-x86_64-3.6/obspy/clients/fdsn/tests
#   copying obspy/clients/fdsn/tests/__init__.py -> build/lib.linux-x86_64-3.6/obspy/clients/fdsn/tests
#   creating build/lib.linux-x86_64-3.6/obspy/clients/fdsn/routing
#   copying obspy/clients/fdsn/routing/routing_client.py -> build/lib.linux-x86_64-3.6/obspy/clients/fdsn/routing
#   copying obspy/clients/fdsn/routing/federator_routing_client.py -> build/lib.linux-x86_64-3.6/obspy/clients/fdsn/routing
#   copying obspy/clients/fdsn/routing/eidaws_routing_client.py -> build/lib.linux-x86_64-3.6/obspy/clients/fdsn/routing
#   copying obspy/clients/fdsn/routing/__init__.py -> build/lib.linux-x86_64-3.6/obspy/clients/fdsn/routing
#   creating build/lib.linux-x86_64-3.6/obspy/clients/fdsn/mass_downloader
#   copying obspy/clients/fdsn/mass_downloader/utils.py -> build/lib.linux-x86_64-3.6/obspy/clients/fdsn/mass_downloader
#   copying obspy/clients/fdsn/mass_downloader/download_helpers.py -> build/lib.linux-x86_64-3.6/obspy/clients/fdsn/mass_downloader
#   copying obspy/clients/fdsn/mass_downloader/domain.py -> build/lib.linux-x86_64-3.6/obspy/clients/fdsn/mass_downloader
#   copying obspy/clients/fdsn/mass_downloader/mass_downloader.py -> build/lib.linux-x86_64-3.6/obspy/clients/fdsn/mass_downloader
#   copying obspy/clients/fdsn/mass_downloader/restrictions.py -> build/lib.linux-x86_64-3.6/obspy/clients/fdsn/mass_downloader
#   copying obspy/clients/fdsn/mass_downloader/__init__.py -> build/lib.linux-x86_64-3.6/obspy/clients/fdsn/mass_downloader
# ...
#   copying obspy/io/xseed/blockette/blockette054.py -> build/lib.linux-x86_64-3.6/obspy/io/xseed/blockette
#   copying obspy/io/xseed/blockette/blockette031.py -> build/lib.linux-x86_64-3.6/obspy/io/xseed/blockette
#   copying obspy/io/xseed/blockette/blockette055.py -> build/lib.linux-x86_64-3.6/obspy/io/xseed/blockette
#   copying obspy/io/xseed/blockette/blockette032.py -> build/lib.linux-x86_64-3.6/obspy/io/xseed/blockette
#   copying obspy/io/xseed/blockette/blockette050.py -> build/lib.linux-x86_64-3.6/obspy/io/xseed/blockette
#   copying obspy/io/xseed/blockette/blockette.py -> build/lib.linux-x86_64-3.6/obspy/io/xseed/blockette
#   copying obspy/io/xseed/blockette/__init__.py -> build/lib.linux-x86_64-3.6/obspy/io/xseed/blockette
#   copying obspy/io/xseed/blockette/blockette062.py -> build/lib.linux-x86_64-3.6/obspy/io/xseed/blockette
#   creating build/lib.linux-x86_64-3.6/obspy/io/cnv
#   copying obspy/io/cnv/core.py -> build/lib.linux-x86_64-3.6/obspy/io/cnv
#   copying obspy/io/cnv/__init__.py -> build/lib.linux-x86_64-3.6/obspy/io/cnv
#   creating build/lib.linux-x86_64-3.6/obspy/io/cnv/tests
#   copying obspy/io/cnv/tests/test_core.py -> build/lib.linux-x86_64-3.6/obspy/io/cnv/tests
#   copying obspy/io/cnv/tests/__init__.py -> build/lib.linux-x86_64-3.6/obspy/io/cnv/tests
#   creating build/lib.linux-x86_64-3.6/obspy/io/dmx
#   copying obspy/io/dmx/core.py -> build/lib.linux-x86_64-3.6/obspy/io/dmx
#   copying obspy/io/dmx/__init__.py -> build/lib.linux-x86_64-3.6/obspy/io/dmx
#   creating build/lib.linux-x86_64-3.6/obspy/io/dmx/tests
#   copying obspy/io/dmx/tests/test_core.py -> build/lib.linux-x86_64-3.6/obspy/io/dmx/tests
#   copying obspy/io/dmx/tests/__init__.py -> build/lib.linux-x86_64-3.6/obspy/io/dmx/tests
#   creating build/lib.linux-x86_64-3.6/obspy/io/nied
#   copying obspy/io/nied/knet.py -> build/lib.linux-x86_64-3.6/obspy/io/nied
#   copying obspy/io/nied/fnetmt.py -> build/lib.linux-x86_64-3.6/obspy/io/nied
#   copying obspy/io/nied/util.py -> build/lib.linux-x86_64-3.6/obspy/io/nied
#   copying obspy/io/nied/__init__.py -> build/lib.linux-x86_64-3.6/obspy/io/nied
#   creating build/lib.linux-x86_64-3.6/obspy/io/nied/tests
#   copying obspy/io/nied/tests/test_knet_reading.py -> build/lib.linux-x86_64-3.6/obspy/io/nied/tests
#   copying obspy/io/nied/tests/test_fnetmt_reading.py -> build/lib.linux-x86_64-3.6/obspy/io/nied/tests
#   copying obspy/io/nied/tests/__init__.py -> build/lib.linux-x86_64-3.6/obspy/io/nied/tests
#   creating build/lib.linux-x86_64-3.6/obspy/io/seg2
#   copying obspy/io/seg2/header.py -> build/lib.linux-x86_64-3.6/obspy/io/seg2
#   copying obspy/io/seg2/seg2.py -> build/lib.linux-x86_64-3.6/obspy/io/seg2
#   copying obspy/io/seg2/__init__.py -> build/lib.linux-x86_64-3.6/obspy/io/seg2
#   creating build/lib.linux-x86_64-3.6/obspy/io/seg2/tests
#   copying obspy/io/seg2/tests/test_seg2.py -> build/lib.linux-x86_64-3.6/obspy/io/seg2/tests
#   copying obspy/io/seg2/tests/__init__.py -> build/lib.linux-x86_64-3.6/obspy/io/seg2/tests
#   creating build/lib.linux-x86_64-3.6/obspy/io/kinemetrics
#   copying obspy/io/kinemetrics/evt.py -> build/lib.linux-x86_64-3.6/obspy/io/kinemetrics
#   copying obspy/io/kinemetrics/core.py -> build/lib.linux-x86_64-3.6/obspy/io/kinemetrics
#   copying obspy/io/kinemetrics/evt_base.py -> build/lib.linux-x86_64-3.6/obspy/io/kinemetrics
#   copying obspy/io/kinemetrics/__init__.py -> build/lib.linux-x86_64-3.6/obspy/io/kinemetrics
#   creating build/lib.linux-x86_64-3.6/obspy/io/kinemetrics/tests
#   copying obspy/io/kinemetrics/tests/test_core.py -> build/lib.linux-x86_64-3.6/obspy/io/kinemetrics/tests
#   copying obspy/io/kinemetrics/tests/__init__.py -> build/lib.linux-x86_64-3.6/obspy/io/kinemetrics/tests
#   creating build/lib.linux-x86_64-3.6/obspy/io/json
#   copying obspy/io/json/core.py -> build/lib.linux-x86_64-3.6/obspy/io/json
#   copying obspy/io/json/default.py -> build/lib.linux-x86_64-3.6/obspy/io/json
#   copying obspy/io/json/__init__.py -> build/lib.linux-x86_64-3.6/obspy/io/json
#   creating build/lib.linux-x86_64-3.6/obspy/io/json/tests
#   copying obspy/io/json/tests/test_json.py -> build/lib.linux-x86_64-3.6/obspy/io/json/tests
#   copying obspy/io/json/tests/__init__.py -> build/lib.linux-x86_64-3.6/obspy/io/json/tests
#   creating build/lib.linux-x86_64-3.6/obspy/io/wav
#   copying obspy/io/wav/core.py -> build/lib.linux-x86_64-3.6/obspy/io/wav
#   copying obspy/io/wav/__init__.py -> build/lib.linux-x86_64-3.6/obspy/io/wav
#   creating build/lib.linux-x86_64-3.6/obspy/io/wav/tests
#   copying obspy/io/wav/tests/test_core.py -> build/lib.linux-x86_64-3.6/obspy/io/wav/tests
#   copying obspy/io/wav/tests/__init__.py -> build/lib.linux-x86_64-3.6/obspy/io/wav/tests
#   creating build/lib.linux-x86_64-3.6/obspy/io/mseed
#   copying obspy/io/mseed/msstruct.py -> build/lib.linux-x86_64-3.6/obspy/io/mseed
#   copying obspy/io/mseed/util.py -> build/lib.linux-x86_64-3.6/obspy/io/mseed
#   copying obspy/io/mseed/core.py -> build/lib.linux-x86_64-3.6/obspy/io/mseed
#   copying obspy/io/mseed/headers.py -> build/lib.linux-x86_64-3.6/obspy/io/mseed
#   copying obspy/io/mseed/__init__.py -> build/lib.linux-x86_64-3.6/obspy/io/mseed
#   creating build/lib.linux-x86_64-3.6/obspy/io/mseed/tests
#   copying obspy/io/mseed/tests/test_recordanalyzer.py -> build/lib.linux-x86_64-3.6/obspy/io/mseed/tests
#   copying obspy/io/mseed/tests/test_mseed_util.py -> build/lib.linux-x86_64-3.6/obspy/io/mseed/tests
#   copying obspy/io/mseed/tests/test_mseed_special_issues.py -> build/lib.linux-x86_64-3.6/obspy/io/mseed/tests
#   copying obspy/io/mseed/tests/test_mseed_reading_and_writing.py -> build/lib.linux-x86_64-3.6/obspy/io/mseed/tests
#   copying obspy/io/mseed/tests/__init__.py -> build/lib.linux-x86_64-3.6/obspy/io/mseed/tests
#   creating build/lib.linux-x86_64-3.6/obspy/io/mseed/scripts
#   copying obspy/io/mseed/scripts/recordanalyzer.py -> build/lib.linux-x86_64-3.6/obspy/io/mseed/scripts
#   copying obspy/io/mseed/scripts/__init__.py -> build/lib.linux-x86_64-3.6/obspy/io/mseed/scripts
#   creating build/lib.linux-x86_64-3.6/obspy/io/arclink
#   copying obspy/io/arclink/inventory.py -> build/lib.linux-x86_64-3.6/obspy/io/arclink
#   copying obspy/io/arclink/__init__.py -> build/lib.linux-x86_64-3.6/obspy/io/arclink
#   creating build/lib.linux-x86_64-3.6/obspy/io/arclink/tests
#   copying obspy/io/arclink/tests/test_inventory_xml.py -> build/lib.linux-x86_64-3.6/obspy/io/arclink/tests
#   copying obspy/io/arclink/tests/__init__.py -> build/lib.linux-x86_64-3.6/obspy/io/arclink/tests
#   creating build/lib.linux-x86_64-3.6/obspy/geodetics
#   copying obspy/geodetics/flinnengdahl.py -> build/lib.linux-x86_64-3.6/obspy/geodetics
#   copying obspy/geodetics/base.py -> build/lib.linux-x86_64-3.6/obspy/geodetics
#   copying obspy/geodetics/__init__.py -> build/lib.linux-x86_64-3.6/obspy/geodetics
#   creating build/lib.linux-x86_64-3.6/obspy/geodetics/tests
#   copying obspy/geodetics/tests/test_util_geodetics.py -> build/lib.linux-x86_64-3.6/obspy/geodetics/tests
#   copying obspy/geodetics/tests/test_util_flinnengdahl.py -> build/lib.linux-x86_64-3.6/obspy/geodetics/tests
#   copying obspy/geodetics/tests/__init__.py -> build/lib.linux-x86_64-3.6/obspy/geodetics/tests
#   creating build/lib.linux-x86_64-3.6/obspy/taup
#   copying obspy/taup/tau_model.py -> build/lib.linux-x86_64-3.6/obspy/taup
#   copying obspy/taup/utils.py -> build/lib.linux-x86_64-3.6/obspy/taup
#   copying obspy/taup/taup_path.py -> build/lib.linux-x86_64-3.6/obspy/taup
#   copying obspy/taup/taup_geo.py -> build/lib.linux-x86_64-3.6/obspy/taup
#   copying obspy/taup/helper_classes.py -> build/lib.linux-x86_64-3.6/obspy/taup
#   copying obspy/taup/c_wrappers.py -> build/lib.linux-x86_64-3.6/obspy/taup
#   copying obspy/taup/taup_create.py -> build/lib.linux-x86_64-3.6/obspy/taup
#   copying obspy/taup/velocity_layer.py -> build/lib.linux-x86_64-3.6/obspy/taup
#   copying obspy/taup/taup_pierce.py -> build/lib.linux-x86_64-3.6/obspy/taup
#   copying obspy/taup/tau.py -> build/lib.linux-x86_64-3.6/obspy/taup
#   copying obspy/taup/taup_time.py -> build/lib.linux-x86_64-3.6/obspy/taup
#   copying obspy/taup/tau_branch.py -> build/lib.linux-x86_64-3.6/obspy/taup
#   copying obspy/taup/velocity_model.py -> build/lib.linux-x86_64-3.6/obspy/taup
#   copying obspy/taup/ray_paths.py -> build/lib.linux-x86_64-3.6/obspy/taup
#   copying obspy/taup/slowness_model.py -> build/lib.linux-x86_64-3.6/obspy/taup
#   copying obspy/taup/slowness_layer.py -> build/lib.linux-x86_64-3.6/obspy/taup
#   copying obspy/taup/seismic_phase.py -> build/lib.linux-x86_64-3.6/obspy/taup
#   copying obspy/taup/__init__.py -> build/lib.linux-x86_64-3.6/obspy/taup
#   creating build/lib.linux-x86_64-3.6/obspy/taup/tests
#   copying obspy/taup/tests/test_plotting.py -> build/lib.linux-x86_64-3.6/obspy/taup/tests
#   copying obspy/taup/tests/test_taup_geo.py -> build/lib.linux-x86_64-3.6/obspy/taup/tests
#   copying obspy/taup/tests/test_misc.py -> build/lib.linux-x86_64-3.6/obspy/taup/tests
#   copying obspy/taup/tests/test_ray_paths.py -> build/lib.linux-x86_64-3.6/obspy/taup/tests
#   copying obspy/taup/tests/test_seismic_phase.py -> build/lib.linux-x86_64-3.6/obspy/taup/tests
#   copying obspy/taup/tests/test_slowness_model.py -> build/lib.linux-x86_64-3.6/obspy/taup/tests
#   copying obspy/taup/tests/test_split_model.py -> build/lib.linux-x86_64-3.6/obspy/taup/tests
#   copying obspy/taup/tests/test_velocity_model.py -> build/lib.linux-x86_64-3.6/obspy/taup/tests
#   copying obspy/taup/tests/test_tau.py -> build/lib.linux-x86_64-3.6/obspy/taup/tests
#   copying obspy/taup/tests/__init__.py -> build/lib.linux-x86_64-3.6/obspy/taup/tests
#   running build_ext
#   customize UnixCCompiler
#   C compiler: /azureml-envs/azureml_20c402732d5823ad8d6d590fb2eba6c0/bin/x86_64-conda_cos6-linux-gnu-cc -DNDEBUG -g -fwrapv -O3 -Wall -Wstrict-prototypes -march=nocona -mtune=haswell -ftree-vectorize -fPIC -fstack-protector-strong -fno-plt -O2 -ffunction-sections -pipe -isystem /azureml-envs/azureml_20c402732d5823ad8d6d590fb2eba6c0/include -DNDEBUG -D_FORTIFY_SOURCE=2 -O2 -isystem /azureml-envs/azureml_20c402732d5823ad8d6d590fb2eba6c0/include -fPIC
#
#   creating /tmp/tmpmsjpz_cg/tmp
#   creating /tmp/tmpmsjpz_cg/tmp/tmpmsjpz_cg
#   compile options: '-MMD -MF /tmp/tmpmsjpz_cg/file.c.d -c'
#   x86_64-conda_cos6-linux-gnu-cc: /tmp/tmpmsjpz_cg/file.c
#   customize UnixCCompiler using build_ext
#   building 'libgse2_Linux_64bit_py36' extension
#   compiling C sources
#   C compiler: /azureml-envs/azureml_20c402732d5823ad8d6d590fb2eba6c0/bin/x86_64-conda_cos6-linux-gnu-cc -DNDEBUG -g -fwrapv -O3 -Wall -Wstrict-prototypes -march=nocona -mtune=haswell -ftree-vectorize -fPIC -fstack-protector-strong -fno-plt -O2 -ffunction-sections -pipe -isystem /azureml-envs/azureml_20c402732d5823ad8d6d590fb2eba6c0/include -DNDEBUG -D_FORTIFY_SOURCE=2 -O2 -isystem /azureml-envs/azureml_20c402732d5823ad8d6d590fb2eba6c0/include -fPIC
#
#   creating build/temp.linux-x86_64-3.6/obspy
#   creating build/temp.linux-x86_64-3.6/obspy/io
#   creating build/temp.linux-x86_64-3.6/obspy/io/gse2
#   creating build/temp.linux-x86_64-3.6/obspy/io/gse2/src
#   creating build/temp.linux-x86_64-3.6/obspy/io/gse2/src/GSE_UTI
#   compile options: '-I/tmp/pip-build-env-j81uxmyz/overlay/lib/python3.6/site-packages/numpy/core/include -I/azureml-envs/azureml_20c402732d5823ad8d6d590fb2eba6c0/include/python3.6m -c'
#   x86_64-conda_cos6-linux-gnu-cc: obspy/io/gse2/src/GSE_UTI/gse_functions.c
#   gcc -pthread -shared -B /azureml-envs/azureml_20c402732d5823ad8d6d590fb2eba6c0/compiler_compat -L/azureml-envs/azureml_20c402732d5823ad8d6d590fb2eba6c0/lib -Wl,-rpath=/azureml-envs/azureml_20c402732d5823ad8d6d590fb2eba6c0/lib -Wl,--no-as-needed -Wl,--sysroot=/ -Wl,-O2 -Wl,--sort-common -Wl,--as-needed -Wl,-z,relro -Wl,-z,now -Wl,--disable-new-dtags -Wl,--gc-sections -Wl,-rpath,/azureml-envs/azureml_20c402732d5823ad8d6d590fb2eba6c0/lib -Wl,-rpath-link,/azureml-envs/azureml_20c402732d5823ad8d6d590fb2eba6c0/lib -L/azureml-envs/azureml_20c402732d5823ad8d6d590fb2eba6c0/lib -march=nocona -mtune=haswell -ftree-vectorize -fPIC -fstack-protector-strong -fno-plt -O2 -ffunction-sections -pipe -isystem /azureml-envs/azureml_20c402732d5823ad8d6d590fb2eba6c0/include -DNDEBUG -D_FORTIFY_SOURCE=2 -O2 -isystem /azureml-envs/azureml_20c402732d5823ad8d6d590fb2eba6c0/include build/temp.linux-x86_64-3.6/obspy/io/gse2/src/GSE_UTI/gse_functions.o -L/azureml-envs/azureml_20c402732d5823ad8d6d590fb2eba6c0/lib -lpython3.6m -o build/lib.linux-x86_64-3.6/obspy/lib/libgse2_Linux_64bit_py36.cpython-36m-x86_64-linux-gnu.so
#   gcc: error: unrecognized command line option ‘-fno-plt’
#   /azureml-envs/azureml_20c402732d5823ad8d6d590fb2eba6c0/lib/python3.6/distutils/dist.py:261: UserWarning: Unknown distribution option: 'features'
#     warnings.warn(msg)
#   /azureml-envs/azureml_20c402732d5823ad8d6d590fb2eba6c0/lib/python3.6/distutils/dist.py:261: UserWarning: Unknown distribution option: 'features'
#     warnings.warn(msg)
#   error: Command "gcc -pthread -shared -B /azureml-envs/azureml_20c402732d5823ad8d6d590fb2eba6c0/compiler_compat -L/azureml-envs/azureml_20c402732d5823ad8d6d590fb2eba6c0/lib -Wl,-rpath=/azureml-envs/azureml_20c402732d5823ad8d6d590fb2eba6c0/lib -Wl,--no-as-needed -Wl,--sysroot=/ -Wl,-O2 -Wl,--sort-common -Wl,--as-needed -Wl,-z,relro -Wl,-z,now -Wl,--disable-new-dtags -Wl,--gc-sections -Wl,-rpath,/azureml-envs/azureml_20c402732d5823ad8d6d590fb2eba6c0/lib -Wl,-rpath-link,/azureml-envs/azureml_20c402732d5823ad8d6d590fb2eba6c0/lib -L/azureml-envs/azureml_20c402732d5823ad8d6d590fb2eba6c0/lib -march=nocona -mtune=haswell -ftree-vectorize -fPIC -fstack-protector-strong -fno-plt -O2 -ffunction-sections -pipe -isystem /azureml-envs/azureml_20c402732d5823ad8d6d590fb2eba6c0/include -DNDEBUG -D_FORTIFY_SOURCE=2 -O2 -isystem /azureml-envs/azureml_20c402732d5823ad8d6d590fb2eba6c0/include build/temp.linux-x86_64-3.6/obspy/io/gse2/src/GSE_UTI/gse_functions.o -L/azureml-envs/azureml_20c402732d5823ad8d6d590fb2eba6c0/lib -lpython3.6m -o build/lib.linux-x86_64-3.6/obspy/lib/libgse2_Linux_64bit_py36.cpython-36m-x86_64-linux-gnu.so" failed with exit status 1
#   ----------------------------------------
#   ERROR: Failed building wheel for obspy
# ERROR: Could not build wheels for obspy which use PEP 517 and cannot be installed directly
#
#
# CondaEnvException: Pip failed
#
#
# The command '/bin/sh -c ldconfig /usr/local/cuda/lib64/stubs && conda env create -p /azureml-envs/azureml_20c402732d5823ad8d6d590fb2eba6c0 -f azureml-environment-setup/mutated_conda_dependencies.yml && rm -rf "$HOME/.cache/pip" && conda clean -aqy && CONDA_ROOT_DIR=$(conda info --root) && rm -rf "$CONDA_ROOT_DIR/pkgs" && find "$CONDA_ROOT_DIR" -type d -name __pycache__ -exec rm -rf {} + && ldconfig' returned a non-zero code: 1
# 2021/05/14 06:28:21 Container failed during run: acb_step_0. No retries remaining.
# failed to run step ID: acb_step_0: exit status 1
#
# Run ID: de3b failed after 6m17s. Error: failed during run, err: exit status 1
# Package creation Failed
# ---------------------------------------------------------------------------
# WebserviceException                       Traceback (most recent call last)
# <ipython-input-13-698bd8b9605c> in <module>
# ----> 1 package_service.wait_for_creation(show_output=True)
#
# ~\anaconda3\envs\conda2\lib\site-packages\azureml\core\model.py in wait_for_creation(self, show_output)
#    2730                 error_message = self.error
#    2731
# -> 2732             raise WebserviceException('Package creation reached non-successful terminal state.\n'
#    2733                                       'State: {}\n'
#    2734                                       'Error:\n'
#
# WebserviceException: WebserviceException:
# 	Message: Package creation reached non-successful terminal state.
# State: Failed
# Error:
# StatusCode: 400
# Message: Environment image build failed.
#
# 	InnerException None
# 	ErrorResponse
# {
#     "error": {
#         "message": "Package creation reached non-successful terminal state.\nState: Failed\nError:\nStatusCode: 400\nMessage: Environment image build failed.\n"
#     }
# }

# %%
print(package_service.state)
# Out:
# Succeeded

# %%
print(package_service.location)
# Out:
# lsmcdevmlwsfe4aa203.azurecr.io/mc-mlmodule@sha256:82815f39b4278e44ac9dfbea9ac3f145aa0111bf7879206bde0c7cec6190c207
