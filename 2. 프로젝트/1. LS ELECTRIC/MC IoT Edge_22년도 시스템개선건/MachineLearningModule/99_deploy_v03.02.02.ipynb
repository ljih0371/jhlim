# %% [markdown]
# ## 추가해야하는 내용

# %%
# Check core SDK version number
import azureml.core
import os

print("SDK version:", azureml.core.VERSION)
# Out:
# SDK version: 1.24.0

# %% [markdown]
# # 1. Azure ML Service 작업 영업에 연결

# %% [markdown]
# #### Notebook이 실행되는 경로 내 Azure ML Service Workspace 접속 정보를 가진 config 파일이 있어야한다.

# %% [markdown]
#  - 테스트 배포 시에는 'data/config_dev.json' 사용
#  - 실제 배포 시에는 'data/config.json' 사용

# %%
from azureml.core.authentication import InteractiveLoginAuthentication

interactive_auth = InteractiveLoginAuthentication(tenant_id="c8b9cf2c-f80b-4c36-912f-74979c640070")

ws = Workspace(subscription_id="1f154107-bef0-481f-a741-68e7ba34affe",
               resource_group="lsmc-prd-rg",
               workspace_name="lsmc-dev-mlws",
               auth=interactive_auth)
# Out:
# Performing interactive authentication. Please follow the instructions on the terminal.
# Note, we have launched a browser for you to login. For old experience with device code, use "az login --use-device-code"
# You have logged in. Now let us find all the subscriptions to which you have access...
# Interactive authentication successfully completed.

# %%
from azureml.core import Workspace

ws = Workspace.from_config('deployment/config/config_dev.json')
print('기계학습이름:'+ws.name, '리소스그룹이름:'+ws.resource_group, '리전이름:'+ws.location, '구독ID:'+ws.subscription_id, sep = '\n')
# Out:
# 기계학습이름:lsmc-dev-mlws
# 리소스그룹이름:lsmc-prd-rg
# 리전이름:koreacentral
# 구독ID:1f154107-bef0-481f-a741-68e7ba34affe

# %% [markdown]
# # 2. 모델 등록

# %% [markdown]
# #### 등록할 모델의 버전을 명시해준다.

# %%
model_version = "03_050_02"
file_name = '{}.pickle'.format(model_version)
print(file_name)
# Out:
# 03_050_02.pickle

# %% [markdown]
# ## Description 수정해아함!!!

# %% [markdown]
# #### 모델을 등록해준다. description에 현재 모델에 대한 간단한 설명을 추가할 수 있다.

# %% [markdown]
#  - 실행하면, [Azure Portal > 기계 학습 > 기계학습이름(위에서 확인) > 모델] 에서 확인 가능함

# %%
from azureml.core.model import Model

#library_version = "DL"+sklearn.__version__.replace(".","x")
model = Model.register(model_path = "deployment/data/pkl/{}".format(file_name),
                       model_name = model_version,
                       tags = {'area': "IoT Edge", 'type': "azureml-automl"},
                       description = "AzureML SDK upgrade & Model upgrade",
                       workspace = ws)
# Out:
# Registering model 03_050_02

# %% [markdown]
# # 3. 이미지 등록

# %% [markdown]
# #### 등록 된 모델 이름을 사용 하 여 모델 파일에 대 한 경로를 반환

# %%
from azureml.core.model import Model
model = Model.get_model_path(model_version, _workspace=ws)
model
# Out:
# 'azureml-models\\03_050_02\\9\\03_050_02.pickle'

# %% [markdown]
# #### 사용되는 package 선언. Edge 환경에서 해당 package를 사용되기 때문에 channel 과 필요한 package명을 선언 해주어야 한다.

# %%
pip_packages = ["azureml-defaults",
                "azureml==0.2.7",
                "azureml-core==1.24.0",
                "azureml-sdk==1.24.0",
                "azureml-automl-core==1.24.0",
                "azureml-automl-runtime==1.24.0",
                "azure-storage-blob==12.6.0",
                "numpy==1.18.5",
                "pandas==0.25.3",
                "sqlalchemy==1.3.21",
                "h5py==2.10.0",
                "tqdm==4.54.0",
                "obspy==1.2.2",
                "mysql-connector-python==8.0.18",
                "joblib==0.14.1",
                "packaging==20.7",
                "xgboost==0.90",
                "noisereduce==1.1.0"]

lib_config_load = ['pyyaml']
lib_clfs = ["gxx_linux-64",
            "gcc_linux-64",
            "librosa==0.8.0"]
#lib_clfs = ['tensorflow==1.1']
conda_packages = lib_clfs + lib_config_load

print('pip packages:', pip_packages)
print('conda packasges:', conda_packages)
# Out:
# pip packages: ['azureml-defaults', 'azureml==0.2.7', 'azureml-core==1.24.0', 'azureml-sdk==1.24.0', 'azureml-automl-core==1.24.0', 'azureml-automl-runtime==1.24.0', 'azure-storage-blob==12.6.0', 'numpy==1.18.5', 'pandas==0.25.3', 'sqlalchemy==1.3.21', 'h5py==2.10.0', 'tqdm==4.54.0', 'obspy==1.2.2', 'mysql-connector-python==8.0.18', 'joblib==0.14.1', 'packaging==20.7', 'xgboost==0.90', 'noisereduce==1.1.0']
# conda packasges: ['gxx_linux-64', 'gcc_linux-64', 'librosa==0.8.0', 'pyyaml']

# %%
from azureml.core.conda_dependencies import CondaDependencies 
from azureml.core import Environment

conda_deps  = CondaDependencies.create(conda_packages=conda_packages, pip_packages=pip_packages)
conda_deps.add_channel('conda-forge')
conda_deps.add_channel('defaults')

myenv = Environment(name='myenv')
myenv.python.conda_dependencies = conda_deps
myenv.docker.base_image = 'mcr.microsoft.com/azureml/base:intelmpi2018.3-ubuntu16.04'
# myenv.docker.base_image = 'mcr.microsoft.com/azureml/base:openmpi3.1.2-ubuntu18.04'


# with open("data/myenv.yml","w") as f:
#     f.write(myenv.serialize_to_string())

# %% [markdown]
# # 4. score_iot.py 파일(전처리 및 ML 판정 수행 로직 실행 스크립트) 생성

# %% [markdown]
#  ### 아래 cell 이 실행되면 score_iot.py에 실행 스크립트가 생성됨

# %% [markdown]
# ### score_iot_test.ipynb에 해당 스크립트의 내용을 복사하여, 실행 시 에러가 발생하지 않는지 꼭 확인!

# %%
import _locale
_locale._getdefaultlocale = (lambda *args: ['en_US', 'utf8'])

# %%
# %%writefile src/score_iot.py


# For Edge
import json
import yaml
import time
import os
import re
import pickle
import shutil
from datetime import datetime
from datetime import timedelta
from time import sleep
from azureml.core.model import Model

# For Clf
import h5py
import pandas as pd
from classify import Classifier
from preprocess_signal_data import Run_
from pkgs.pipelines import FeatureDeployed as Featurizing
from pkgs.utils import read_json


def init_preprocessor(feature_params, Featurizing, test_no, input_type="ReadData"):
    # set preprocess class
    preproc = Run_(
        feature_params=feature_params, Featurizing=Featurizing, test_no=test_no
    )
    if input_type == "ReadData":
        preproc.pl.steps = [
            (step_name, step)
            for step_name, step in preproc.pl.steps
            if step.name != "ReadData"
        ]

    return preproc


def score(
    preproc,
    input_values,
    feature_names,
    column_names,
    cut_off,
    rule_model_params,
    mode,
    input_name="ReadData",
    parallel=1,
    verbose=0,
):
    # Preprocess
    df = preproc.pl.run(
        input_name=input_name,
        input_values=[input_values],
        feature_names=feature_names,
        parallel=parallel,
        verbose=verbose,
    )
    df = pd.DataFrame(df[0])
    df["TEST_NO"] = [0,1,2]
    df_features = df[column_names]

    # Predict
    df["PROB"] = loaded_model.predict_proba(df_features)[:,1]
    
    # Classify
    df["ML_R"] = df.PROB >= cut_off
    df["ML_R"] = df.ML_R.astype(int)
    df = Classifier.classify_all(
        df=df[df.TEST_NO.isin(preproc.featurizer.params["test_no"])],
        rule_cutoffs=rule_model_params,
        mode=mode,
    )
    return df, df_features


def init():
    global preproc, loaded_model, model_version, column_names, line, cut_off, rule_model_params, ml_model_params, model_path, error_dir
    # 수정필요  --------------------------------------------------------
    model_version = "03_050_02"  # model_name 입력
    file_name = "{}.pickle".format(model_version)
    edge_config = "/home/data/edge_config.yml"
#     file_name = "deployment/data/pkl/{}.pickle".format(model_version)
#     edge_config = "deployment/config/edge_config.yml"
    feature_params = read_json("src/config/featureD050_parameters.json")
    column_names = read_json("src/config/model_03_050_02_features.json")["feature_names"]
    # ----------------------------------------------------------------

    # load line info
    with open(edge_config, "r") as stream:
        try:
            edge_config = yaml.load(stream, Loader=yaml.BaseLoader)
            line = edge_config["config"]["line"]["name"]
            cut_off = float(edge_config["config"]["param"]["cutoff"])
            rule_model_params = edge_config["config"]["param"]["rule_model"]
            ml_model_params = edge_config["config"]["param"]["ml_model"]

        except yaml.YAMLError as exc:
            print("line config error: ", exc)

    # set preprocess class
    for param_, dic_ in ml_model_params.items():
        for key_, value_ in dic_.items():
            feature_params[param_][key_] = float(value_)
    preproc = init_preprocessor(
        feature_params=feature_params, Featurizing=Featurizing, test_no=[0, 1, 2]
    )

    # load model
    model_path = Model.get_model_path(file_name)
    with open(model_path, "rb") as f:
        loaded_model = pickle.load(f)
    
    error_dir = "/home/data/error_file/"
    try:
        os.makedirs(error_dir, mode=777)
    except:
        pass


def run(input_json):
    print("\n", "mlmodule start")
    print("\n", datetime.now() + timedelta(hours=9), "\n")
    # for test#
    input_json = json.loads(input_json)
    print("\n", "json loaded", "\n")
    print(input_json, "\n")
    mltime = datetime.now() + timedelta(hours=9)
    chtime = input_json["chtime"]
    print("chtime : ", chtime)
    ct = datetime.strptime(
        chtime.replace("T", " ").split("+")[0][:-1], "%Y-%m-%d %H:%M:%S.%f"
    )
    diff = mltime - ct
    input_json["chtime"] = str(ct)
    input_json["mltime"] = str(mltime)
    input_json["etime_ch"] = diff.seconds + diff.microseconds / 1e6

    # file load
    init_time = time.time()
    # input_json = json.loads(input_json)
    input_path = input_json["path"]
    print("\n", input_path)

    for attempt in range(3):
        try:
#             input_raw = pr.ReadDataBlob(input_path)
            print("Attempt: " + str(attempt + 1) + "  Time: " + str(datetime.now()))
            with h5py.File(input_path, "r") as f:
                tmp = f["Raw"][:]
            input_raw = pd.DataFrame(tmp, columns=[0, 1, 2])
            print("\n", "hdf loaded")

        except Exception as ex:
            if attempt == 2:
                ex_message = str(ex)

            sleep(0.02)
            continue

        break

    else:
        input_json["b"] = 2
        input_json["prob"] = 2
        input_json["error"] = ex_message
        input_json["etime"] = time.time() - init_time

        result_json = [json.dumps(input_json)]
        print("*" * 5, " ", "LOAD ERROR", " ", "*" * 5)
        print(result_json)
        try:
            shutil.copy(input_path, error_dir)
        except:
            pass

    # for test#
    # diff = (datetime.now()+ timedelta(hours=9))-mltime
    # input_json['etime_load'] = diff.seconds + diff.microseconds/1E6
    input_json["etime_load"] = time.time() - init_time

    ### json insert
    input_json["cutoff"] = cut_off
    input_json["TRHD_NM_SET"] = "/".join([key for key in rule_model_params.keys()] + [f"{key_}-{param}" for key_, dict_ in ml_model_params.items() for param, value in dict_.items()])
    input_json["TRHD_VAL_SET"] = "/".join(
        [str(value) for value in rule_model_params.values()]+[str(value) for key_, dict_ in ml_model_params.items() for param, value in dict_.items()]
    )
    input_json["FTUR_NM_SET"] = "/".join(
        [
            "/".join([col + "_TEST_N1" for col in column_names]),
            "/".join([col + "_TEST_N2" for col in column_names]),
            "/".join([col + "_TEST_N3" for col in column_names]),
        ]
    )
    input_json["lid"] = line
    input_json["v"] = model_version

    try:
        filename = input_path.split("/")[-1]
        filename = filename.strip("Data\\").split("_")
        input_json["bc"] = "_".join(filename[0:2])
        input_json["dtfull"] = filename[2][:-3]

    except Exception as ex:  # 에러 종류
        input_json["bc"] = "ERROR"
        input_json["dtfull"] = str(datetime.now())
        input_json["r"] = 2
        input_json["prob"] = 2
        input_json["error"] = str(ex)
        input_json["etime"] = time.time() - init_time

        result_json = [json.dumps(input_json)]
        print("*" * 5, " ", "FILENAME ERROR", " ", "*" * 5)
        print(result_json)
        try:
            cmd = "cp " + input_json["path"] + " " + error_dir
            os.system(cmd)
        except:
            pass

    try:
        df, df_features = score(
            preproc=preproc,
            input_values=input_raw,
            feature_names=preproc.featurizer.params["feature_names"],
            column_names=column_names,
            cut_off=cut_off,
            rule_model_params=rule_model_params,
            mode="or",
            input_name="ReadData",
            parallel=1,
            verbose=0,
        )
        
        input_json["r"] = int(df.R.values[0])
        input_json["prob"] = float(df.PROB.values[0])
        input_json["error"] = str(df.TEST_NG_R.values[0])
        input_json["etime"] = time.time() - init_time
        input_json["FTUR_VAL_SET"] = "/".join(
            [str(value) for value in df_features.values.flatten()]
        )

        result_json = [json.dumps(input_json)]
        print(result_json)

    except Exception as ex:  # 에러 종류
        input_json["r"] = 2
        input_json["prob"] = 2
        input_json["error"] = str(ex)
        input_json["etime"] = time.time() - init_time
        input_json["FTUR_VAL_SET"] = ""

        result_json = [json.dumps(input_json)]
        print("*" * 5, " ", "ERROR", " ", "*" * 5)
        print(result_json)
        try:
            cmd = "cp " + input_json["path"] + " " + error_dir
            os.system(cmd)
        except:
            pass

    return result_json
# Out:
# Overwriting src/score_iot.py

# %%
import os
os.getcwd()
# Out:
# 'C:\\Users\\Nam\\Documents\\Jupyter Test\\ML Module Test'

# %% [markdown]
# # 5. Azure MLWS에 이미지 업로드

# %%
from azureml.core.model import InferenceConfig

inference_config = InferenceConfig(entry_script="score_iot.py", environment=myenv, source_directory="src")
package_service = Model.package(workspace=ws,
                                models=[model],
                                image_name="mc-mlmodule",
                                image_label=17,
                                inference_config=inference_config)
# Out:
# ModelNotFound: Model with id azureml-models\03_050_02\9\03_050_02.pickle not found in provided workspace
# Registering model 03_050_02.pickle

# %%
package_service.wait_for_creation(show_output=True)
# Out:
# 2021/03/23 06:04:30 Downloading source code...
# 2021/03/23 06:04:32 Finished downloading source code
# 2021/03/23 06:04:32 Creating Docker network: acb_default_network, driver: 'bridge'
# 2021/03/23 06:04:33 Successfully set up Docker network: acb_default_network
# 2021/03/23 06:04:33 Setting up Docker configuration...
# 2021/03/23 06:04:34 Successfully set up Docker configuration
# 2021/03/23 06:04:34 Logging in to registry: lsmcdevmlwsfe4aa203.azurecr.io
# 2021/03/23 06:04:35 Successfully logged into lsmcdevmlwsfe4aa203.azurecr.io
# 2021/03/23 06:04:35 Executing step ID: acb_step_0. Timeout(sec): 5400, Working directory: '', Network: 'acb_default_network'
# 2021/03/23 06:04:35 Scanning for dependencies...
# 2021/03/23 06:04:35 Successfully scanned dependencies
# 2021/03/23 06:04:35 Launching container with name: acb_step_0
# Sending build context to Docker daemon  67.07kB
# Step 1/18 : FROM mcr.microsoft.com/azureml/base:intelmpi2018.3-ubuntu16.04@sha256:a1b514f3ba884b9a7695cbba5638933ddaf222e8ce3e8c81e8cdf861679abb05
# sha256:a1b514f3ba884b9a7695cbba5638933ddaf222e8ce3e8c81e8cdf861679abb05: Pulling from azureml/base
# a1298f4ce990: Pulling fs layer
# 04a3282d9c4b: Pulling fs layer
# 9b0d3db6dc03: Pulling fs layer
# 8269c605f3f1: Pulling fs layer
# 6504d449e70c: Pulling fs layer
# 4e38f320d0d4: Pulling fs layer
# b0a763e8ee03: Pulling fs layer
# 11917a028ca4: Pulling fs layer
# a6c378d11cbf: Pulling fs layer
# 6cc007ad9140: Pulling fs layer
# 6c1698a608f3: Pulling fs layer
# b0a763e8ee03: Waiting
# 8269c605f3f1: Waiting
# 11917a028ca4: Waiting
# 6504d449e70c: Waiting
# 4e38f320d0d4: Waiting
# a6c378d11cbf: Waiting
# 6cc007ad9140: Waiting
# 6c1698a608f3: Waiting
# 04a3282d9c4b: Verifying Checksum
# 04a3282d9c4b: Download complete
# 9b0d3db6dc03: Download complete
# 8269c605f3f1: Verifying Checksum
# 8269c605f3f1: Download complete
# a1298f4ce990: Verifying Checksum
# a1298f4ce990: Download complete
# 4e38f320d0d4: Verifying Checksum
# 4e38f320d0d4: Download complete
# b0a763e8ee03: Verifying Checksum
# b0a763e8ee03: Download complete
# 6504d449e70c: Verifying Checksum
# 6504d449e70c: Download complete
# 11917a028ca4: Verifying Checksum
# 11917a028ca4: Download complete
# 6cc007ad9140: Verifying Checksum
# 6cc007ad9140: Download complete
# a1298f4ce990: Pull complete
# 6c1698a608f3: Download complete
# 04a3282d9c4b: Pull complete
# 9b0d3db6dc03: Pull complete
# 8269c605f3f1: Pull complete
# a6c378d11cbf: Verifying Checksum
# a6c378d11cbf: Download complete
# 6504d449e70c: Pull complete
# 4e38f320d0d4: Pull complete
# b0a763e8ee03: Pull complete
# 11917a028ca4: Pull complete
# a6c378d11cbf: Pull complete
# 6cc007ad9140: Pull complete
# 6c1698a608f3: Pull complete
# Digest: sha256:a1b514f3ba884b9a7695cbba5638933ddaf222e8ce3e8c81e8cdf861679abb05
# Status: Downloaded newer image for mcr.microsoft.com/azureml/base:intelmpi2018.3-ubuntu16.04@sha256:a1b514f3ba884b9a7695cbba5638933ddaf222e8ce3e8c81e8cdf861679abb05
#  ---> 93a72e6bd1ce
# Step 2/18 : USER root
#  ---> Running in 51b76dfb4bb0
# Removing intermediate container 51b76dfb4bb0
#  ---> b6b5d7cf819a
# Step 3/18 : RUN mkdir -p $HOME/.cache
#  ---> Running in 3bc2f2cab02f
# Removing intermediate container 3bc2f2cab02f
#  ---> b80dd3227841
# Step 4/18 : WORKDIR /
#  ---> Running in e1755c170890
# Removing intermediate container e1755c170890
#  ---> 0110b6abad24
# Step 5/18 : COPY azureml-environment-setup/99brokenproxy /etc/apt/apt.conf.d/
#  ---> c730178477af
# Step 6/18 : RUN if dpkg --compare-versions `conda --version | grep -oE '[^ ]+$'` lt 4.4.11; then conda install conda==4.4.11; fi
#  ---> Running in de11944e43a4
# Removing intermediate container de11944e43a4
#  ---> 2379b755533d
# Step 7/18 : COPY azureml-environment-setup/mutated_conda_dependencies.yml azureml-environment-setup/mutated_conda_dependencies.yml
#  ---> a71b5968752f
# Step 8/18 : RUN ldconfig /usr/local/cuda/lib64/stubs && conda env create -p /azureml-envs/azureml_882aeb18bd4696f212b5c79bda0dd217 -f azureml-environment-setup/mutated_conda_dependencies.yml && rm -rf "$HOME/.cache/pip" && conda clean -aqy && CONDA_ROOT_DIR=$(conda info --root) && rm -rf "$CONDA_ROOT_DIR/pkgs" && find "$CONDA_ROOT_DIR" -type d -name __pycache__ -exec rm -rf {} + && ldconfig
#  ---> Running in 2cbd1368dc90
# Solving environment: ...working...
# done
#
#
# ==> WARNING: A newer version of conda exists. <==
#   current version: 4.5.11
#   latest version: 4.9.2
#
# Please update conda by running
#
#     $ conda update -n base -c defaults conda
#
#
# joblib-0.17.0        | 205 KB    | ########## | 100%
# lame-3.100           | 502 KB    | ########## | 100%
# libvpx-1.7.0         | 2.4 MB    | ########## | 100%
# ca-certificates-2020 | 128 KB    | ########## | 100%
# gettext-0.19.8.1     | 3.7 MB    | ########## | 100%
# resampy-0.2.2        | 332 KB    | ########## | 100%
# kiwisolver-1.2.0     | 91 KB     | ########## | 100%
# gmp-6.1.2            | 744 KB    | ########## | 100%
# cryptography-2.3.1   | 585 KB    | ########## | 100%
# pyparsing-2.4.7      | 64 KB     | ########## | 100%
# ffmpeg-4.2.2         | 80.5 MB   | ########## | 100%
# matplotlib-base-3.2. | 7.2 MB    | ########## | 100%
# gcc_impl_linux-64-7. | 70.6 MB   | #########7 |  97%
# gcc_impl_linux-64-7. | 70.6 MB   | ########## | 100%
# mkl-service-2.3.0    | 208 KB    | ########## | 100%
# binutils_linux-64-2. | 24 KB     | ########## | 100%
# libgfortran-ng-7.3.0 | 1.3 MB    | ########## | 100%
# tk-8.6.10            | 3.2 MB    | ########## | 100%
# numpy-1.19.1         | 20 KB     | ########## | 100%
# packaging-20.4       | 35 KB     | ########## | 100%
# yaml-0.2.5           | 87 KB     | ########## | 100%
# intel-openmp-2020.2  | 947 KB    | ########## | 100%
# pooch-1.3.0          | 40 KB     | ########## | 100%
# gcc_linux-64-7.3.0   | 25 KB     | ########## | 100%
# pysocks-1.7.1        | 30 KB     | ########## | 100%
# pyopenssl-19.0.0     | 82 KB     | ########## | 100%
# brotlipy-0.7.0       | 348 KB    | ########## | 100%
# scipy-1.5.2          | 18.5 MB   | ########## | 100%
# numpy-base-1.19.1    | 5.2 MB    | ########## | 100%
# gxx_linux-64-7.3.0   | 25 KB     | ########## | 100%
# idna-2.10            | 56 KB     | ########## | 100%
# mkl_random-1.1.0     | 369 KB    | ########## | 100%
# setuptools-50.3.0    | 891 KB    | ########## | 100%
# zlib-1.2.11          | 120 KB    | ########## | 100%
# libopus-1.3.1        | 570 KB    | ########## | 100%
# python-dateutil-2.8. | 224 KB    | ########## | 100%
# llvmlite-0.34.0      | 319 KB    | ########## | 100%
# libedit-3.1          | 171 KB    | ########## | 100%
# gxx_impl_linux-64-7. | 19.1 MB   | ########## | 100%
# ld_impl_linux-64-2.3 | 645 KB    | ########## | 100%
# ncurses-6.0          | 907 KB    | ########## | 100%
# certifi-2020.6.20    | 160 KB    | ########## | 100%
# wheel-0.35.1         | 36 KB     | ########## | 100%
# icu-58.2             | 22.7 MB   | ########## | 100%
# xz-5.2.5             | 438 KB    | ########## | 100%
# scikit-learn-0.23.2  | 6.9 MB    | ########## | 100%
# x264-1!157.20191217  | 2.5 MB    | ########## | 100%
# cycler-0.10.0        | 13 KB     | ########## | 100%
# mkl-2019.4           | 204.1 MB  | ########4  |  84%
# mkl-2019.4           | 204.1 MB  | #########  |  91%
# mkl-2019.4           | 204.1 MB  | #########7 |  97%
# mkl-2019.4           | 204.1 MB  | ########## | 100%
# mkl_fft-1.2.0        | 164 KB    | ########## | 100%
# python_abi-3.6       | 4 KB      | ########## | 100%
# blas-1.0             | 6 KB      | ########## | 100%
# decorator-4.4.2      | 14 KB     | ########## | 100%
# audioread-2.1.9      | 32 KB     | ########## | 100%
# numba-0.51.2         | 3.7 MB    | ########## | 100%
# asn1crypto-1.4.0     | 77 KB     | ########## | 100%
# nettle-3.4.1         | 6.7 MB    | ########## | 100%
# pyyaml-5.3.1         | 191 KB    | ########## | 100%
# sqlite-3.23.1        | 1.5 MB    | ########## | 100%
# pip-20.2.4           | 2.0 MB    | ########## | 100%
# libstdcxx-ng-9.1.0   | 4.0 MB    | ########## | 100%
# bzip2-1.0.8          | 105 KB    | ########## | 100%
# six-1.15.0           | 13 KB     | ########## | 100%
# libgcc-ng-9.1.0      | 8.1 MB    | ########## | 100%
# threadpoolctl-2.1.0  | 16 KB     | ########## | 100%
# libllvm10-10.0.1     | 26.5 MB   | ########## | 100%
# requests-2.24.0      | 54 KB     | ########## | 100%
# gnutls-3.6.5         | 1.9 MB    | ########## | 100%
# libogg-1.3.2         | 205 KB    | ########## | 100%
# appdirs-1.4.4        | 13 KB     | ########## | 100%
# libvorbis-1.3.7      | 549 KB    | ########## | 100%
# libflac-1.3.3        | 517 KB    | ########## | 100%
# openssl-1.0.2u       | 3.1 MB    | ########## | 100%
# openh264-2.1.0       | 1.5 MB    | ########## | 100%
# librosa-0.8.0        | 145 KB    | ########## | 100%
# freetype-2.10.4      | 901 KB    | ########## | 100%
# libpng-1.6.37        | 364 KB    | ########## | 100%
# pysoundfile-0.10.3.p | 23 KB     | ########## | 100%
# libffi-3.2.1         | 52 KB     | ########## | 100%
# readline-7.0         | 387 KB    | ########## | 100%
# tornado-6.0.4        | 650 KB    | ########## | 100%
# urllib3-1.25.11      | 93 KB     | ########## | 100%
# cffi-1.14.0          | 225 KB    | ########## | 100%
# libsndfile-1.0.29    | 534 KB    | ########## | 100%
# chardet-3.0.4        | 197 KB    | ########## | 100%
# pycparser-2.20       | 94 KB     | ########## | 100%
# binutils_impl_linux- | 8.6 MB    | ########## | 100%
# python-3.6.2         | 27.0 MB   | ########## | 100%
# Downloading and Extracting Packages
# Preparing transaction: ...working... done
# Verifying transaction: ...working...
# done
# Executing transaction: ...working...
# done
# Collecting azureml-defaults
#   Downloading azureml_defaults-1.24.0-py3-none-any.whl (3.1 kB)
# Collecting azureml==0.2.7
#   Downloading azureml-0.2.7-py2.py3-none-any.whl (23 kB)
# Collecting azureml-core==1.24.0
#   Downloading azureml_core-1.24.0-py3-none-any.whl (2.2 MB)
# Collecting azureml-sdk==1.24.0
#   Downloading azureml_sdk-1.24.0-py3-none-any.whl (4.4 kB)
# Collecting azureml-automl-core==1.24.0
#   Downloading azureml_automl_core-1.24.0-py3-none-any.whl (195 kB)
# Collecting azureml-automl-runtime==1.24.0
#   Downloading azureml_automl_runtime-1.24.0-py3-none-any.whl (2.0 MB)
# Collecting azure-storage-blob==12.6.0
#   Downloading azure_storage_blob-12.6.0-py2.py3-none-any.whl (328 kB)
# Collecting numpy==1.18.5
#   Downloading numpy-1.18.5-cp36-cp36m-manylinux1_x86_64.whl (20.1 MB)
# Collecting pandas==0.25.3
#   Downloading pandas-0.25.3-cp36-cp36m-manylinux1_x86_64.whl (10.4 MB)
# Collecting sqlalchemy==1.3.21
#   Downloading SQLAlchemy-1.3.21-cp36-cp36m-manylinux2010_x86_64.whl (1.3 MB)
# Collecting h5py==2.10.0
#   Downloading h5py-2.10.0-cp36-cp36m-manylinux1_x86_64.whl (2.9 MB)
# Collecting tqdm==4.54.0
#   Downloading tqdm-4.54.0-py2.py3-none-any.whl (69 kB)
# Collecting obspy==1.2.2
#   Downloading obspy-1.2.2.zip (24.7 MB)
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: finished with status 'done'
#   Installing backend dependencies: started
#   Installing backend dependencies: finished with status 'done'
#     Preparing wheel metadata: started
#     Preparing wheel metadata: finished with status 'done'
# Collecting mysql-connector-python==8.0.18
#   Downloading mysql_connector_python-8.0.18-cp36-cp36m-manylinux1_x86_64.whl (16.1 MB)
# Collecting joblib==0.14.1
#   Downloading joblib-0.14.1-py2.py3-none-any.whl (294 kB)
# Collecting packaging==20.7
#   Downloading packaging-20.7-py2.py3-none-any.whl (35 kB)
# Collecting xgboost==0.90
#   Downloading xgboost-0.90-py2.py3-none-manylinux1_x86_64.whl (142.8 MB)
# Collecting noisereduce==1.1.0
#   Downloading noisereduce-1.1.0.tar.gz (6.3 kB)
# Collecting applicationinsights>=0.11.7
#   Downloading applicationinsights-0.11.9-py2.py3-none-any.whl (58 kB)
# Collecting gunicorn==19.9.0
#   Downloading gunicorn-19.9.0-py2.py3-none-any.whl (112 kB)
# Collecting werkzeug<=1.0.1,>=0.16.1
#   Downloading Werkzeug-1.0.1-py2.py3-none-any.whl (298 kB)
# Collecting azureml-dataset-runtime[fuse]~=1.24.0
#   Downloading azureml_dataset_runtime-1.24.0-py3-none-any.whl (3.4 kB)
# Collecting azureml-model-management-sdk==1.0.1b6.post1
#   Downloading azureml_model_management_sdk-1.0.1b6.post1-py2.py3-none-any.whl (130 kB)
# Collecting json-logging-py==0.2
#   Downloading json-logging-py-0.2.tar.gz (3.6 kB)
# Collecting flask==1.0.3
#   Downloading Flask-1.0.3-py2.py3-none-any.whl (92 kB)
# Collecting configparser==3.7.4
#   Downloading configparser-3.7.4-py2.py3-none-any.whl (22 kB)
# Requirement already satisfied: requests in /azureml-envs/azureml_882aeb18bd4696f212b5c79bda0dd217/lib/python3.6/site-packages (from azureml==0.2.7->-r /azureml-environment-setup/condaenv.g8xvz0at.requirements.txt (line 2)) (2.24.0)
# Requirement already satisfied: python-dateutil in /azureml-envs/azureml_882aeb18bd4696f212b5c79bda0dd217/lib/python3.6/site-packages (from azureml==0.2.7->-r /azureml-environment-setup/condaenv.g8xvz0at.requirements.txt (line 2)) (2.8.1)
# Collecting pytz
#   Downloading pytz-2021.1-py2.py3-none-any.whl (510 kB)
# Collecting azure-mgmt-resource<15.0.0,>=1.2.1
#   Downloading azure_mgmt_resource-12.1.0-py2.py3-none-any.whl (1.1 MB)
# Collecting azure-mgmt-authorization<1.0.0,>=0.40.0
#   Downloading azure_mgmt_authorization-0.61.0-py2.py3-none-any.whl (94 kB)
# Collecting jmespath
#   Downloading jmespath-0.10.0-py2.py3-none-any.whl (24 kB)
# Requirement already satisfied: urllib3>=1.23 in /azureml-envs/azureml_882aeb18bd4696f212b5c79bda0dd217/lib/python3.6/site-packages (from azureml-core==1.24.0->-r /azureml-environment-setup/condaenv.g8xvz0at.requirements.txt (line 3)) (1.25.11)
# Collecting jsonpickle
#   Downloading jsonpickle-2.0.0-py2.py3-none-any.whl (37 kB)
# Collecting adal>=1.2.0
#   Downloading adal-1.2.6-py2.py3-none-any.whl (55 kB)
# Requirement already satisfied: cryptography!=1.9,!=2.0.*,!=2.1.*,!=2.2.*,<=3.2 in /azureml-envs/azureml_882aeb18bd4696f212b5c79bda0dd217/lib/python3.6/site-packages (from azureml-core==1.24.0->-r /azureml-environment-setup/condaenv.g8xvz0at.requirements.txt (line 3)) (2.3.1)
# Collecting ruamel.yaml>=0.15.35
#   Downloading ruamel.yaml-0.16.13-py2.py3-none-any.whl (111 kB)
# Collecting docker
#   Downloading docker-4.4.4-py2.py3-none-any.whl (147 kB)
# Collecting contextlib2
#   Downloading contextlib2-0.6.0.post1-py2.py3-none-any.whl (9.8 kB)
# Collecting azure-mgmt-containerregistry>=2.0.0
#   Downloading azure_mgmt_containerregistry-2.8.0-py2.py3-none-any.whl (718 kB)
# Collecting pathspec
#   Downloading pathspec-0.8.1-py2.py3-none-any.whl (28 kB)
# Collecting PyJWT<3.0.0
#   Downloading PyJWT-2.0.1-py3-none-any.whl (15 kB)
# Collecting backports.tempfile
#   Downloading backports.tempfile-1.0-py2.py3-none-any.whl (4.4 kB)
# Collecting SecretStorage
#   Downloading SecretStorage-3.3.1-py3-none-any.whl (15 kB)
# Collecting msrestazure>=0.4.33
#   Downloading msrestazure-0.6.4-py2.py3-none-any.whl (40 kB)
# Requirement already satisfied: pyopenssl<21.0.0 in /azureml-envs/azureml_882aeb18bd4696f212b5c79bda0dd217/lib/python3.6/site-packages (from azureml-core==1.24.0->-r /azureml-environment-setup/condaenv.g8xvz0at.requirements.txt (line 3)) (19.0.0)
# Collecting msrest>=0.5.1
#   Downloading msrest-0.6.21-py2.py3-none-any.whl (85 kB)
# Collecting azure-common>=1.1.12
#   Downloading azure_common-1.1.26-py2.py3-none-any.whl (12 kB)
# Collecting azure-graphrbac<1.0.0,>=0.40.0
#   Downloading azure_graphrbac-0.61.1-py2.py3-none-any.whl (141 kB)
# Collecting azure-mgmt-storage<16.0.0,>=1.5.0
#   Downloading azure_mgmt_storage-11.2.0-py2.py3-none-any.whl (547 kB)
# Collecting azure-mgmt-keyvault<7.0.0,>=0.40.0
#   Downloading azure_mgmt_keyvault-2.2.0-py2.py3-none-any.whl (89 kB)
# Collecting ndg-httpsclient
#   Downloading ndg_httpsclient-0.5.1-py3-none-any.whl (34 kB)
# Collecting azureml-pipeline~=1.24.0
#   Downloading azureml_pipeline-1.24.0-py3-none-any.whl (3.7 kB)
# Collecting azureml-train-automl-client~=1.24.0
#   Downloading azureml_train_automl_client-1.24.0-py3-none-any.whl (118 kB)
# Collecting azureml-train~=1.24.0
#   Downloading azureml_train-1.24.0-py3-none-any.whl (3.3 kB)
# Collecting azureml-telemetry~=1.24.0
#   Downloading azureml_telemetry-1.24.0-py3-none-any.whl (30 kB)
# Collecting onnx<=1.7.0,>=1.5.0
#   Downloading onnx-1.7.0-cp36-cp36m-manylinux1_x86_64.whl (7.4 MB)
# Collecting boto3<=1.15.18
#   Downloading boto3-1.15.18-py2.py3-none-any.whl (129 kB)
# Collecting onnxconverter-common<=1.6.0,>=1.4.2
#   Downloading onnxconverter_common-1.6.0-py2.py3-none-any.whl (43 kB)
# Collecting lightgbm<=2.3.0,>=2.0.11
#   Downloading lightgbm-2.3.0-py2.py3-none-manylinux1_x86_64.whl (1.3 MB)
# Collecting statsmodels<=0.10.2,>=0.9.0
#   Downloading statsmodels-0.10.2-cp36-cp36m-manylinux1_x86_64.whl (8.1 MB)
# Collecting smart-open<=1.9.0
#   Downloading smart_open-1.9.0.tar.gz (70 kB)
# Collecting onnxruntime<=1.6.0,>=1.3.0
#   Downloading onnxruntime-1.6.0-cp36-cp36m-manylinux2014_x86_64.whl (4.1 MB)
# Collecting sklearn-pandas<=1.7.0,>=1.4.0
#   Downloading sklearn_pandas-1.7.0-py2.py3-none-any.whl (10 kB)
# Collecting onnxmltools==1.4.1
#   Downloading onnxmltools-1.4.1-py2.py3-none-any.whl (371 kB)
# Collecting keras2onnx<=1.6.0,>=1.4.0
#   Downloading keras2onnx-1.6.0-py3-none-any.whl (219 kB)
# Requirement already satisfied: scipy<=1.5.2,>=1.0.0 in /azureml-envs/azureml_882aeb18bd4696f212b5c79bda0dd217/lib/python3.6/site-packages (from azureml-automl-runtime==1.24.0->-r /azureml-environment-setup/condaenv.g8xvz0at.requirements.txt (line 6)) (1.5.2)
# Collecting gensim<3.9.0
#   Downloading gensim-3.8.3-cp36-cp36m-manylinux1_x86_64.whl (24.2 MB)
# Collecting pmdarima==1.1.1
#   Downloading pmdarima-1.1.1-cp36-cp36m-manylinux1_x86_64.whl (682 kB)
# Collecting py-cpuinfo==5.0.0
#   Downloading py-cpuinfo-5.0.0.tar.gz (82 kB)
# Collecting scikit-learn<0.23.0,>=0.19.0
#   Downloading scikit_learn-0.22.2.post1-cp36-cp36m-manylinux1_x86_64.whl (7.1 MB)
# Collecting psutil<6.0.0,>=5.2.2
#   Downloading psutil-5.8.0-cp36-cp36m-manylinux2010_x86_64.whl (291 kB)
# Collecting nimbusml<=1.8.0,>=1.7.1
#   Downloading nimbusml-1.8.0-cp36-none-manylinux1_x86_64.whl (114.1 MB)
# Collecting botocore<=1.18.18
#   Downloading botocore-1.18.18-py2.py3-none-any.whl (6.7 MB)
# Collecting dill<0.4.0,>=0.2.8
#   Downloading dill-0.3.3-py2.py3-none-any.whl (81 kB)
# Collecting skl2onnx==1.4.9
#   Downloading skl2onnx-1.4.9-py2.py3-none-any.whl (114 kB)
# Collecting azure-core<2.0.0,>=1.9.0
#   Downloading azure_core-1.12.0-py2.py3-none-any.whl (130 kB)
# Requirement already satisfied: six in /azureml-envs/azureml_882aeb18bd4696f212b5c79bda0dd217/lib/python3.6/site-packages (from h5py==2.10.0->-r /azureml-environment-setup/condaenv.g8xvz0at.requirements.txt (line 11)) (1.15.0)
# Requirement already satisfied: setuptools in /azureml-envs/azureml_882aeb18bd4696f212b5c79bda0dd217/lib/python3.6/site-packages (from obspy==1.2.2->-r /azureml-environment-setup/condaenv.g8xvz0at.requirements.txt (line 13)) (50.3.0.post20201006)
# Collecting lxml
#   Downloading lxml-4.6.3-cp36-cp36m-manylinux1_x86_64.whl (5.5 MB)
# Requirement already satisfied: matplotlib>=1.1.0 in /azureml-envs/azureml_882aeb18bd4696f212b5c79bda0dd217/lib/python3.6/site-packages (from obspy==1.2.2->-r /azureml-environment-setup/condaenv.g8xvz0at.requirements.txt (line 13)) (3.2.2)
# Requirement already satisfied: decorator in /azureml-envs/azureml_882aeb18bd4696f212b5c79bda0dd217/lib/python3.6/site-packages (from obspy==1.2.2->-r /azureml-environment-setup/condaenv.g8xvz0at.requirements.txt (line 13)) (4.4.2)
# Collecting future>=0.12.4
#   Downloading future-0.18.2.tar.gz (829 kB)
# Collecting protobuf>=3.0.0
#   Downloading protobuf-3.15.6-cp36-cp36m-manylinux1_x86_64.whl (1.0 MB)
# Requirement already satisfied: pyparsing>=2.0.2 in /azureml-envs/azureml_882aeb18bd4696f212b5c79bda0dd217/lib/python3.6/site-packages (from packaging==20.7->-r /azureml-environment-setup/condaenv.g8xvz0at.requirements.txt (line 16)) (2.4.7)
# Requirement already satisfied: librosa in /azureml-envs/azureml_882aeb18bd4696f212b5c79bda0dd217/lib/python3.6/site-packages (from noisereduce==1.1.0->-r /azureml-environment-setup/condaenv.g8xvz0at.requirements.txt (line 18)) (0.8.0)
# Collecting azureml-dataprep<2.12.0a,>=2.11.0a
#   Downloading azureml_dataprep-2.11.2-py3-none-any.whl (39.4 MB)
# Collecting pyarrow<2.0.0,>=0.17.0
#   Downloading pyarrow-1.0.1-cp36-cp36m-manylinux2014_x86_64.whl (17.3 MB)
# Collecting fusepy<4.0.0,>=3.0.1; extra == "fuse"
#   Downloading fusepy-3.0.1.tar.gz (11 kB)
# Collecting liac-arff>=2.1.1
#   Downloading liac-arff-2.5.0.tar.gz (13 kB)
# Collecting Jinja2>=2.10
#   Downloading Jinja2-2.11.3-py2.py3-none-any.whl (125 kB)
# Collecting itsdangerous>=0.24
#   Downloading itsdangerous-1.1.0-py2.py3-none-any.whl (16 kB)
# Collecting click>=5.1
#   Downloading click-7.1.2-py2.py3-none-any.whl (82 kB)
# Requirement already satisfied: idna<3,>=2.5 in /azureml-envs/azureml_882aeb18bd4696f212b5c79bda0dd217/lib/python3.6/site-packages (from requests->azureml==0.2.7->-r /azureml-environment-setup/condaenv.g8xvz0at.requirements.txt (line 2)) (2.10)
# Requirement already satisfied: certifi>=2017.4.17 in /azureml-envs/azureml_882aeb18bd4696f212b5c79bda0dd217/lib/python3.6/site-packages (from requests->azureml==0.2.7->-r /azureml-environment-setup/condaenv.g8xvz0at.requirements.txt (line 2)) (2020.6.20)
# Requirement already satisfied: chardet<4,>=3.0.2 in /azureml-envs/azureml_882aeb18bd4696f212b5c79bda0dd217/lib/python3.6/site-packages (from requests->azureml==0.2.7->-r /azureml-environment-setup/condaenv.g8xvz0at.requirements.txt (line 2)) (3.0.4)
# Collecting importlib-metadata; python_version < "3.8"
#   Downloading importlib_metadata-3.7.3-py3-none-any.whl (12 kB)
# Requirement already satisfied: asn1crypto>=0.21.0 in /azureml-envs/azureml_882aeb18bd4696f212b5c79bda0dd217/lib/python3.6/site-packages (from cryptography!=1.9,!=2.0.*,!=2.1.*,!=2.2.*,<=3.2->azureml-core==1.24.0->-r /azureml-environment-setup/condaenv.g8xvz0at.requirements.txt (line 3)) (1.4.0)
# Requirement already satisfied: cffi!=1.11.3,>=1.7 in /azureml-envs/azureml_882aeb18bd4696f212b5c79bda0dd217/lib/python3.6/site-packages (from cryptography!=1.9,!=2.0.*,!=2.1.*,!=2.2.*,<=3.2->azureml-core==1.24.0->-r /azureml-environment-setup/condaenv.g8xvz0at.requirements.txt (line 3)) (1.14.0)
# Collecting ruamel.yaml.clib>=0.1.2; platform_python_implementation == "CPython" and python_version < "3.10"
#   Downloading ruamel.yaml.clib-0.2.2-cp36-cp36m-manylinux1_x86_64.whl (549 kB)
# Collecting websocket-client>=0.32.0
#   Downloading websocket_client-0.58.0-py2.py3-none-any.whl (61 kB)
# Collecting backports.weakref
#   Downloading backports.weakref-1.0.post1-py2.py3-none-any.whl (5.2 kB)
# Collecting jeepney>=0.6
#   Downloading jeepney-0.6.0-py3-none-any.whl (45 kB)
# Collecting requests-oauthlib>=0.5.0
#   Downloading requests_oauthlib-1.3.0-py2.py3-none-any.whl (23 kB)
# Collecting isodate>=0.6.0
#   Downloading isodate-0.6.0-py2.py3-none-any.whl (45 kB)
# Collecting pyasn1>=0.1.1
#   Downloading pyasn1-0.4.8-py2.py3-none-any.whl (77 kB)
# Collecting azureml-pipeline-core~=1.24.0
#   Downloading azureml_pipeline_core-1.24.0-py3-none-any.whl (308 kB)
# Collecting azureml-pipeline-steps~=1.24.0
#   Downloading azureml_pipeline_steps-1.24.0-py3-none-any.whl (67 kB)
# Collecting azureml-train-core~=1.24.0
#   Downloading azureml_train_core-1.24.0-py3-none-any.whl (8.6 MB)
# Collecting typing-extensions>=3.6.2.1
#   Downloading typing_extensions-3.7.4.3-py3-none-any.whl (22 kB)
# Collecting s3transfer<0.4.0,>=0.3.0
#   Downloading s3transfer-0.3.6-py2.py3-none-any.whl (73 kB)
# Collecting patsy>=0.4.0
#   Downloading patsy-0.5.1-py2.py3-none-any.whl (231 kB)
# Collecting boto>=2.32
#   Downloading boto-2.49.0-py2.py3-none-any.whl (1.4 MB)
# Collecting fire
#   Downloading fire-0.4.0.tar.gz (87 kB)
# Collecting Cython>=0.29
#   Downloading Cython-0.29.22-cp36-cp36m-manylinux1_x86_64.whl (2.0 MB)
# Collecting dotnetcore2>=2.1.2
#   Downloading dotnetcore2-2.1.20-py3-none-manylinux1_x86_64.whl (28.7 MB)
# Requirement already satisfied: cycler>=0.10 in /azureml-envs/azureml_882aeb18bd4696f212b5c79bda0dd217/lib/python3.6/site-packages (from matplotlib>=1.1.0->obspy==1.2.2->-r /azureml-environment-setup/condaenv.g8xvz0at.requirements.txt (line 13)) (0.10.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /azureml-envs/azureml_882aeb18bd4696f212b5c79bda0dd217/lib/python3.6/site-packages (from matplotlib>=1.1.0->obspy==1.2.2->-r /azureml-environment-setup/condaenv.g8xvz0at.requirements.txt (line 13)) (1.2.0)
# Requirement already satisfied: pooch>=1.0 in /azureml-envs/azureml_882aeb18bd4696f212b5c79bda0dd217/lib/python3.6/site-packages (from librosa->noisereduce==1.1.0->-r /azureml-environment-setup/condaenv.g8xvz0at.requirements.txt (line 18)) (1.3.0)
# Requirement already satisfied: numba>=0.43.0 in /azureml-envs/azureml_882aeb18bd4696f212b5c79bda0dd217/lib/python3.6/site-packages (from librosa->noisereduce==1.1.0->-r /azureml-environment-setup/condaenv.g8xvz0at.requirements.txt (line 18)) (0.51.2)
# Requirement already satisfied: resampy>=0.2.2 in /azureml-envs/azureml_882aeb18bd4696f212b5c79bda0dd217/lib/python3.6/site-packages (from librosa->noisereduce==1.1.0->-r /azureml-environment-setup/condaenv.g8xvz0at.requirements.txt (line 18)) (0.2.2)
# Requirement already satisfied: audioread>=2.0.0 in /azureml-envs/azureml_882aeb18bd4696f212b5c79bda0dd217/lib/python3.6/site-packages (from librosa->noisereduce==1.1.0->-r /azureml-environment-setup/condaenv.g8xvz0at.requirements.txt (line 18)) (2.1.9)
# Requirement already satisfied: soundfile>=0.9.0 in /azureml-envs/azureml_882aeb18bd4696f212b5c79bda0dd217/lib/python3.6/site-packages (from librosa->noisereduce==1.1.0->-r /azureml-environment-setup/condaenv.g8xvz0at.requirements.txt (line 18)) (0.10.3.post1)
# Collecting cloudpickle<2.0.0,>=1.1.0
#   Downloading cloudpickle-1.6.0-py3-none-any.whl (23 kB)
# Collecting azureml-dataprep-rslex<1.10.0a,>=1.9.0dev0
#   Downloading azureml_dataprep_rslex-1.9.1-cp36-cp36m-manylinux2010_x86_64.whl (9.0 MB)
# Collecting azureml-dataprep-native<31.0.0,>=30.0.0
#   Downloading azureml_dataprep_native-30.0.0-cp36-cp36m-manylinux1_x86_64.whl (1.3 MB)
# Collecting azure-identity<1.5.0,>=1.2.0
#   Downloading azure_identity-1.4.1-py2.py3-none-any.whl (86 kB)
# Collecting MarkupSafe>=0.23
#   Downloading MarkupSafe-1.1.1-cp36-cp36m-manylinux2010_x86_64.whl (32 kB)
# Collecting zipp>=0.5
#   Downloading zipp-3.4.1-py3-none-any.whl (5.2 kB)
# Requirement already satisfied: pycparser in /azureml-envs/azureml_882aeb18bd4696f212b5c79bda0dd217/lib/python3.6/site-packages (from cffi!=1.11.3,>=1.7->cryptography!=1.9,!=2.0.*,!=2.1.*,!=2.2.*,<=3.2->azureml-core==1.24.0->-r /azureml-environment-setup/condaenv.g8xvz0at.requirements.txt (line 3)) (2.20)
# Collecting oauthlib>=3.0.0
#   Downloading oauthlib-3.1.0-py2.py3-none-any.whl (147 kB)
# Collecting azureml-train-restclients-hyperdrive~=1.24.0
#   Downloading azureml_train_restclients_hyperdrive-1.24.0-py3-none-any.whl (19 kB)
# Collecting termcolor
#   Downloading termcolor-1.1.0.tar.gz (3.9 kB)
# Collecting distro>=1.2.0
#   Downloading distro-1.5.0-py2.py3-none-any.whl (18 kB)
# Requirement already satisfied: appdirs in /azureml-envs/azureml_882aeb18bd4696f212b5c79bda0dd217/lib/python3.6/site-packages (from pooch>=1.0->librosa->noisereduce==1.1.0->-r /azureml-environment-setup/condaenv.g8xvz0at.requirements.txt (line 18)) (1.4.4)
# Requirement already satisfied: llvmlite<0.35,>=0.34.0.dev0 in /azureml-envs/azureml_882aeb18bd4696f212b5c79bda0dd217/lib/python3.6/site-packages (from numba>=0.43.0->librosa->noisereduce==1.1.0->-r /azureml-environment-setup/condaenv.g8xvz0at.requirements.txt (line 18)) (0.34.0)
# Collecting msal<2.0.0,>=1.3.0
#   Downloading msal-1.10.0-py2.py3-none-any.whl (60 kB)
# Collecting msal-extensions~=0.2.2
#   Downloading msal_extensions-0.2.2-py2.py3-none-any.whl (15 kB)
# Collecting portalocker~=1.0; platform_system != "Windows"
#   Downloading portalocker-1.7.1-py2.py3-none-any.whl (10 kB)
# Building wheels for collected packages: obspy, noisereduce, json-logging-py, smart-open, py-cpuinfo, future, fusepy, liac-arff, fire, termcolor
#   Building wheel for obspy (PEP 517): started
#
#   Building wheel for obspy (PEP 517): finished with status 'done'
#   Created wheel for obspy: filename=obspy-1.2.2-cp36-cp36m-linux_x86_64.whl size=21694285 sha256=ff92dcd513d3f340afc51c6f02887e8617a4b6ab42bf6fb2ceafc8a042bf3d2e
#   Stored in directory: /root/.cache/pip/wheels/e5/26/f8/739635bd6ce26550743eac39d0a4fd5dfb01b16b4d3a644ebc
#   Building wheel for noisereduce (setup.py): started
#   Building wheel for noisereduce (setup.py): finished with status 'done'
#   Created wheel for noisereduce: filename=noisereduce-1.1.0-py3-none-any.whl size=7607 sha256=c9c77fb06e5add1447d1f803792b029e3e0ce9b82708dde41fbccabe0e521e5d
#   Stored in directory: /root/.cache/pip/wheels/a9/d4/51/49c94295d30569d64c83dc11dce56166173635c85d060c9859
#   Building wheel for json-logging-py (setup.py): started
#   Building wheel for json-logging-py (setup.py): finished with status 'done'
#   Created wheel for json-logging-py: filename=json_logging_py-0.2-py3-none-any.whl size=3924 sha256=bf42eb589294fc0300032049ac004024a5ce7603bbe3c358517d515126e6d00a
#   Stored in directory: /root/.cache/pip/wheels/e2/1d/52/535a274b9c2ce7d4064838f2bdb62013801281ef7d7f21e2ee
#   Building wheel for smart-open (setup.py): started
#   Building wheel for smart-open (setup.py): finished with status 'done'
#   Created wheel for smart-open: filename=smart_open-1.9.0-py3-none-any.whl size=73087 sha256=c481819607e47d76bccdb0dd9adcc307c676cb6a45b4f86ee727bb4ae7676e0f
#   Stored in directory: /root/.cache/pip/wheels/8e/9f/cd/dbf5c1362c59abb699a218c1151679033b8ccb5b6db559d512
#   Building wheel for py-cpuinfo (setup.py): started
#   Building wheel for py-cpuinfo (setup.py): finished with status 'done'
#   Created wheel for py-cpuinfo: filename=py_cpuinfo-5.0.0-py3-none-any.whl size=18683 sha256=be9134028f1b29d5bc0f19ae390e11362c424b806ecb925140b4c74fab93a6e5
#   Stored in directory: /root/.cache/pip/wheels/e6/54/db/65176a1697a583d8ec5f90510f6faab11cda739d0e4f0ba2ea
#   Building wheel for future (setup.py): started
#   Building wheel for future (setup.py): finished with status 'done'
#   Created wheel for future: filename=future-0.18.2-py3-none-any.whl size=491059 sha256=c8c24a70ab5d063900003ecb63fa0d833dfa8245fa468721a2569a1f4e80d002
#   Stored in directory: /root/.cache/pip/wheels/6e/9c/ed/4499c9865ac1002697793e0ae05ba6be33553d098f3347fb94
#   Building wheel for fusepy (setup.py): started
#   Building wheel for fusepy (setup.py): finished with status 'done'
#   Created wheel for fusepy: filename=fusepy-3.0.1-py3-none-any.whl size=10504 sha256=58b41ccaa16147e31d79908b3cb4c59c5c0bf23069b2106cbcbbc1b3ed2cadb1
#   Stored in directory: /root/.cache/pip/wheels/21/5c/83/1dd7e8a232d12227e5410120f4374b33adeb4037473105b079
#   Building wheel for liac-arff (setup.py): started
#   Building wheel for liac-arff (setup.py): finished with status 'done'
#   Created wheel for liac-arff: filename=liac_arff-2.5.0-py3-none-any.whl size=11730 sha256=ea50ff3c59eae2599f93e71e37f48f859e9a5c998da8d99e9b4858c51c0e8baf
#   Stored in directory: /root/.cache/pip/wheels/53/ba/da/8562a6a6dbb428fd1ecc21053106df3948645cd991958f669b
#   Building wheel for fire (setup.py): started
#   Building wheel for fire (setup.py): finished with status 'done'
#   Created wheel for fire: filename=fire-0.4.0-py2.py3-none-any.whl size=115928 sha256=9ce05dea6386d1510c015d851d3e6454af75cfb9011a912ed472c84dbdbb7c20
#   Stored in directory: /root/.cache/pip/wheels/a6/12/74/ce0728e3990845862240349a12d7179a262e388ec73938024b
#   Building wheel for termcolor (setup.py): started
#   Building wheel for termcolor (setup.py): finished with status 'done'
#   Created wheel for termcolor: filename=termcolor-1.1.0-py3-none-any.whl size=4830 sha256=6c1041ca1e4220383c89b03b2d5f97952b01e641b2484ba52debbfe7cf743517
#   Stored in directory: /root/.cache/pip/wheels/93/2a/eb/e58dbcbc963549ee4f065ff80a59f274cc7210b6eab962acdc
# Successfully built obspy noisereduce json-logging-py smart-open py-cpuinfo future fusepy liac-arff fire termcolor
# Installing collected packages: applicationinsights, gunicorn, werkzeug, cloudpickle, azureml-dataprep-rslex, distro, dotnetcore2, azureml-dataprep-native, azure-core, PyJWT, msal, portalocker, msal-extensions, azure-identity, azureml-dataprep, numpy, pyarrow, fusepy, azureml-dataset-runtime, pytz, oauthlib, requests-oauthlib, isodate, msrest, azure-common, adal, msrestazure, azure-mgmt-resource, azure-mgmt-authorization, jmespath, zipp, typing-extensions, importlib-metadata, jsonpickle, ruamel.yaml.clib, ruamel.yaml, websocket-client, docker, contextlib2, azure-mgmt-containerregistry, pathspec, backports.weakref, backports.tempfile, jeepney, SecretStorage, azure-graphrbac, azure-mgmt-storage, azure-mgmt-keyvault, pyasn1, ndg-httpsclient, azureml-core, dill, liac-arff, pandas, azureml-model-management-sdk, json-logging-py, MarkupSafe, Jinja2, itsdangerous, click, flask, configparser, azureml-defaults, azureml, azureml-pipeline-core, azureml-train-restclients-hyperdrive, azureml-telemetry, azureml-train-core, azureml-automl-core, azureml-train-automl-client, azureml-pipeline-steps, azureml-pipeline, azureml-train, azureml-sdk, protobuf, onnx, botocore, s3transfer, boto3, onnxconverter-common, joblib, scikit-learn, lightgbm, patsy, statsmodels, boto, smart-open, onnxruntime, sklearn-pandas, skl2onnx, termcolor, fire, keras2onnx, onnxmltools, gensim, Cython, pmdarima, py-cpuinfo, psutil, nimbusml, azureml-automl-runtime, azure-storage-blob, sqlalchemy, h5py, tqdm, lxml, future, obspy, mysql-connector-python, packaging, xgboost, noisereduce
#   Attempting uninstall: numpy
#     Found existing installation: numpy 1.19.1
#     Uninstalling numpy-1.19.1:
#       Successfully uninstalled numpy-1.19.1
#
#   Attempting uninstall: joblib
#     Found existing installation: joblib 0.17.0
#     Uninstalling joblib-0.17.0:
#       Successfully uninstalled joblib-0.17.0
#   Attempting uninstall: scikit-learn
#     Found existing installation: scikit-learn 0.23.2
#     Uninstalling scikit-learn-0.23.2:
#       Successfully uninstalled scikit-learn-0.23.2
#
#   Attempting uninstall: packaging
#     Found existing installation: packaging 20.4
#     Uninstalling packaging-20.4:
#       Successfully uninstalled packaging-20.4
# Successfully installed Cython-0.29.22 Jinja2-2.11.3 MarkupSafe-1.1.1 PyJWT-2.0.1 SecretStorage-3.3.1 adal-1.2.6 applicationinsights-0.11.9 azure-common-1.1.26 azure-core-1.12.0 azure-graphrbac-0.61.1 azure-identity-1.4.1 azure-mgmt-authorization-0.61.0 azure-mgmt-containerregistry-2.8.0 azure-mgmt-keyvault-2.2.0 azure-mgmt-resource-12.1.0 azure-mgmt-storage-11.2.0 azure-storage-blob-12.6.0 azureml-0.2.7 azureml-automl-core-1.24.0 azureml-automl-runtime-1.24.0 azureml-core-1.24.0 azureml-dataprep-2.11.2 azureml-dataprep-native-30.0.0 azureml-dataprep-rslex-1.9.1 azureml-dataset-runtime-1.24.0 azureml-defaults-1.24.0 azureml-model-management-sdk-1.0.1b6.post1 azureml-pipeline-1.24.0 azureml-pipeline-core-1.24.0 azureml-pipeline-steps-1.24.0 azureml-sdk-1.24.0 azureml-telemetry-1.24.0 azureml-train-1.24.0 azureml-train-automl-client-1.24.0 azureml-train-core-1.24.0 azureml-train-restclients-hyperdrive-1.24.0 backports.tempfile-1.0 backports.weakref-1.0.post1 boto-2.49.0 boto3-1.15.18 botocore-1.18.18 click-7.1.2 cloudpickle-1.6.0 configparser-3.7.4 contextlib2-0.6.0.post1 dill-0.3.3 distro-1.5.0 docker-4.4.4 dotnetcore2-2.1.20 fire-0.4.0 flask-1.0.3 fusepy-3.0.1 future-0.18.2 gensim-3.8.3 gunicorn-19.9.0 h5py-2.10.0 importlib-metadata-3.7.3 isodate-0.6.0 itsdangerous-1.1.0 jeepney-0.6.0 jmespath-0.10.0 joblib-0.14.1 json-logging-py-0.2 jsonpickle-2.0.0 keras2onnx-1.6.0 liac-arff-2.5.0 lightgbm-2.3.0 lxml-4.6.3 msal-1.10.0 msal-extensions-0.2.2 msrest-0.6.21 msrestazure-0.6.4 mysql-connector-python-8.0.18 ndg-httpsclient-0.5.1 nimbusml-1.8.0 noisereduce-1.1.0 numpy-1.18.5 oauthlib-3.1.0 obspy-1.2.2 onnx-1.7.0 onnxconverter-common-1.6.0 onnxmltools-1.4.1 onnxruntime-1.6.0 packaging-20.7 pandas-0.25.3 pathspec-0.8.1 patsy-0.5.1 pmdarima-1.1.1 portalocker-1.7.1 protobuf-3.15.6 psutil-5.8.0 py-cpuinfo-5.0.0 pyarrow-1.0.1 pyasn1-0.4.8 pytz-2021.1 requests-oauthlib-1.3.0 ruamel.yaml-0.16.13 ruamel.yaml.clib-0.2.2 s3transfer-0.3.6 scikit-learn-0.22.2.post1 skl2onnx-1.4.9 sklearn-pandas-1.7.0 smart-open-1.9.0 sqlalchemy-1.3.21 statsmodels-0.10.2 termcolor-1.1.0 tqdm-4.54.0 typing-extensions-3.7.4.3 websocket-client-0.58.0 werkzeug-1.0.1 xgboost-0.90 zipp-3.4.1
#
# #
# # To activate this environment, use:
# # > source activate /azureml-envs/azureml_882aeb18bd4696f212b5c79bda0dd217
# #
# # To deactivate an active environment, use:
# # > source deactivate
# #
#
#
# Removing intermediate container 2cbd1368dc90
#  ---> 681b3c0ae338
# Step 9/18 : ENV PATH /azureml-envs/azureml_882aeb18bd4696f212b5c79bda0dd217/bin:$PATH
#  ---> Running in b281de2a79fb
# Removing intermediate container b281de2a79fb
#  ---> 15f17e050d7e
# Step 10/18 : COPY azureml-environment-setup/send_conda_dependencies.py azureml-environment-setup/send_conda_dependencies.py
#  ---> 5156ed640560
# Step 11/18 : COPY azureml-environment-setup/environment_context.json azureml-environment-setup/environment_context.json
#  ---> 3b3c917c5c32
# Step 12/18 : RUN python /azureml-environment-setup/send_conda_dependencies.py -p /azureml-envs/azureml_882aeb18bd4696f212b5c79bda0dd217
#  ---> Running in 51cd830fdb08
# Report materialized dependencies for the environment
# Reading environment context
# Exporting conda environment
# Exception occured on getting conda environment details
# Failed to send materialized environment details
# Removing intermediate container 51cd830fdb08
#  ---> 65e9dadf885f
# Step 13/18 : ENV AZUREML_CONDA_ENVIRONMENT_PATH /azureml-envs/azureml_882aeb18bd4696f212b5c79bda0dd217
#  ---> Running in c0c8d3ab2e23
# Removing intermediate container c0c8d3ab2e23
#  ---> 708f5fbef93a
# Step 14/18 : ENV LD_LIBRARY_PATH /azureml-envs/azureml_882aeb18bd4696f212b5c79bda0dd217/lib:$LD_LIBRARY_PATH
#  ---> Running in ab9ce2621c56
# Removing intermediate container ab9ce2621c56
#  ---> 57d3707ca4a6
# Step 15/18 : COPY azureml-environment-setup/spark_cache.py azureml-environment-setup/log4j.properties /azureml-environment-setup/
#  ---> 175c862b93a8
# Step 16/18 : RUN if [ $SPARK_HOME ]; then /bin/bash -c '$SPARK_HOME/bin/spark-submit  /azureml-environment-setup/spark_cache.py'; fi
#  ---> Running in 2206c823a89d
# Removing intermediate container 2206c823a89d
#  ---> 8ce8bcfd694b
# Step 17/18 : ENV AZUREML_ENVIRONMENT_IMAGE True
#  ---> Running in afa09c965a7a
# Removing intermediate container afa09c965a7a
#  ---> 1cd1e8e859bc
# Step 18/18 : CMD ["bash"]
#  ---> Running in 892a85c92844
# Removing intermediate container 892a85c92844
#  ---> 179078c43ea9
# Successfully built 179078c43ea9
# Successfully tagged lsmcdevmlwsfe4aa203.azurecr.io/azureml/azureml_a3f23c10bf76c00df7b2e9f000cc80d6:latest
# Successfully tagged lsmcdevmlwsfe4aa203.azurecr.io/azureml/azureml_a3f23c10bf76c00df7b2e9f000cc80d6:1
# 2021/03/23 06:15:04 Successfully executed container: acb_step_0
# 2021/03/23 06:15:04 Executing step ID: acb_step_1. Timeout(sec): 5400, Working directory: '', Network: 'acb_default_network'
# 2021/03/23 06:15:04 Pushing image: lsmcdevmlwsfe4aa203.azurecr.io/azureml/azureml_a3f23c10bf76c00df7b2e9f000cc80d6:1, attempt 1
# The push refers to repository [lsmcdevmlwsfe4aa203.azurecr.io/azureml/azureml_a3f23c10bf76c00df7b2e9f000cc80d6]
# 042f1039e937: Preparing
# 2f97c1c19538: Preparing
# 25cd86239bea: Preparing
# f951bdd7ecf7: Preparing
# 0c0e8f3644e3: Preparing
# d3b0ffd02446: Preparing
# 4143d149ed23: Preparing
# b8ed19c90bb1: Preparing
# 106e6976095f: Preparing
# e1171d4d60ca: Preparing
# 6ef1a8ae63b7: Preparing
# 85389f9ead9e: Preparing
# f2608f66a0e3: Preparing
# 0e259b09e5f4: Preparing
# 340dc32eb998: Preparing
# df18b66efaa6: Preparing
# ccdb13a20bf2: Preparing
# 9513cdf4e497: Preparing
# 7f083f9454c0: Preparing
# 29f36b5893dc: Preparing
# d3b0ffd02446: Waiting
# 4143d149ed23: Waiting
# b8ed19c90bb1: Waiting
# 106e6976095f: Waiting
# e1171d4d60ca: Waiting
# 6ef1a8ae63b7: Waiting
# 85389f9ead9e: Waiting
# f2608f66a0e3: Waiting
# 0e259b09e5f4: Waiting
# 340dc32eb998: Waiting
# df18b66efaa6: Waiting
# ccdb13a20bf2: Waiting
# 9513cdf4e497: Waiting
# 7f083f9454c0: Waiting
# 29f36b5893dc: Waiting
# 042f1039e937: Pushed
# 25cd86239bea: Pushed
# f951bdd7ecf7: Pushed
# d3b0ffd02446: Pushed
# 2f97c1c19538: Pushed
# 4143d149ed23: Pushed
# b8ed19c90bb1: Pushed
# 106e6976095f: Pushed
# e1171d4d60ca: Pushed
# 6ef1a8ae63b7: Pushed
# 340dc32eb998: Pushed
# 85389f9ead9e: Pushed
# ccdb13a20bf2: Pushed
# 0e259b09e5f4: Pushed
# 9513cdf4e497: Pushed
# 7f083f9454c0: Pushed
# f2608f66a0e3: Pushed
# 29f36b5893dc: Pushed
# df18b66efaa6: Pushed
# 0c0e8f3644e3: Pushed
# 1: digest: sha256:2ad5a00ba2a67510401fb44a70c7fa6659967490d2bae70f71d6eea76580c80c size: 4510
# 2021/03/23 06:19:48 Successfully pushed image: lsmcdevmlwsfe4aa203.azurecr.io/azureml/azureml_a3f23c10bf76c00df7b2e9f000cc80d6:1
# 2021/03/23 06:19:48 Executing step ID: acb_step_2. Timeout(sec): 5400, Working directory: '', Network: 'acb_default_network'
# 2021/03/23 06:19:48 Pushing image: lsmcdevmlwsfe4aa203.azurecr.io/azureml/azureml_a3f23c10bf76c00df7b2e9f000cc80d6:latest, attempt 1
# The push refers to repository [lsmcdevmlwsfe4aa203.azurecr.io/azureml/azureml_a3f23c10bf76c00df7b2e9f000cc80d6]
# 042f1039e937: Preparing
# 2f97c1c19538: Preparing
# 25cd86239bea: Preparing
# f951bdd7ecf7: Preparing
# 0c0e8f3644e3: Preparing
# d3b0ffd02446: Preparing
# 4143d149ed23: Preparing
# b8ed19c90bb1: Preparing
# 106e6976095f: Preparing
# e1171d4d60ca: Preparing
# 6ef1a8ae63b7: Preparing
# 85389f9ead9e: Preparing
# f2608f66a0e3: Preparing
# 0e259b09e5f4: Preparing
# 340dc32eb998: Preparing
# df18b66efaa6: Preparing
# ccdb13a20bf2: Preparing
# 9513cdf4e497: Preparing
# 7f083f9454c0: Preparing
# 29f36b5893dc: Preparing
# d3b0ffd02446: Waiting
# 4143d149ed23: Waiting
# f2608f66a0e3: Waiting
# 0e259b09e5f4: Waiting
# 340dc32eb998: Waiting
# df18b66efaa6: Waiting
# b8ed19c90bb1: Waiting
# 106e6976095f: Waiting
# e1171d4d60ca: Waiting
# 6ef1a8ae63b7: Waiting
# 85389f9ead9e: Waiting
# ccdb13a20bf2: Waiting
# 9513cdf4e497: Waiting
# 7f083f9454c0: Waiting
# 29f36b5893dc: Waiting
# 0c0e8f3644e3: Layer already exists
# 042f1039e937: Layer already exists
# 2f97c1c19538: Layer already exists
# f951bdd7ecf7: Layer already exists
# 25cd86239bea: Layer already exists
# b8ed19c90bb1: Layer already exists
# d3b0ffd02446: Layer already exists
# 4143d149ed23: Layer already exists
# 106e6976095f: Layer already exists
# e1171d4d60ca: Layer already exists
# 6ef1a8ae63b7: Layer already exists
# 85389f9ead9e: Layer already exists
# f2608f66a0e3: Layer already exists
# 0e259b09e5f4: Layer already exists
# 340dc32eb998: Layer already exists
# df18b66efaa6: Layer already exists
# ccdb13a20bf2: Layer already exists
# 9513cdf4e497: Layer already exists
# 7f083f9454c0: Layer already exists
# 29f36b5893dc: Layer already exists
# latest: digest: sha256:2ad5a00ba2a67510401fb44a70c7fa6659967490d2bae70f71d6eea76580c80c size: 4510
# 2021/03/23 06:19:49 Successfully pushed image: lsmcdevmlwsfe4aa203.azurecr.io/azureml/azureml_a3f23c10bf76c00df7b2e9f000cc80d6:latest
# 2021/03/23 06:19:49 Step ID: acb_step_0 marked as successful (elapsed time in seconds: 629.539190)
# 2021/03/23 06:19:49 Populating digests for step ID: acb_step_0...
# 2021/03/23 06:19:53 Successfully populated digests for step ID: acb_step_0
# 2021/03/23 06:19:53 Step ID: acb_step_1 marked as successful (elapsed time in seconds: 283.761876)
# 2021/03/23 06:19:53 Step ID: acb_step_2 marked as successful (elapsed time in seconds: 1.503326)
# 2021/03/23 06:19:53 The following dependencies were found:
# 2021/03/23 06:19:53
# - image:
#     registry: lsmcdevmlwsfe4aa203.azurecr.io
#     repository: azureml/azureml_a3f23c10bf76c00df7b2e9f000cc80d6
#     tag: latest
#     digest: sha256:2ad5a00ba2a67510401fb44a70c7fa6659967490d2bae70f71d6eea76580c80c
#   runtime-dependency:
#     registry: mcr.microsoft.com
#     repository: azureml/base
#     tag: intelmpi2018.3-ubuntu16.04
#     digest: sha256:a1b514f3ba884b9a7695cbba5638933ddaf222e8ce3e8c81e8cdf861679abb05
#   git: {}
# - image:
#     registry: lsmcdevmlwsfe4aa203.azurecr.io
#     repository: azureml/azureml_a3f23c10bf76c00df7b2e9f000cc80d6
#     tag: "1"
#     digest: sha256:2ad5a00ba2a67510401fb44a70c7fa6659967490d2bae70f71d6eea76580c80c
#   runtime-dependency:
#     registry: mcr.microsoft.com
#     repository: azureml/base
#     tag: intelmpi2018.3-ubuntu16.04
#     digest: sha256:a1b514f3ba884b9a7695cbba5638933ddaf222e8ce3e8c81e8cdf861679abb05
#   git: {}
#
#
# Run ID: de1g was successful after 15m24s
# 2021/03/23 06:20:25 Downloading source code...
# 2021/03/23 06:20:27 Finished downloading source code
# 2021/03/23 06:20:28 Creating Docker network: acb_default_network, driver: 'bridge'
# 2021/03/23 06:20:31 Successfully set up Docker network: acb_default_network
# 2021/03/23 06:20:31 Setting up Docker configuration...
# 2021/03/23 06:20:32 Successfully set up Docker configuration
# 2021/03/23 06:20:32 Logging in to registry: lsmcdevmlwsfe4aa203.azurecr.io
# 2021/03/23 06:20:33 Successfully logged into lsmcdevmlwsfe4aa203.azurecr.io
# 2021/03/23 06:20:33 Executing step ID: acb_step_0. Timeout(sec): 5400, Working directory: '', Network: 'acb_default_network'
# 2021/03/23 06:20:33 Launching container with name: acb_step_0
# WARNING! Using --password via the CLI is insecure. Use --password-stdin.
# WARNING! Your password will be stored unencrypted in /acb/home/.docker/config.json.
# Configure a credential helper to remove this warning. See
# https://docs.docker.com/engine/reference/commandline/login/#credentials-store
#
# Login Succeeded
# 2021/03/23 06:20:35 Successfully executed container: acb_step_0
# 2021/03/23 06:20:35 Executing step ID: acb_step_1. Timeout(sec): 5400, Working directory: '', Network: 'acb_default_network'
# 2021/03/23 06:20:35 Scanning for dependencies...
# 2021/03/23 06:20:35 Successfully scanned dependencies
# 2021/03/23 06:20:35 Launching container with name: acb_step_1
# Sending build context to Docker daemon  67.07kB
# Step 1/7 : FROM lsmcdevmlwsfe4aa203.azurecr.io/azureml/azureml_a3f23c10bf76c00df7b2e9f000cc80d6
# latest: Pulling from azureml/azureml_a3f23c10bf76c00df7b2e9f000cc80d6
# a1298f4ce990: Pulling fs layer
# 04a3282d9c4b: Pulling fs layer
# 9b0d3db6dc03: Pulling fs layer
# 8269c605f3f1: Pulling fs layer
# 6504d449e70c: Pulling fs layer
# 4e38f320d0d4: Pulling fs layer
# b0a763e8ee03: Pulling fs layer
# 11917a028ca4: Pulling fs layer
# a6c378d11cbf: Pulling fs layer
# 6cc007ad9140: Pulling fs layer
# 6c1698a608f3: Pulling fs layer
# 3caa4d87ee51: Pulling fs layer
# 6a6703085cfe: Pulling fs layer
# bf531c6ad7df: Pulling fs layer
# d4905620267f: Pulling fs layer
# fa041df52bda: Pulling fs layer
# bb4652a9bfef: Pulling fs layer
# 3913c73fbbd7: Pulling fs layer
# a57f978b2dbd: Pulling fs layer
# bf5256c1906d: Pulling fs layer
# 8269c605f3f1: Waiting
# 6504d449e70c: Waiting
# 4e38f320d0d4: Waiting
# b0a763e8ee03: Waiting
# 11917a028ca4: Waiting
# a6c378d11cbf: Waiting
# 6cc007ad9140: Waiting
# 6c1698a608f3: Waiting
# 3caa4d87ee51: Waiting
# 6a6703085cfe: Waiting
# bf531c6ad7df: Waiting
# d4905620267f: Waiting
# fa041df52bda: Waiting
# bb4652a9bfef: Waiting
# 3913c73fbbd7: Waiting
# a57f978b2dbd: Waiting
# bf5256c1906d: Waiting
# 9b0d3db6dc03: Verifying Checksum
# 9b0d3db6dc03: Download complete
# 04a3282d9c4b: Verifying Checksum
# 04a3282d9c4b: Download complete
# a1298f4ce990: Verifying Checksum
# a1298f4ce990: Download complete
# a1298f4ce990: Pull complete
# 04a3282d9c4b: Pull complete
# 9b0d3db6dc03: Pull complete
# 8269c605f3f1: Verifying Checksum
# 8269c605f3f1: Download complete
# 8269c605f3f1: Pull complete
# 4e38f320d0d4: Verifying Checksum
# 4e38f320d0d4: Download complete
# b0a763e8ee03: Verifying Checksum
# b0a763e8ee03: Download complete
# 11917a028ca4: Verifying Checksum
# 11917a028ca4: Download complete
# 6504d449e70c: Verifying Checksum
# 6504d449e70c: Download complete
# 6c1698a608f3: Verifying Checksum
# 6c1698a608f3: Download complete
# 6cc007ad9140: Verifying Checksum
# 6cc007ad9140: Download complete
# 3caa4d87ee51: Verifying Checksum
# 3caa4d87ee51: Download complete
# 6a6703085cfe: Verifying Checksum
# 6a6703085cfe: Download complete
# d4905620267f: Verifying Checksum
# d4905620267f: Download complete
# bf531c6ad7df: Verifying Checksum
# bf531c6ad7df: Download complete
# bb4652a9bfef: Verifying Checksum
# bb4652a9bfef: Download complete
# 3913c73fbbd7: Verifying Checksum
# 3913c73fbbd7: Download complete
# a57f978b2dbd: Verifying Checksum
# a57f978b2dbd: Download complete
# bf5256c1906d: Verifying Checksum
# bf5256c1906d: Download complete
# a6c378d11cbf: Verifying Checksum
# a6c378d11cbf: Download complete
# 6504d449e70c: Pull complete
# 4e38f320d0d4: Pull complete
# b0a763e8ee03: Pull complete
# fa041df52bda: Verifying Checksum
# fa041df52bda: Download complete
# 11917a028ca4: Pull complete
# a6c378d11cbf: Pull complete
# 6cc007ad9140: Pull complete
# 6c1698a608f3: Pull complete
# 3caa4d87ee51: Pull complete
# 6a6703085cfe: Pull complete
# bf531c6ad7df: Pull complete
# d4905620267f: Pull complete
#
# fa041df52bda: Pull complete
# bb4652a9bfef: Pull complete
# 3913c73fbbd7: Pull complete
# a57f978b2dbd: Pull complete
# bf5256c1906d: Pull complete
# Digest: sha256:2ad5a00ba2a67510401fb44a70c7fa6659967490d2bae70f71d6eea76580c80c
# Status: Downloaded newer image for lsmcdevmlwsfe4aa203.azurecr.io/azureml/azureml_a3f23c10bf76c00df7b2e9f000cc80d6:latest
#  ---> 179078c43ea9
# Step 2/7 : ENV AZUREML_MODEL_DIR=azureml-models/03_050_02.pickle/1
#  ---> Running in 46a7fa3750cd
# Removing intermediate container 46a7fa3750cd
#  ---> 5056f728e9a4
# Step 3/7 : RUN mkdir -p '/var/azureml-app' && /var/azureml-util/download_asset.sh 'https://lsmcdevmlws6662442335.blob.core.windows.net/azureml/LocalUpload/ee21332f/tmp2ufllg36.py?sv=2019-02-02&sr=b&sig=OTUc5UKUGIsvR0LNu%2F94VqT3IsaQ0X29b%2BpDZ6qOe%2B0%3D&st=2021-03-23T06%3A10%3A19Z&se=2021-03-23T14%3A20%3A19Z&sp=r' '/var/azureml-app/tmp2ufllg36.py' && /var/azureml-util/download_asset.sh 'https://lsmcdevmlws6662442335.blob.core.windows.net/azureml/LocalUpload/f43db628/31fe0c22.tar.gz?sv=2019-02-02&sr=b&sig=kMay%2BLt17znmxWOTlwVoFhpblyvuH2TxyA%2B4YZRVJJA%3D&st=2021-03-23T06%3A10%3A19Z&se=2021-03-23T14%3A20%3A19Z&sp=r' /tmp/temp.tar.gz && tar xzf /tmp/temp.tar.gz -C '/var/azureml-app' && rm -f /tmp/temp.tar.gz
#  ---> Running in e0a0ddd1c050
# Downloading https://lsmcdevmlws6662442335.blob.core.windows.net/azureml/LocalUpload/ee21332f/tmp2ufllg36.py?sv=2019-02-02&sr=b&sig=OTUc5UKUGIsvR0LNu%2F94VqT3IsaQ0X29b%2BpDZ6qOe%2B0%3D&st=2021-03-23T06%3A10%3A19Z&se=2021-03-23T14%3A20%3A19Z&sp=r as /var/azureml-app/tmp2ufllg36.py
# wget: /azureml-envs/azureml_882aeb18bd4696f212b5c79bda0dd217/lib/libcrypto.so.1.0.0: no version information available (required by wget)
# wget: /azureml-envs/azureml_882aeb18bd4696f212b5c79bda0dd217/lib/libssl.so.1.0.0: no version information available (required by wget)
# wget: /azureml-envs/azureml_882aeb18bd4696f212b5c79bda0dd217/lib/libssl.so.1.0.0: no version information available (required by wget)
# --2021-03-23 06:22:32--  https://lsmcdevmlws6662442335.blob.core.windows.net/azureml/LocalUpload/ee21332f/tmp2ufllg36.py?sv=2019-02-02&sr=b&sig=OTUc5UKUGIsvR0LNu%2F94VqT3IsaQ0X29b%2BpDZ6qOe%2B0%3D&st=2021-03-23T06%3A10%3A19Z&se=2021-03-23T14%3A20%3A19Z&sp=r
# Resolving lsmcdevmlws6662442335.blob.core.windows.net (lsmcdevmlws6662442335.blob.core.windows.net)... 52.239.148.4
# Connecting to lsmcdevmlws6662442335.blob.core.windows.net (lsmcdevmlws6662442335.blob.core.windows.net)|52.239.148.4|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 1187 (1.2K) [application/octet-stream]
# Saving to: ‘/var/azureml-app/tmp2ufllg36.py’
#
#      0K                                    100%  129M=0s
#
# 2021-03-23 06:22:33 (129 MB/s) - ‘/var/azureml-app/tmp2ufllg36.py’ saved [1187/1187]
#
# Downloading https://lsmcdevmlws6662442335.blob.core.windows.net/azureml/LocalUpload/f43db628/31fe0c22.tar.gz?sv=2019-02-02&sr=b&sig=kMay%2BLt17znmxWOTlwVoFhpblyvuH2TxyA%2B4YZRVJJA%3D&st=2021-03-23T06%3A10%3A19Z&se=2021-03-23T14%3A20%3A19Z&sp=r as /tmp/temp.tar.gz
# wget: /azureml-envs/azureml_882aeb18bd4696f212b5c79bda0dd217/lib/libcrypto.so.1.0.0: no version information available (required by wget)
# wget: /azureml-envs/azureml_882aeb18bd4696f212b5c79bda0dd217/lib/libssl.so.1.0.0: no version information available (required by wget)
# wget: /azureml-envs/azureml_882aeb18bd4696f212b5c79bda0dd217/lib/libssl.so.1.0.0: no version information available (required by wget)
# --2021-03-23 06:22:33--  https://lsmcdevmlws6662442335.blob.core.windows.net/azureml/LocalUpload/f43db628/31fe0c22.tar.gz?sv=2019-02-02&sr=b&sig=kMay%2BLt17znmxWOTlwVoFhpblyvuH2TxyA%2B4YZRVJJA%3D&st=2021-03-23T06%3A10%3A19Z&se=2021-03-23T14%3A20%3A19Z&sp=r
# Resolving lsmcdevmlws6662442335.blob.core.windows.net (lsmcdevmlws6662442335.blob.core.windows.net)... 52.239.148.4
# Connecting to lsmcdevmlws6662442335.blob.core.windows.net (lsmcdevmlws6662442335.blob.core.windows.net)|52.239.148.4|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 31978 (31K) [application/octet-stream]
# Saving to: ‘/tmp/temp.tar.gz’
#
#      0K                                    100% 23.5M=0.001s
#
# 2021-03-23 06:22:33 (23.5 MB/s) - ‘/tmp/temp.tar.gz’ saved [31978/31978]
#
# Removing intermediate container e0a0ddd1c050
#  ---> 4572424c3c70
# Step 4/7 : RUN mkdir -p '/var/azureml-app/azureml-models/03_050_02.pickle/1' && /var/azureml-util/download_asset.sh 'https://lsmcdevmlws6662442335.blob.core.windows.net/azureml/LocalUpload/210323T150417-83c6fa50/03_050_02.pickle?sv=2019-02-02&sr=b&sig=uyZ3SErYGBfSF6%2BwJopFXBwJq12LurVdQ%2FHUcnydnTs%3D&st=2021-03-23T06%3A10%3A19Z&se=2021-03-23T14%3A20%3A19Z&sp=r' '/var/azureml-app/azureml-models/03_050_02.pickle/1/03_050_02.pickle'
#  ---> Running in 69fb5d85f008
# Downloading https://lsmcdevmlws6662442335.blob.core.windows.net/azureml/LocalUpload/210323T150417-83c6fa50/03_050_02.pickle?sv=2019-02-02&sr=b&sig=uyZ3SErYGBfSF6%2BwJopFXBwJq12LurVdQ%2FHUcnydnTs%3D&st=2021-03-23T06%3A10%3A19Z&se=2021-03-23T14%3A20%3A19Z&sp=r as /var/azureml-app/azureml-models/03_050_02.pickle/1/03_050_02.pickle
# wget: /azureml-envs/azureml_882aeb18bd4696f212b5c79bda0dd217/lib/libcrypto.so.1.0.0: no version information available (required by wget)
# wget: /azureml-envs/azureml_882aeb18bd4696f212b5c79bda0dd217/lib/libssl.so.1.0.0: no version information available (required by wget)
# wget: /azureml-envs/azureml_882aeb18bd4696f212b5c79bda0dd217/lib/libssl.so.1.0.0: no version information available (required by wget)
# --2021-03-23 06:22:38--  https://lsmcdevmlws6662442335.blob.core.windows.net/azureml/LocalUpload/210323T150417-83c6fa50/03_050_02.pickle?sv=2019-02-02&sr=b&sig=uyZ3SErYGBfSF6%2BwJopFXBwJq12LurVdQ%2FHUcnydnTs%3D&st=2021-03-23T06%3A10%3A19Z&se=2021-03-23T14%3A20%3A19Z&sp=r
# Resolving lsmcdevmlws6662442335.blob.core.windows.net (lsmcdevmlws6662442335.blob.core.windows.net)... 52.239.148.4
# Connecting to lsmcdevmlws6662442335.blob.core.windows.net (lsmcdevmlws6662442335.blob.core.windows.net)|52.239.148.4|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 5176203 (4.9M) [application/octet-stream]
# Saving to: ‘/var/azureml-app/azureml-models/03_050_02.pickle/1/03_050_02.pickle’
#
#      0K ....                               100% 61.6M=0.08s
#
# 2021-03-23 06:22:38 (61.6 MB/s) - ‘/var/azureml-app/azureml-models/03_050_02.pickle/1/03_050_02.pickle’ saved [5176203/5176203]
#
# Removing intermediate container 69fb5d85f008
#  ---> de42f783c1cb
# Step 5/7 : RUN mkdir -p '/var/azureml-app' && echo ... | base64 --decode > /var/azureml-app/model_config_map.json
#  ---> Running in c0e4a7724c95
# Removing intermediate container c0e4a7724c95
#  ---> 64650409f49c
# Step 6/7 : RUN mv '/var/azureml-app/tmp2ufllg36.py' /var/azureml-app/main.py
#  ---> Running in 14ecb38d53d4
# Removing intermediate container 14ecb38d53d4
#  ---> d8f408228d4e
# Step 7/7 : CMD ["runsvdir","/var/runit"]
#  ---> Running in f5172f8a3253
# Removing intermediate container f5172f8a3253
#  ---> 109cf1c9f37e
# Successfully built 109cf1c9f37e
# Successfully tagged lsmcdevmlwsfe4aa203.azurecr.io/azureml/azureml_beae5e83137d4ca411feb401bf73b506:latest
# Successfully tagged lsmcdevmlwsfe4aa203.azurecr.io/azureml/azureml_beae5e83137d4ca411feb401bf73b506:1
# 2021/03/23 06:22:57 Successfully executed container: acb_step_1
# 2021/03/23 06:22:57 Executing step ID: acb_step_2. Timeout(sec): 5400, Working directory: '', Network: 'acb_default_network'
# 2021/03/23 06:22:57 Pushing image: lsmcdevmlwsfe4aa203.azurecr.io/azureml/azureml_beae5e83137d4ca411feb401bf73b506:1, attempt 1
# The push refers to repository [lsmcdevmlwsfe4aa203.azurecr.io/azureml/azureml_beae5e83137d4ca411feb401bf73b506]
# 9a21c9c708a4: Preparing
# 3b25a40394f4: Preparing
# 972ff9dabb0a: Preparing
# 5c353fbff8e1: Preparing
# 042f1039e937: Preparing
# 2f97c1c19538: Preparing
# 25cd86239bea: Preparing
# f951bdd7ecf7: Preparing
# 0c0e8f3644e3: Preparing
# d3b0ffd02446: Preparing
# 4143d149ed23: Preparing
# b8ed19c90bb1: Preparing
# 106e6976095f: Preparing
# e1171d4d60ca: Preparing
# 6ef1a8ae63b7: Preparing
# 85389f9ead9e: Preparing
# f2608f66a0e3: Preparing
# 0e259b09e5f4: Preparing
# 340dc32eb998: Preparing
# df18b66efaa6: Preparing
# ccdb13a20bf2: Preparing
# 9513cdf4e497: Preparing
# 7f083f9454c0: Preparing
# 29f36b5893dc: Preparing
# 2f97c1c19538: Waiting
# 25cd86239bea: Waiting
# 85389f9ead9e: Waiting
# f951bdd7ecf7: Waiting
# 0c0e8f3644e3: Waiting
# f2608f66a0e3: Waiting
# d3b0ffd02446: Waiting
# 0e259b09e5f4: Waiting
# 4143d149ed23: Waiting
# b8ed19c90bb1: Waiting
# 340dc32eb998: Waiting
# 106e6976095f: Waiting
# e1171d4d60ca: Waiting
# df18b66efaa6: Waiting
# 6ef1a8ae63b7: Waiting
# ccdb13a20bf2: Waiting
# 29f36b5893dc: Waiting
# 7f083f9454c0: Waiting
# 042f1039e937: Mounted from azureml/azureml_a3f23c10bf76c00df7b2e9f000cc80d6
# 9a21c9c708a4: Pushed
# 3b25a40394f4: Pushed
# 2f97c1c19538: Mounted from azureml/azureml_a3f23c10bf76c00df7b2e9f000cc80d6
# 25cd86239bea: Mounted from azureml/azureml_a3f23c10bf76c00df7b2e9f000cc80d6
# f951bdd7ecf7: Mounted from azureml/azureml_a3f23c10bf76c00df7b2e9f000cc80d6
# 5c353fbff8e1: Pushed
# 0c0e8f3644e3: Mounted from azureml/azureml_a3f23c10bf76c00df7b2e9f000cc80d6
# d3b0ffd02446: Mounted from azureml/azureml_a3f23c10bf76c00df7b2e9f000cc80d6
# 4143d149ed23: Mounted from azureml/azureml_a3f23c10bf76c00df7b2e9f000cc80d6
# b8ed19c90bb1: Mounted from azureml/azureml_a3f23c10bf76c00df7b2e9f000cc80d6
# 972ff9dabb0a: Pushed
# 106e6976095f: Mounted from azureml/azureml_a3f23c10bf76c00df7b2e9f000cc80d6
# e1171d4d60ca: Mounted from azureml/azureml_a3f23c10bf76c00df7b2e9f000cc80d6
# 6ef1a8ae63b7: Mounted from azureml/azureml_a3f23c10bf76c00df7b2e9f000cc80d6
# 85389f9ead9e: Mounted from azureml/azureml_a3f23c10bf76c00df7b2e9f000cc80d6
# f2608f66a0e3: Mounted from azureml/azureml_a3f23c10bf76c00df7b2e9f000cc80d6
# 340dc32eb998: Mounted from azureml/azureml_a3f23c10bf76c00df7b2e9f000cc80d6
# ccdb13a20bf2: Mounted from azureml/azureml_a3f23c10bf76c00df7b2e9f000cc80d6
# 9513cdf4e497: Mounted from azureml/azureml_a3f23c10bf76c00df7b2e9f000cc80d6
# 7f083f9454c0: Mounted from azureml/azureml_a3f23c10bf76c00df7b2e9f000cc80d6
# 29f36b5893dc: Mounted from azureml/azureml_a3f23c10bf76c00df7b2e9f000cc80d6
# df18b66efaa6: Mounted from azureml/azureml_a3f23c10bf76c00df7b2e9f000cc80d6
# 0e259b09e5f4: Mounted from azureml/azureml_a3f23c10bf76c00df7b2e9f000cc80d6
# 1: digest: sha256:6f4f8dfb493bf31114b67995efff6bccd9211ffe6f96e898762b17514917979f size: 5344
# 2021/03/23 06:23:07 Successfully pushed image: lsmcdevmlwsfe4aa203.azurecr.io/azureml/azureml_beae5e83137d4ca411feb401bf73b506:1
# 2021/03/23 06:23:07 Executing step ID: acb_step_3. Timeout(sec): 5400, Working directory: '', Network: 'acb_default_network'
# 2021/03/23 06:23:07 Pushing image: lsmcdevmlwsfe4aa203.azurecr.io/azureml/azureml_beae5e83137d4ca411feb401bf73b506:latest, attempt 1
# The push refers to repository [lsmcdevmlwsfe4aa203.azurecr.io/azureml/azureml_beae5e83137d4ca411feb401bf73b506]
# 9a21c9c708a4: Preparing
# 3b25a40394f4: Preparing
# 972ff9dabb0a: Preparing
# 5c353fbff8e1: Preparing
# 042f1039e937: Preparing
# 2f97c1c19538: Preparing
# 25cd86239bea: Preparing
# f951bdd7ecf7: Preparing
# 0c0e8f3644e3: Preparing
# d3b0ffd02446: Preparing
# 4143d149ed23: Preparing
# b8ed19c90bb1: Preparing
# 106e6976095f: Preparing
# e1171d4d60ca: Preparing
# 6ef1a8ae63b7: Preparing
# 85389f9ead9e: Preparing
# f2608f66a0e3: Preparing
# 0e259b09e5f4: Preparing
# 340dc32eb998: Preparing
# df18b66efaa6: Preparing
# ccdb13a20bf2: Preparing
# 9513cdf4e497: Preparing
# 7f083f9454c0: Preparing
# 29f36b5893dc: Preparing
# 2f97c1c19538: Waiting
# 25cd86239bea: Waiting
# f951bdd7ecf7: Waiting
# 0c0e8f3644e3: Waiting
# d3b0ffd02446: Waiting
# 4143d149ed23: Waiting
# b8ed19c90bb1: Waiting
# 106e6976095f: Waiting
# e1171d4d60ca: Waiting
# 6ef1a8ae63b7: Waiting
# 85389f9ead9e: Waiting
# f2608f66a0e3: Waiting
# 0e259b09e5f4: Waiting
# 340dc32eb998: Waiting
# df18b66efaa6: Waiting
# ccdb13a20bf2: Waiting
# 9513cdf4e497: Waiting
# 7f083f9454c0: Waiting
# 29f36b5893dc: Waiting
# 042f1039e937: Layer already exists
# 972ff9dabb0a: Layer already exists
# 9a21c9c708a4: Layer already exists
# 5c353fbff8e1: Layer already exists
# 3b25a40394f4: Layer already exists
# 0c0e8f3644e3: Layer already exists
# 25cd86239bea: Layer already exists
# 2f97c1c19538: Layer already exists
# f951bdd7ecf7: Layer already exists
# d3b0ffd02446: Layer already exists
# b8ed19c90bb1: Layer already exists
# 106e6976095f: Layer already exists
# 4143d149ed23: Layer already exists
# e1171d4d60ca: Layer already exists
# 6ef1a8ae63b7: Layer already exists
# 0e259b09e5f4: Layer already exists
# 85389f9ead9e: Layer already exists
# 340dc32eb998: Layer already exists
# f2608f66a0e3: Layer already exists
# ccdb13a20bf2: Layer already exists
# df18b66efaa6: Layer already exists
# 9513cdf4e497: Layer already exists
# 7f083f9454c0: Layer already exists
# 29f36b5893dc: Layer already exists
# latest: digest: sha256:6f4f8dfb493bf31114b67995efff6bccd9211ffe6f96e898762b17514917979f size: 5344
# 2021/03/23 06:23:09 Successfully pushed image: lsmcdevmlwsfe4aa203.azurecr.io/azureml/azureml_beae5e83137d4ca411feb401bf73b506:latest
# 2021/03/23 06:23:09 Step ID: acb_step_0 marked as successful (elapsed time in seconds: 1.282614)
# 2021/03/23 06:23:09 Step ID: acb_step_1 marked as successful (elapsed time in seconds: 142.414928)
# 2021/03/23 06:23:09 Populating digests for step ID: acb_step_1...
# 2021/03/23 06:23:12 Successfully populated digests for step ID: acb_step_1
# 2021/03/23 06:23:12 Step ID: acb_step_2 marked as successful (elapsed time in seconds: 10.194947)
# 2021/03/23 06:23:12 Step ID: acb_step_3 marked as successful (elapsed time in seconds: 1.339761)
# 2021/03/23 06:23:12 The following dependencies were found:
# 2021/03/23 06:23:12
# - image:
#     registry: lsmcdevmlwsfe4aa203.azurecr.io
#     repository: azureml/azureml_beae5e83137d4ca411feb401bf73b506
#     tag: latest
#     digest: sha256:6f4f8dfb493bf31114b67995efff6bccd9211ffe6f96e898762b17514917979f
#   runtime-dependency:
#     registry: lsmcdevmlwsfe4aa203.azurecr.io
#     repository: azureml/azureml_a3f23c10bf76c00df7b2e9f000cc80d6
#     tag: latest
#     digest: sha256:2ad5a00ba2a67510401fb44a70c7fa6659967490d2bae70f71d6eea76580c80c
#   git: {}
# - image:
#     registry: lsmcdevmlwsfe4aa203.azurecr.io
#     repository: azureml/azureml_beae5e83137d4ca411feb401bf73b506
#     tag: "1"
#     digest: sha256:6f4f8dfb493bf31114b67995efff6bccd9211ffe6f96e898762b17514917979f
#   runtime-dependency:
#     registry: lsmcdevmlwsfe4aa203.azurecr.io
#     repository: azureml/azureml_a3f23c10bf76c00df7b2e9f000cc80d6
#     tag: latest
#     digest: sha256:2ad5a00ba2a67510401fb44a70c7fa6659967490d2bae70f71d6eea76580c80c
#   git: {}
#
# Run ID: de1h was successful after 2m48s
# Package creation Succeeded

# %%
print(package_service.state)
# Out:
# Succeeded

# %%
print(package_service.location)
# Out:
# lsmcdevmlwsfe4aa203.azurecr.io/mc-mlmodule@sha256:6f4f8dfb493bf31114b67995efff6bccd9211ffe6f96e898762b17514917979f
