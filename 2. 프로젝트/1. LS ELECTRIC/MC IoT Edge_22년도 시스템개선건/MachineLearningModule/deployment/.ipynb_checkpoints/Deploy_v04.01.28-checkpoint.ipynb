# %% [markdown]
# ## 추가해야하는 내용

# %%
# Check core SDK version number
import azureml.core
import os

print("SDK version:", azureml.core.VERSION)
# Out:
# SDK version: 1.24.0

# %% [markdown]
# # 1. Azure ML Service 작업 영업에 연결

# %% [markdown]
# #### Notebook이 실행되는 경로 내 Azure ML Service Workspace 접속 정보를 가진 config 파일이 있어야한다.

# %% [markdown]
#  - 테스트 배포 시에는 'data/config_dev.json' 사용
#  - 실제 배포 시에는 'data/config.json' 사용

# %%
from azureml.core.authentication import InteractiveLoginAuthentication

interactive_auth = InteractiveLoginAuthentication(tenant_id="c8b9cf2c-f80b-4c36-912f-74979c640070")

ws = Workspace(subscription_id="1f154107-bef0-481f-a741-68e7ba34affe",
               resource_group="lsmc-prd-rg",
               workspace_name="lsmc-dev-mlws",
               auth=interactive_auth)
# Out:
# Performing interactive authentication. Please follow the instructions on the terminal.
# Note, we have launched a browser for you to login. For old experience with device code, use "az login --use-device-code"
# You have logged in. Now let us find all the subscriptions to which you have access...
# ---------------------------------------------------------------------------
# AuthenticationException                   Traceback (most recent call last)
# <ipython-input-2-35ae42be60ab> in <module>
#       1 from azureml.core.authentication import InteractiveLoginAuthentication
#       2
# ----> 3 interactive_auth = InteractiveLoginAuthentication(tenant_id="c8b9cf2c-f80b-4c36-912f-74979c640070")
#       4
#       5 ws = Workspace(subscription_id="1f154107-bef0-481f-a741-68e7ba34affe",
#
# ~\AppData\Roaming\Python\Python38\site-packages\azureml\core\authentication.py in __init__(self, force, tenant_id, cloud)
#     486                     print("Performing interactive authentication. Please follow the instructions "
#     487                           "on the terminal.")
# --> 488                     perform_interactive_login(tenant=tenant_id, cloud_type=self._cloud_type)
#     489                     print("Interactive authentication successfully completed.")
#     490
#
# ~\AppData\Roaming\Python\Python38\site-packages\azureml\_base_sdk_common\common.py in perform_interactive_login(username, password, service_principal, tenant, allow_no_subscriptions, identity, use_device_code, use_cert_sn_issuer, cloud_type)
#     569     from adal.adal_error import AdalError
#     570     try:
# --> 571         subscriptions = profile.find_subscriptions_on_login(
#     572             interactive,
#     573             username,
#
# ~\AppData\Roaming\Python\Python38\site-packages\azureml\_vendor\azure_cli_core\_profile.py in find_subscriptions_on_login(self, interactive, username, password, is_service_principal, tenant, use_device_code, allow_no_subscriptions, subscription_finder, use_cert_sn_issuer)
#     240
#     241         if not allow_no_subscriptions and not subscriptions:
# --> 242             raise AuthenticationException("No subscriptions were found for '{}'. If this is expected, use "
#     243                                           "'--allow-no-subscriptions' to have tenant level accesses".format(username))
#     244
#
# AuthenticationException: AuthenticationException:
# 	Message: No subscriptions were found for 'None'. If this is expected, use '--allow-no-subscriptions' to have tenant level accesses
# 	InnerException None
# 	ErrorResponse
# {
#     "error": {
#         "code": "UserError",
#         "inner_error": {
#             "code": "Authentication"
#         },
#         "message": "No subscriptions were found for 'None'. If this is expected, use '--allow-no-subscriptions' to have tenant level accesses"
#     }
# }

# %%
from azureml.core.authentication import InteractiveLoginAuthentication

interactive_auth = InteractiveLoginAuthentication(tenant_id="54af7187-79bd-47bd-aea7-8fb194e64cdd")

ws = Workspace(subscription_id="245d9749-ca17-42f2-ae5e-2aefd9de113b",
               resource_group="bigdatateam",
               workspace_name="mltest21",
               auth=interactive_auth)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-3-ce88c80cfcc9> in <module>
#       3 interactive_auth = InteractiveLoginAuthentication(tenant_id="54af7187-79bd-47bd-aea7-8fb194e64cdd")
#       4
# ----> 5 ws = Workspace(subscription_id="245d9749-ca17-42f2-ae5e-2aefd9de113b",
#       6                resource_group="bigdatateam",
#       7                workspace_name="mltest21",
#
# NameError: name 'Workspace' is not defined

# %%
from azureml.core import Workspace

ws = Workspace.from_config('config/config_dev_test.json')
print('기계학습이름:'+ws.name, '리소스그룹이름:'+ws.resource_group, '리전이름:'+ws.location, '구독ID:'+ws.subscription_id, sep = '\n')
# Out:
# ---------------------------------------------------------------------------
# UserErrorException                        Traceback (most recent call last)
# <ipython-input-3-e9a29907a4d8> in <module>
#       1 from azureml.core import Workspace
#       2
# ----> 3 ws = Workspace.from_config('config/config_dev_test.json')
#       4 print('기계학습이름:'+ws.name, '리소스그룹이름:'+ws.resource_group, '리전이름:'+ws.location, '구독ID:'+ws.subscription_id, sep = '\n')
#
# ~\AppData\Roaming\Python\Python38\site-packages\azureml\core\workspace.py in from_config(path, auth, _logger, _file_name)
#     286
#     287         _logger.info('Found the config file in: %s', found_path)
# --> 288         return Workspace.get(
#     289             workspace_name,
#     290             auth=auth,
#
# ~\AppData\Roaming\Python\Python38\site-packages\azureml\core\workspace.py in get(name, auth, subscription_id, resource_group)
#     587             auth = InteractiveLoginAuthentication()
#     588
# --> 589         workspace = _commands.get_workspace(
#     590             auth,
#     591             subscription_id=subscription_id,
#
# ~\AppData\Roaming\Python\Python38\site-packages\azureml\_project\_commands.py in get_workspace(auth, subscription_id, resource_group_name, workspace_name)
#     389     """
#     390     try:
# --> 391         workspaces = auth._get_service_client(AzureMachineLearningWorkspaces, subscription_id).workspaces
#     392         return WorkspacesOperations.get(
#     393             workspaces,
#
# ~\AppData\Roaming\Python\Python38\site-packages\azureml\core\authentication.py in _get_service_client(self, client_class, subscription_id, subscription_bound, base_url)
#     174         if subscription_id:
#     175             all_subscription_list, tenant_id = self._get_all_subscription_ids()
# --> 176             self._check_if_subscription_exists(subscription_id, all_subscription_list, tenant_id)
#     177
#     178         if not base_url:
#
# ~\AppData\Roaming\Python\Python38\site-packages\azureml\core\authentication.py in _check_if_subscription_exists(self, subscription_id, subscription_id_list, tenant_id)
#     565
#     566     def _check_if_subscription_exists(self, subscription_id, subscription_id_list, tenant_id):
# --> 567         super(InteractiveLoginAuthentication, self)._check_if_subscription_exists(subscription_id,
#     568                                                                                   subscription_id_list, tenant_id)
#     569
#
# ~\AppData\Roaming\Python\Python38\site-packages\azureml\core\authentication.py in _check_if_subscription_exists(self, subscription_id, subscription_id_list, tenant_id)
#     253                                                                                    subscription_id_list))
#     254         else:
# --> 255             raise UserErrorException("You are currently logged-in to {} tenant. You don't have access "
#     256                                      "to {} subscription, please check if it is in this tenant. "
#     257                                      "All the subscriptions that you have access to in this tenant are = \n "
#
# UserErrorException: UserErrorException:
# 	Message: You are currently logged-in to 54af7187-79bd-47bd-aea7-8fb194e64cdd tenant. You don't have access to 1f154107-bef0-481f-a741-68e7ba34affe subscription, please check if it is in this tenant. All the subscriptions that you have access to in this tenant are =
#  [SubscriptionInfo(subscription_name='Azure Big data', subscription_id='245d9749-ca17-42f2-ae5e-2aefd9de113b')].
#  Please refer to aka.ms/aml-notebook-auth for different authentication mechanisms in azureml-sdk.
# 	InnerException None
# 	ErrorResponse
# {
#     "error": {
#         "code": "UserError",
#         "message": "You are currently logged-in to 54af7187-79bd-47bd-aea7-8fb194e64cdd tenant. You don't have access to 1f154107-bef0-481f-a741-68e7ba34affe subscription, please check if it is in this tenant. All the subscriptions that you have access to in this tenant are = \n [SubscriptionInfo(subscription_name='Azure Big data', subscription_id='245d9749-ca17-42f2-ae5e-2aefd9de113b')]. \n Please refer to aka.ms/aml-notebook-auth for different authentication mechanisms in azureml-sdk."
#     }
# }

# %% [markdown]
# # 2. 모델 등록

# %% [markdown]
# #### 등록할 모델의 버전을 명시해준다.

# %%
model_version = "03_051_01"
file_name = '{}.pickle'.format(model_version)
print(file_name)
# Out:
# 03_051_01.pickle

# %% [markdown]
# ## Description 수정해아함!!!

# %% [markdown]
# #### 모델을 등록해준다. description에 현재 모델에 대한 간단한 설명을 추가할 수 있다.

# %% [markdown]
#  - 실행하면, [Azure Portal > 기계 학습 > 기계학습이름(위에서 확인) > 모델] 에서 확인 가능함

# %%
from azureml.core.model import Model

#library_version = "DL"+sklearn.__version__.replace(".","x")
model = Model.register(model_path = "data/pkl/{}".format(file_name),
                       model_name = model_version,
                       tags = {'area': "IoT Edge", 'type': "azureml-automl"},
                       description = "ML=03_051_01, Sys=04.01.00",
                       workspace = ws)
# Out:
# Registering model 03_051_01

# %% [markdown]
# # 3. 이미지 등록

# %% [markdown]
# #### 등록 된 모델 이름을 사용 하 여 모델 파일에 대 한 경로를 반환

# %%
from azureml.core.model import Model
model = Model.get_model_path(model_version, _workspace=ws)
model
# Out:
# 'azureml-models\\03_051_01\\13\\03_051_01.pickle'

# %% [markdown]
# #### 사용되는 package 선언. Edge 환경에서 해당 package를 사용되기 때문에 channel 과 필요한 package명을 선언 해주어야 한다.

# %%
pip_packages = ["azureml-defaults",
                "azureml==0.2.7",
                "azureml-core==1.24.0",
                "azureml-sdk==1.24.0",
                "azureml-automl-core==1.24.0",
                "azureml-automl-runtime==1.24.0",
                "azure-storage-blob==12.6.0",
                "numpy==1.18.5",
                "pandas==0.25.3",
                "sqlalchemy==1.3.21",
                "h5py==2.10.0",
                "tqdm==4.54.0",
                "obspy==1.2.2",
                "mysql-connector-python==8.0.18",
                "joblib==0.14.1",
                "packaging==20.7",
                "xgboost==0.90",
                "noisereduce==1.1.0"]

lib_config_load = ['pyyaml']
lib_clfs = ["gxx_linux-64",
            "gcc_linux-64",
            "librosa==0.8.0"]
#lib_clfs = ['tensorflow==1.1']
conda_packages = lib_clfs + lib_config_load

print('pip packages:', pip_packages)
print('conda packasges:', conda_packages)
# Out:
# pip packages: ['azureml-defaults', 'azureml==0.2.7', 'azureml-core==1.24.0', 'azureml-sdk==1.24.0', 'azureml-automl-core==1.24.0', 'azureml-automl-runtime==1.24.0', 'azure-storage-blob==12.6.0', 'numpy==1.18.5', 'pandas==0.25.3', 'sqlalchemy==1.3.21', 'h5py==2.10.0', 'tqdm==4.54.0', 'obspy==1.2.2', 'mysql-connector-python==8.0.18', 'joblib==0.14.1', 'packaging==20.7', 'xgboost==0.90', 'noisereduce==1.1.0']
# conda packasges: ['gxx_linux-64', 'gcc_linux-64', 'librosa==0.8.0', 'pyyaml']

# %%
from azureml.core.conda_dependencies import CondaDependencies 
from azureml.core import Environment

conda_deps  = CondaDependencies.create(conda_packages=conda_packages, pip_packages=pip_packages)
conda_deps.add_channel('conda-forge')
conda_deps.add_channel('defaults')

myenv = Environment(name='myenv')
myenv.python.conda_dependencies = conda_deps
myenv.docker.base_image = 'mcr.microsoft.com/azureml/base:intelmpi2018.3-ubuntu16.04'
# myenv.docker.base_image = 'mcr.microsoft.com/azureml/base:openmpi3.1.2-ubuntu18.04'


# with open("data/myenv.yml","w") as f:
#     f.write(myenv.serialize_to_string())

# %% [markdown]
# # 4. score_iot.py 파일(전처리 및 ML 판정 수행 로직 실행 스크립트) 생성

# %% [markdown]
#  ### 아래 cell 이 실행되면 score_iot.py에 실행 스크립트가 생성됨

# %% [markdown]
# ### score_iot_test.ipynb에 해당 스크립트의 내용을 복사하여, 실행 시 에러가 발생하지 않는지 꼭 확인!

# %%
import _locale
_locale._getdefaultlocale = (lambda *args: ['en_US', 'utf8'])

# %%
# %%writefile ../src/score_iot.py

# For Edge
import json
import yaml
import time
import os
import re
import pickle
import shutil
from datetime import datetime
from datetime import timedelta
from time import sleep
from azureml.core.model import Model

# For Clf
import h5py
import pandas as pd
from classify import Classifier
from preprocess_signal_data import Run_
from pkgs.pipelines import FeatureDeployed as Featurizing
from pkgs.utils import read_json

def read_data(input_path, attempt):
    print("Attempt: " + str(attempt + 1) + "  Time: " + str(datetime.now()))
    with h5py.File(input_path, "r") as f:
        tmp = f["Raw"][:]
    input_raw = pd.DataFrame(tmp, columns=[0, 1, 2])
    print("\n", "hdf loaded")
    
    return input_raw
# --------------------------------------------------------------------

def init_preprocessor(feature_params, Featurizing, test_no, input_type="ReadData"):
    # set preprocess class
    preproc = Run_(
        feature_params=feature_params, Featurizing=Featurizing, test_no=test_no
    )
    if input_type == "ReadData":
        preproc.pl.steps = [
            (step_name, step)
            for step_name, step in preproc.pl.steps
            if step.name != "ReadData"
        ]

    return preproc


def score(
    preproc,
    input_values,
    feature_names,
    column_names,
    cut_off,
    rule_model_params,
    mode,
    input_name="ReadData",
    parallel=1,
    verbose=0,
):
    # Preprocess
    df = preproc.pl.run(
        input_name=input_name,
        input_values=[input_values],
        feature_names=feature_names,
        parallel=parallel,
        verbose=verbose,
    )
    df = pd.DataFrame(df[0])
    df["TEST_NO"] = [0,1,2]
    df_features = df[column_names]

    # Predict
    df["PROB"] = loaded_model.predict_proba(df_features)[:,1]
    
    # Classify
    df["ML_R"] = df.PROB >= cut_off
    df["ML_R"] = df.ML_R.astype(int)
    
    df_classified = Classifier.classify_all(
        df=df[df.TEST_NO.isin(preproc.featurizer.params["test_no"])],
        rule_cutoffs=rule_model_params,
        mode=mode,
    )
    return df_classified, df


def init():
    global preproc, loaded_model, model_version, column_names, line, cut_off, rule_model_params, ml_model_params, model_path, error_dir
    # 수정필요  --------------------------------------------------------
    model_version = "03_051_01"  # model_name 입력
    file_name = "{}.pickle".format(model_version)
    edge_config = "/home/data/edge_config.yml"
    feature_params = read_json("src/config/feature051_parameters.json")
    column_names = read_json("src/config/model_03_051_01_features.json")["feature_names"]
    # ----------------------------------------------------------------

    # load line info
    with open(edge_config, "r") as stream:
        try:
            edge_config = yaml.load(stream, Loader=yaml.BaseLoader)
            line = edge_config["config"]["line"]["name"]
            cut_off = float(edge_config["config"]["param"]["cutoff"])
            rule_model_params = edge_config["config"]["param"]["rule_model"]
            ml_model_params = edge_config["config"]["param"]["ml_model"]

        except yaml.YAMLError as exc:
            print("line config error: ", exc)

    # set preprocess class
    for param_, dic_ in ml_model_params.items():
        for key_, value_ in dic_.items():
            feature_params[param_][key_] = float(value_)
    preproc = init_preprocessor(
        feature_params=feature_params, Featurizing=Featurizing, test_no=[0, 1, 2]
    )

    # load model
    model_path = Model.get_model_path(file_name)
    with open(model_path, "rb") as f:
        loaded_model = pickle.load(f)
    
    error_dir = "/home/data/error_file/"
    try:
        os.makedirs(error_dir, mode=777)
    except:
        pass


def run(input_json):
    print("\n", "mlmodule start")
    print("\n", datetime.now() + timedelta(hours=9), "\n")
    # for test#
    input_json = json.loads(input_json)
    print("\n", "json loaded", "\n")
    print(input_json, "\n")
    mltime = datetime.now() + timedelta(hours=9)
    chtime = input_json["chtime"]
    print("chtime : ", chtime)
    ct = datetime.strptime(
        chtime.replace("T", " ").split("+")[0][:-1], "%Y-%m-%d %H:%M:%S.%f"
    )
    diff = mltime - ct
    input_json["chtime"] = str(ct)
    input_json["mltime"] = str(mltime)
    input_json["etime_ch"] = diff.seconds + diff.microseconds / 1e6

    # file load
    init_time = time.time()
    # input_json = json.loads(input_json)
    input_path = input_json["path"]
    print("\n", input_path)

    for attempt in range(3):
        try:
            input_raw = read_data(input_path, attempt)

        except Exception as ex:
            if attempt == 2:
                ex_message = str(ex)

            sleep(0.02)
            continue

        break

    else:
        input_json["b"] = 2
        input_json["prob"] = 2
        input_json["error"] = ex_message
        input_json["etime"] = time.time() - init_time

        result_json = [json.dumps(input_json)]
        print("*" * 5, " ", "LOAD ERROR", " ", "*" * 5)
        print(result_json)
        try:
            shutil.copy(input_path, error_dir)
        except:
            pass

    # for test#
    # diff = (datetime.now()+ timedelta(hours=9))-mltime
    # input_json['etime_load'] = diff.seconds + diff.microseconds/1E6
    input_json["etime_load"] = time.time() - init_time

    ### json insert
    input_json["cutoff"] = cut_off
    input_json["FTUR_ENRG_TRHD"] = float(rule_model_params["FTUR_ENRG"])
    input_json["FTUR_WVFM_STDDEV_TRHD"] = float(rule_model_params["FTUR_WVFM_STDDEV"])
    input_json["FTUR_TRGER_TRHD"] = float(rule_model_params["FTUR_TRGER"])
    
    input_json["TRHD_NM_SET"] = "/".join([key for key in rule_model_params.keys()] + [f"{key_}-{param}" for key_, dict_ in ml_model_params.items() for param, value in dict_.items()])
    input_json["TRHD_VAL_SET"] = "/".join(
        [str(value) for value in rule_model_params.values()]+[str(value) for key_, dict_ in ml_model_params.items() for param, value in dict_.items()]
    )
    input_json["FTUR_NM_SET"] = "/".join(
        [
            "/".join([col + "_TEST_N1" for col in preproc.featurizer.params["feature_names"]]),
            "/".join([col + "_TEST_N2" for col in preproc.featurizer.params["feature_names"]]),
            "/".join([col + "_TEST_N3" for col in preproc.featurizer.params["feature_names"]]),
        ]
    )
    input_json["lid"] = line
    
    ##시스템 변수 반드시 수정 필요
    input_json["v"] = "04.01.00"
    ##############################

    try:
        filename = input_path.split("/")[-1]
        filename = filename.strip("Data\\").split("_")
        input_json["bc"] = "_".join(filename[0:2])
        input_json["dtfull"] = filename[2][:-3]

    except Exception as ex:  # 에러 종류
        input_json["bc"] = "ERROR"
        input_json["dtfull"] = str(datetime.now())
        input_json["r"] = 2
        input_json["prob"] = 2
        input_json["error"] = str(ex)
        input_json["etime"] = time.time() - init_time

        result_json = [json.dumps(input_json)]
        print("*" * 5, " ", "FILENAME ERROR", " ", "*" * 5)
        print(result_json)
        try:
            cmd = "cp " + input_json["path"] + " " + error_dir
            os.system(cmd)
        except:
            pass

    try:
        df, df_all = score(
            preproc=preproc,
            input_values=input_raw,
            feature_names=preproc.featurizer.params["feature_names"],
            column_names=column_names,
            cut_off=cut_off,
            rule_model_params=rule_model_params,
            mode="or",
            input_name="ReadData",
            parallel=1,
            verbose=0,
        )
        df_max = df_all.max()
        
        input_json["r"] = int(df.R.values[0])
        input_json["prob"] = float(df.PROB.values[0])
        input_json["error"] = str(df.TEST_NG_R.values[0])
        input_json["etime"] = time.time() - init_time
        input_json["FTUR_VAL_SET"] = "/".join(
            [str(value) for value in df_all[preproc.featurizer.params["feature_names"]].values.flatten()]
        )
        input_json["ML_R"] = int(df.ML_R.values[0])
        input_json["RULE_R"] = int(df.RULE_R.values[0])
        input_json["TEST_NG_R"] = int(df.TEST_NG_R.values[0])
        input_json["FTUR_ENRG"] = float(df_max.FTUR_ENRG)
        input_json["FTUR_WVFM_STDDEV"] = float(df_max.FTUR_WVFM_STDDEV)
        input_json["FTUR_TRGER"] = float(df_max.FTUR_TRGER)

        result_json = [json.dumps(input_json)]
        print(result_json)

    except Exception as ex:  # 에러 종류
        input_json["r"] = 2
        input_json["prob"] = 2
        input_json["error"] = str(ex)
        input_json["etime"] = time.time() - init_time
        input_json["FTUR_VAL_SET"] = ""
        input_json["ML_R"] = 2
        input_json["RULE_R"] = 2
        input_json["TEST_NG_R"] = 2
        input_json["FTUR_ENRG"] = -1
        input_json["FTUR_WVFM_STDDEV"] = -1
        input_json["FTUR_TRGER"] = -1
        

        result_json = [json.dumps(input_json)]
        print("*" * 5, " ", "ERROR", " ", "*" * 5)
        print(result_json)
        try:
            cmd = "cp " + input_json["path"] + " " + error_dir
            os.system(cmd)
        except:
            pass

    return result_json
# Out:
# Overwriting ../src/score_iot.py

# %%
import os
os.getcwd()
# Out:
# 'C:\\Users\\Nam\\Documents\\Jupyter Test\\ML Module Test\\deployment'

# %% [markdown]
# # 5. Azure MLWS에 이미지 업로드

# %%
from azureml.core.model import InferenceConfig

inference_config = InferenceConfig(entry_script="score_iot.py", environment=myenv, source_directory="../src",
                                   description="ML=03_051_01, Sys=04.01.00")
package_service = Model.package(workspace=ws,
                                models=[model],
                                image_name="mc-mlmodule",
                                image_label=21,
                                inference_config=inference_config)
# Out:
# ModelNotFound: Model with id azureml-models\03_051_01\13\03_051_01.pickle not found in provided workspace
# Registering model 03_051_01.pickle

# %%
package_service.wait_for_creation(show_output=True)
# Out:
# 2021/05/06 02:30:10 Downloading source code...
# 2021/05/06 02:30:11 Finished downloading source code
# 2021/05/06 02:30:12 Creating Docker network: acb_default_network, driver: 'bridge'
# 2021/05/06 02:30:12 Successfully set up Docker network: acb_default_network
# 2021/05/06 02:30:12 Setting up Docker configuration...
# 2021/05/06 02:30:13 Successfully set up Docker configuration
# 2021/05/06 02:30:13 Logging in to registry: 328b44081e0a40338b99edcaa606d991.azurecr.io
# 2021/05/06 02:30:14 Successfully logged into 328b44081e0a40338b99edcaa606d991.azurecr.io
# 2021/05/06 02:30:14 Executing step ID: acb_step_0. Timeout(sec): 5400, Working directory: '', Network: 'acb_default_network'
# 2021/05/06 02:30:14 Launching container with name: acb_step_0
# WARNING! Using --password via the CLI is insecure. Use --password-stdin.
# WARNING! Your password will be stored unencrypted in /acb/home/.docker/config.json.
# Configure a credential helper to remove this warning. See
# https://docs.docker.com/engine/reference/commandline/login/#credentials-store
#
# Login Succeeded
# 2021/05/06 02:30:15 Successfully executed container: acb_step_0
# 2021/05/06 02:30:15 Executing step ID: acb_step_1. Timeout(sec): 5400, Working directory: '', Network: 'acb_default_network'
# 2021/05/06 02:30:15 Scanning for dependencies...
# 2021/05/06 02:30:16 Successfully scanned dependencies
# 2021/05/06 02:30:16 Launching container with name: acb_step_1
# Sending build context to Docker daemon  66.05kB
# Step 1/7 : FROM 328b44081e0a40338b99edcaa606d991.azurecr.io/azureml/azureml_a3f23c10bf76c00df7b2e9f000cc80d6
# latest: Pulling from azureml/azureml_a3f23c10bf76c00df7b2e9f000cc80d6
# a1298f4ce990: Pulling fs layer
# 04a3282d9c4b: Pulling fs layer
# 9b0d3db6dc03: Pulling fs layer
# 8269c605f3f1: Pulling fs layer
# 6504d449e70c: Pulling fs layer
# 4e38f320d0d4: Pulling fs layer
# b0a763e8ee03: Pulling fs layer
# 11917a028ca4: Pulling fs layer
# a6c378d11cbf: Pulling fs layer
# 6cc007ad9140: Pulling fs layer
# 6c1698a608f3: Pulling fs layer
# 2ab68f2e8244: Pulling fs layer
# d4b4a2ff1c81: Pulling fs layer
# 9ace610c318a: Pulling fs layer
# f8be25f80cbd: Pulling fs layer
# 29eb5f607f7a: Pulling fs layer
# 8ebef938b19d: Pulling fs layer
# 31dafb14d637: Pulling fs layer
# 73599a49f7af: Pulling fs layer
# d0e308c207f4: Pulling fs layer
# b0a763e8ee03: Waiting
# 11917a028ca4: Waiting
# a6c378d11cbf: Waiting
# 6cc007ad9140: Waiting
# 6c1698a608f3: Waiting
# 2ab68f2e8244: Waiting
# d4b4a2ff1c81: Waiting
# 9ace610c318a: Waiting
# f8be25f80cbd: Waiting
# 29eb5f607f7a: Waiting
# 8ebef938b19d: Waiting
# 31dafb14d637: Waiting
# 73599a49f7af: Waiting
# d0e308c207f4: Waiting
# 8269c605f3f1: Waiting
# 6504d449e70c: Waiting
# 4e38f320d0d4: Waiting
# 9b0d3db6dc03: Verifying Checksum
# 9b0d3db6dc03: Download complete
# 04a3282d9c4b: Verifying Checksum
# 04a3282d9c4b: Download complete
# 8269c605f3f1: Verifying Checksum
# 8269c605f3f1: Download complete
# a1298f4ce990: Verifying Checksum
# a1298f4ce990: Download complete
# 4e38f320d0d4: Verifying Checksum
# 4e38f320d0d4: Download complete
# 6504d449e70c: Verifying Checksum
# 6504d449e70c: Download complete
# b0a763e8ee03: Verifying Checksum
# b0a763e8ee03: Download complete
# 6cc007ad9140: Verifying Checksum
# 6cc007ad9140: Download complete
# 6c1698a608f3: Verifying Checksum
# 6c1698a608f3: Download complete
# 11917a028ca4: Verifying Checksum
# 11917a028ca4: Download complete
# 2ab68f2e8244: Verifying Checksum
# 2ab68f2e8244: Download complete
# d4b4a2ff1c81: Verifying Checksum
# d4b4a2ff1c81: Download complete
# 9ace610c318a: Verifying Checksum
# 9ace610c318a: Download complete
# f8be25f80cbd: Verifying Checksum
# f8be25f80cbd: Download complete
# a6c378d11cbf: Verifying Checksum
# a6c378d11cbf: Download complete
# a1298f4ce990: Pull complete
# 04a3282d9c4b: Pull complete
# 9b0d3db6dc03: Pull complete
# 8269c605f3f1: Pull complete
# 31dafb14d637: Verifying Checksum
# 31dafb14d637: Download complete
# 8ebef938b19d: Verifying Checksum
# 8ebef938b19d: Download complete
# d0e308c207f4: Verifying Checksum
# d0e308c207f4: Download complete
# 73599a49f7af: Verifying Checksum
# 73599a49f7af: Download complete
# 6504d449e70c: Pull complete
# 4e38f320d0d4: Pull complete
# b0a763e8ee03: Pull complete
# 29eb5f607f7a: Verifying Checksum
# 29eb5f607f7a: Download complete
# 11917a028ca4: Pull complete
# a6c378d11cbf: Pull complete
# 6cc007ad9140: Pull complete
# 6c1698a608f3: Pull complete
# 2ab68f2e8244: Pull complete
# d4b4a2ff1c81: Pull complete
# 9ace610c318a: Pull complete
# f8be25f80cbd: Pull complete
#
# 29eb5f607f7a: Pull complete
# 8ebef938b19d: Pull complete
# 31dafb14d637: Pull complete
# 73599a49f7af: Pull complete
# d0e308c207f4: Pull complete
# Digest: sha256:7af086e3e4144ec63173c3b1fa665c51cdd9beb52c86f983c5e6613bc452f5bb
# Status: Downloaded newer image for 328b44081e0a40338b99edcaa606d991.azurecr.io/azureml/azureml_a3f23c10bf76c00df7b2e9f000cc80d6:latest
#  ---> 9512676835f8
# Step 2/7 : ENV AZUREML_MODEL_DIR=azureml-models/03_051_01.pickle/9
#  ---> Running in d850c7e4da7f
# Removing intermediate container d850c7e4da7f
#  ---> 5d2ee0d207ac
# Step 3/7 : RUN mkdir -p '/var/azureml-app' && /var/azureml-util/download_asset.sh 'https://mltest213552016753.blob.core.windows.net/azureml/LocalUpload/32e75496/tmpkqw40amu.py?sv=2019-02-02&sr=b&sig=ObiDrq9fH%2BR%2BenLX8k0i2qZC7rQVpLWvzpuN8KaWy%2Fg%3D&st=2021-05-06T02%3A20%3A06Z&se=2021-05-06T10%3A30%3A06Z&sp=r' '/var/azureml-app/tmpkqw40amu.py' && /var/azureml-util/download_asset.sh 'https://mltest213552016753.blob.core.windows.net/azureml/LocalUpload/75aa3bcd/63a4bffb.tar.gz?sv=2019-02-02&sr=b&sig=yhbYv9EZtezouh5Q%2Fap6UpzHpjpPLBe2TA0uMhMVtKI%3D&st=2021-05-06T02%3A20%3A06Z&se=2021-05-06T10%3A30%3A06Z&sp=r' /tmp/temp.tar.gz && tar xzf /tmp/temp.tar.gz -C '/var/azureml-app' && rm -f /tmp/temp.tar.gz
#  ---> Running in 5f4a68b891a6
# Downloading https://mltest213552016753.blob.core.windows.net/azureml/LocalUpload/32e75496/tmpkqw40amu.py?sv=2019-02-02&sr=b&sig=ObiDrq9fH%2BR%2BenLX8k0i2qZC7rQVpLWvzpuN8KaWy%2Fg%3D&st=2021-05-06T02%3A20%3A06Z&se=2021-05-06T10%3A30%3A06Z&sp=r as /var/azureml-app/tmpkqw40amu.py
# wget: /azureml-envs/azureml_882aeb18bd4696f212b5c79bda0dd217/lib/libcrypto.so.1.0.0: no version information available (required by wget)
# wget: /azureml-envs/azureml_882aeb18bd4696f212b5c79bda0dd217/lib/libssl.so.1.0.0: no version information available (required by wget)
# wget: /azureml-envs/azureml_882aeb18bd4696f212b5c79bda0dd217/lib/libssl.so.1.0.0: no version information available (required by wget)
# --2021-05-06 02:32:04--  https://mltest213552016753.blob.core.windows.net/azureml/LocalUpload/32e75496/tmpkqw40amu.py?sv=2019-02-02&sr=b&sig=ObiDrq9fH%2BR%2BenLX8k0i2qZC7rQVpLWvzpuN8KaWy%2Fg%3D&st=2021-05-06T02%3A20%3A06Z&se=2021-05-06T10%3A30%3A06Z&sp=r
# Resolving mltest213552016753.blob.core.windows.net (mltest213552016753.blob.core.windows.net)... 20.150.4.36
# Connecting to mltest213552016753.blob.core.windows.net (mltest213552016753.blob.core.windows.net)|20.150.4.36|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 1187 (1.2K) [application/octet-stream]
# Saving to: ‘/var/azureml-app/tmpkqw40amu.py’
#
#      0K                                    100%  126M=0s
#
# 2021-05-06 02:32:04 (126 MB/s) - ‘/var/azureml-app/tmpkqw40amu.py’ saved [1187/1187]
#
# Downloading https://mltest213552016753.blob.core.windows.net/azureml/LocalUpload/75aa3bcd/63a4bffb.tar.gz?sv=2019-02-02&sr=b&sig=yhbYv9EZtezouh5Q%2Fap6UpzHpjpPLBe2TA0uMhMVtKI%3D&st=2021-05-06T02%3A20%3A06Z&se=2021-05-06T10%3A30%3A06Z&sp=r as /tmp/temp.tar.gz
# wget: /azureml-envs/azureml_882aeb18bd4696f212b5c79bda0dd217/lib/libcrypto.so.1.0.0: no version information available (required by wget)
# wget: /azureml-envs/azureml_882aeb18bd4696f212b5c79bda0dd217/lib/libssl.so.1.0.0: no version information available (required by wget)
# wget: /azureml-envs/azureml_882aeb18bd4696f212b5c79bda0dd217/lib/libssl.so.1.0.0: no version information available (required by wget)
# --2021-05-06 02:32:04--  https://mltest213552016753.blob.core.windows.net/azureml/LocalUpload/75aa3bcd/63a4bffb.tar.gz?sv=2019-02-02&sr=b&sig=yhbYv9EZtezouh5Q%2Fap6UpzHpjpPLBe2TA0uMhMVtKI%3D&st=2021-05-06T02%3A20%3A06Z&se=2021-05-06T10%3A30%3A06Z&sp=r
# Resolving mltest213552016753.blob.core.windows.net (mltest213552016753.blob.core.windows.net)... 20.150.4.36
# Connecting to mltest213552016753.blob.core.windows.net (mltest213552016753.blob.core.windows.net)|20.150.4.36|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 32743 (32K) [application/octet-stream]
# Saving to: ‘/tmp/temp.tar.gz’
#
#      0K                                    100% 35.5M=0.001s
#
# 2021-05-06 02:32:04 (35.5 MB/s) - ‘/tmp/temp.tar.gz’ saved [32743/32743]
#
# Removing intermediate container 5f4a68b891a6
#  ---> 6f7bb8d2451a
# Step 4/7 : RUN mkdir -p '/var/azureml-app/azureml-models/03_051_01.pickle/9' && /var/azureml-util/download_asset.sh 'https://mltest213552016753.blob.core.windows.net/azureml/LocalUpload/210506T112953-f09490ba/03_051_01.pickle?sv=2019-02-02&sr=b&sig=lSF2g4JThGRvoSnIk5W1hWMNwiN31ScFNWduBuxAy1A%3D&st=2021-05-06T02%3A20%3A05Z&se=2021-05-06T10%3A30%3A05Z&sp=r' '/var/azureml-app/azureml-models/03_051_01.pickle/9/03_051_01.pickle'
#  ---> Running in 08faaf3a0cc5
# Downloading https://mltest213552016753.blob.core.windows.net/azureml/LocalUpload/210506T112953-f09490ba/03_051_01.pickle?sv=2019-02-02&sr=b&sig=lSF2g4JThGRvoSnIk5W1hWMNwiN31ScFNWduBuxAy1A%3D&st=2021-05-06T02%3A20%3A05Z&se=2021-05-06T10%3A30%3A05Z&sp=r as /var/azureml-app/azureml-models/03_051_01.pickle/9/03_051_01.pickle
# wget: /azureml-envs/azureml_882aeb18bd4696f212b5c79bda0dd217/lib/libcrypto.so.1.0.0: no version information available (required by wget)
# wget: /azureml-envs/azureml_882aeb18bd4696f212b5c79bda0dd217/lib/libssl.so.1.0.0: no version information available (required by wget)
# wget: /azureml-envs/azureml_882aeb18bd4696f212b5c79bda0dd217/lib/libssl.so.1.0.0: no version information available (required by wget)
# --2021-05-06 02:32:08--  https://mltest213552016753.blob.core.windows.net/azureml/LocalUpload/210506T112953-f09490ba/03_051_01.pickle?sv=2019-02-02&sr=b&sig=lSF2g4JThGRvoSnIk5W1hWMNwiN31ScFNWduBuxAy1A%3D&st=2021-05-06T02%3A20%3A05Z&se=2021-05-06T10%3A30%3A05Z&sp=r
# Resolving mltest213552016753.blob.core.windows.net (mltest213552016753.blob.core.windows.net)... 20.150.4.36
# Connecting to mltest213552016753.blob.core.windows.net (mltest213552016753.blob.core.windows.net)|20.150.4.36|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 3043766 (2.9M) [application/octet-stream]
# Saving to: ‘/var/azureml-app/azureml-models/03_051_01.pickle/9/03_051_01.pickle’
#
#      0K ..                                 100% 81.6M=0.04s
#
# 2021-05-06 02:32:09 (81.6 MB/s) - ‘/var/azureml-app/azureml-models/03_051_01.pickle/9/03_051_01.pickle’ saved [3043766/3043766]
#
# Removing intermediate container 08faaf3a0cc5
#  ---> e129f7e38590
# Step 5/7 : RUN mkdir -p '/var/azureml-app' && echo ... | base64 --decode > /var/azureml-app/model_config_map.json
#  ---> Running in b39820ba48de
# Removing intermediate container b39820ba48de
#  ---> d6d8aed42dc6
# Step 6/7 : RUN mv '/var/azureml-app/tmpkqw40amu.py' /var/azureml-app/main.py
#  ---> Running in a3672897e0e5
# Removing intermediate container a3672897e0e5
#  ---> 7dd61d6cae71
# Step 7/7 : CMD ["runsvdir","/var/runit"]
#  ---> Running in c3c61e82cf93
# Removing intermediate container c3c61e82cf93
#  ---> 15adb10cc1f4
# Successfully built 15adb10cc1f4
# Successfully tagged 328b44081e0a40338b99edcaa606d991.azurecr.io/azureml/azureml_afe4946e613e4f9e0425c9b14e467d84:latest
# Successfully tagged 328b44081e0a40338b99edcaa606d991.azurecr.io/azureml/azureml_afe4946e613e4f9e0425c9b14e467d84:1
# Successfully tagged 328b44081e0a40338b99edcaa606d991.azurecr.io/mc-mlmodule:21
# 2021/05/06 02:32:27 Successfully executed container: acb_step_1
# 2021/05/06 02:32:27 Executing step ID: acb_step_2. Timeout(sec): 5400, Working directory: '', Network: 'acb_default_network'
# 2021/05/06 02:32:27 Pushing image: 328b44081e0a40338b99edcaa606d991.azurecr.io/azureml/azureml_afe4946e613e4f9e0425c9b14e467d84:1, attempt 1
# The push refers to repository [328b44081e0a40338b99edcaa606d991.azurecr.io/azureml/azureml_afe4946e613e4f9e0425c9b14e467d84]
# 54444f1f8063: Preparing
# f3db2b2fa3fc: Preparing
# b2f357399fff: Preparing
# 3ea46864f09b: Preparing
# 68dab05570c2: Preparing
# 3e0de079deab: Preparing
# 008268763c99: Preparing
# c75ab6854fe0: Preparing
# 149d2b5eaf6e: Preparing
# c3407f8f3693: Preparing
# cd1d75aae864: Preparing
# a5c706e98b4d: Preparing
# 2ef846464619: Preparing
# e1171d4d60ca: Preparing
# 6ef1a8ae63b7: Preparing
# 85389f9ead9e: Preparing
# f2608f66a0e3: Preparing
# 0e259b09e5f4: Preparing
# 340dc32eb998: Preparing
# df18b66efaa6: Preparing
# ccdb13a20bf2: Preparing
# 9513cdf4e497: Preparing
# 7f083f9454c0: Preparing
# 29f36b5893dc: Preparing
# 3e0de079deab: Waiting
# 6ef1a8ae63b7: Waiting
# 85389f9ead9e: Waiting
# 008268763c99: Waiting
# c75ab6854fe0: Waiting
# 149d2b5eaf6e: Waiting
# c3407f8f3693: Waiting
# cd1d75aae864: Waiting
# a5c706e98b4d: Waiting
# 2ef846464619: Waiting
# e1171d4d60ca: Waiting
# 0e259b09e5f4: Waiting
# f2608f66a0e3: Waiting
# 340dc32eb998: Waiting
# df18b66efaa6: Waiting
# 9513cdf4e497: Waiting
# 7f083f9454c0: Waiting
# 29f36b5893dc: Waiting
# ccdb13a20bf2: Waiting
# 68dab05570c2: Mounted from azureml/azureml_a3f23c10bf76c00df7b2e9f000cc80d6
# 54444f1f8063: Pushed
# f3db2b2fa3fc: Pushed
# 3ea46864f09b: Pushed
# 3e0de079deab: Mounted from azureml/azureml_a3f23c10bf76c00df7b2e9f000cc80d6
# c75ab6854fe0: Mounted from azureml/azureml_a3f23c10bf76c00df7b2e9f000cc80d6
# 008268763c99: Mounted from azureml/azureml_a3f23c10bf76c00df7b2e9f000cc80d6
# 149d2b5eaf6e: Mounted from azureml/azureml_a3f23c10bf76c00df7b2e9f000cc80d6
# b2f357399fff: Pushed
# c3407f8f3693: Mounted from azureml/azureml_a3f23c10bf76c00df7b2e9f000cc80d6
# cd1d75aae864: Mounted from azureml/azureml_a3f23c10bf76c00df7b2e9f000cc80d6
# a5c706e98b4d: Mounted from azureml/azureml_a3f23c10bf76c00df7b2e9f000cc80d6
# 2ef846464619: Mounted from azureml/azureml_a3f23c10bf76c00df7b2e9f000cc80d6
# e1171d4d60ca: Mounted from azureml/azureml_a3f23c10bf76c00df7b2e9f000cc80d6
# 6ef1a8ae63b7: Mounted from azureml/azureml_a3f23c10bf76c00df7b2e9f000cc80d6
# 85389f9ead9e: Mounted from azureml/azureml_a3f23c10bf76c00df7b2e9f000cc80d6
# 0e259b09e5f4: Mounted from azureml/azureml_a3f23c10bf76c00df7b2e9f000cc80d6
# f2608f66a0e3: Mounted from azureml/azureml_a3f23c10bf76c00df7b2e9f000cc80d6
# 340dc32eb998: Mounted from azureml/azureml_a3f23c10bf76c00df7b2e9f000cc80d6
# df18b66efaa6: Mounted from azureml/azureml_a3f23c10bf76c00df7b2e9f000cc80d6
# ccdb13a20bf2: Mounted from azureml/azureml_a3f23c10bf76c00df7b2e9f000cc80d6
# 9513cdf4e497: Mounted from azureml/azureml_a3f23c10bf76c00df7b2e9f000cc80d6
# 7f083f9454c0: Mounted from azureml/azureml_a3f23c10bf76c00df7b2e9f000cc80d6
# 29f36b5893dc: Mounted from azureml/azureml_a3f23c10bf76c00df7b2e9f000cc80d6
# 1: digest: sha256:4fcec070ef4de63bf77d4056efc8b0cf496ce10e966892a0e846ae3d6692c1f0 size: 5344
# 2021/05/06 02:32:41 Successfully pushed image: 328b44081e0a40338b99edcaa606d991.azurecr.io/azureml/azureml_afe4946e613e4f9e0425c9b14e467d84:1
# 2021/05/06 02:32:41 Executing step ID: acb_step_3. Timeout(sec): 5400, Working directory: '', Network: 'acb_default_network'
# 2021/05/06 02:32:41 Pushing image: 328b44081e0a40338b99edcaa606d991.azurecr.io/mc-mlmodule:21, attempt 1
# The push refers to repository [328b44081e0a40338b99edcaa606d991.azurecr.io/mc-mlmodule]
# 54444f1f8063: Preparing
# f3db2b2fa3fc: Preparing
# b2f357399fff: Preparing
# 3ea46864f09b: Preparing
# 68dab05570c2: Preparing
# 3e0de079deab: Preparing
# 008268763c99: Preparing
# c75ab6854fe0: Preparing
# 149d2b5eaf6e: Preparing
# c3407f8f3693: Preparing
# cd1d75aae864: Preparing
# a5c706e98b4d: Preparing
# 2ef846464619: Preparing
# e1171d4d60ca: Preparing
# 6ef1a8ae63b7: Preparing
# 85389f9ead9e: Preparing
# f2608f66a0e3: Preparing
# 0e259b09e5f4: Preparing
# 340dc32eb998: Preparing
# df18b66efaa6: Preparing
# ccdb13a20bf2: Preparing
# 9513cdf4e497: Preparing
# 7f083f9454c0: Preparing
# 29f36b5893dc: Preparing
# 3e0de079deab: Waiting
# 008268763c99: Waiting
# c75ab6854fe0: Waiting
# 149d2b5eaf6e: Waiting
# c3407f8f3693: Waiting
# cd1d75aae864: Waiting
# a5c706e98b4d: Waiting
# 2ef846464619: Waiting
# e1171d4d60ca: Waiting
# 6ef1a8ae63b7: Waiting
# 85389f9ead9e: Waiting
# f2608f66a0e3: Waiting
# 0e259b09e5f4: Waiting
# 340dc32eb998: Waiting
# df18b66efaa6: Waiting
# ccdb13a20bf2: Waiting
# 9513cdf4e497: Waiting
# 7f083f9454c0: Waiting
# 29f36b5893dc: Waiting
# 68dab05570c2: Mounted from azureml/azureml_afe4946e613e4f9e0425c9b14e467d84
# f3db2b2fa3fc: Mounted from azureml/azureml_afe4946e613e4f9e0425c9b14e467d84
# b2f357399fff: Mounted from azureml/azureml_afe4946e613e4f9e0425c9b14e467d84
# 3ea46864f09b: Mounted from azureml/azureml_afe4946e613e4f9e0425c9b14e467d84
# 54444f1f8063: Mounted from azureml/azureml_afe4946e613e4f9e0425c9b14e467d84
# 3e0de079deab: Mounted from azureml/azureml_afe4946e613e4f9e0425c9b14e467d84
# 008268763c99: Mounted from azureml/azureml_afe4946e613e4f9e0425c9b14e467d84
# c75ab6854fe0: Mounted from azureml/azureml_afe4946e613e4f9e0425c9b14e467d84
# 149d2b5eaf6e: Mounted from azureml/azureml_afe4946e613e4f9e0425c9b14e467d84
# c3407f8f3693: Mounted from azureml/azureml_afe4946e613e4f9e0425c9b14e467d84
# cd1d75aae864: Mounted from azureml/azureml_afe4946e613e4f9e0425c9b14e467d84
# 2ef846464619: Mounted from azureml/azureml_afe4946e613e4f9e0425c9b14e467d84
# 85389f9ead9e: Layer already exists
# a5c706e98b4d: Mounted from azureml/azureml_afe4946e613e4f9e0425c9b14e467d84
# 6ef1a8ae63b7: Layer already exists
# e1171d4d60ca: Layer already exists
# 0e259b09e5f4: Layer already exists
# df18b66efaa6: Layer already exists
# 9513cdf4e497: Layer already exists
# 29f36b5893dc: Layer already exists
# ccdb13a20bf2: Layer already exists
# 340dc32eb998: Layer already exists
# f2608f66a0e3: Layer already exists
# 7f083f9454c0: Layer already exists
# 21: digest: sha256:4fcec070ef4de63bf77d4056efc8b0cf496ce10e966892a0e846ae3d6692c1f0 size: 5344
# 2021/05/06 02:32:43 Successfully pushed image: 328b44081e0a40338b99edcaa606d991.azurecr.io/mc-mlmodule:21
# 2021/05/06 02:32:43 Executing step ID: acb_step_4. Timeout(sec): 5400, Working directory: '', Network: 'acb_default_network'
# 2021/05/06 02:32:43 Pushing image: 328b44081e0a40338b99edcaa606d991.azurecr.io/azureml/azureml_afe4946e613e4f9e0425c9b14e467d84:latest, attempt 1
# The push refers to repository [328b44081e0a40338b99edcaa606d991.azurecr.io/azureml/azureml_afe4946e613e4f9e0425c9b14e467d84]
# 54444f1f8063: Preparing
# f3db2b2fa3fc: Preparing
# b2f357399fff: Preparing
# 3ea46864f09b: Preparing
# 68dab05570c2: Preparing
# 3e0de079deab: Preparing
# 008268763c99: Preparing
# c75ab6854fe0: Preparing
# 149d2b5eaf6e: Preparing
# c3407f8f3693: Preparing
# cd1d75aae864: Preparing
# a5c706e98b4d: Preparing
# 2ef846464619: Preparing
# e1171d4d60ca: Preparing
# 6ef1a8ae63b7: Preparing
# 85389f9ead9e: Preparing
# f2608f66a0e3: Preparing
# 0e259b09e5f4: Preparing
# 340dc32eb998: Preparing
# df18b66efaa6: Preparing
# ccdb13a20bf2: Preparing
# 9513cdf4e497: Preparing
# 7f083f9454c0: Preparing
# 29f36b5893dc: Preparing
# 3e0de079deab: Waiting
# 008268763c99: Waiting
# c75ab6854fe0: Waiting
# 149d2b5eaf6e: Waiting
# c3407f8f3693: Waiting
# 6ef1a8ae63b7: Waiting
# cd1d75aae864: Waiting
# 85389f9ead9e: Waiting
# a5c706e98b4d: Waiting
# 2ef846464619: Waiting
# f2608f66a0e3: Waiting
# e1171d4d60ca: Waiting
# 0e259b09e5f4: Waiting
# 9513cdf4e497: Waiting
# 7f083f9454c0: Waiting
# 29f36b5893dc: Waiting
# 340dc32eb998: Waiting
# df18b66efaa6: Waiting
# ccdb13a20bf2: Waiting
# 68dab05570c2: Layer already exists
# 54444f1f8063: Layer already exists
# f3db2b2fa3fc: Layer already exists
# b2f357399fff: Layer already exists
# 3ea46864f09b: Layer already exists
# 3e0de079deab: Layer already exists
# 008268763c99: Layer already exists
# 149d2b5eaf6e: Layer already exists
# c75ab6854fe0: Layer already exists
# c3407f8f3693: Layer already exists
# cd1d75aae864: Layer already exists
# 2ef846464619: Layer already exists
# e1171d4d60ca: Layer already exists
# a5c706e98b4d: Layer already exists
# 85389f9ead9e: Layer already exists
# 6ef1a8ae63b7: Layer already exists
# f2608f66a0e3: Layer already exists
# 340dc32eb998: Layer already exists
# 0e259b09e5f4: Layer already exists
# 7f083f9454c0: Layer already exists
# 29f36b5893dc: Layer already exists
# df18b66efaa6: Layer already exists
# 9513cdf4e497: Layer already exists
# ccdb13a20bf2: Layer already exists
# latest: digest: sha256:4fcec070ef4de63bf77d4056efc8b0cf496ce10e966892a0e846ae3d6692c1f0 size: 5344
# 2021/05/06 02:32:45 Successfully pushed image: 328b44081e0a40338b99edcaa606d991.azurecr.io/azureml/azureml_afe4946e613e4f9e0425c9b14e467d84:latest
# 2021/05/06 02:32:45 Step ID: acb_step_0 marked as successful (elapsed time in seconds: 1.217392)
# 2021/05/06 02:32:45 Step ID: acb_step_1 marked as successful (elapsed time in seconds: 131.364034)
# 2021/05/06 02:32:45 Populating digests for step ID: acb_step_1...
# 2021/05/06 02:32:51 Successfully populated digests for step ID: acb_step_1
# 2021/05/06 02:32:51 Step ID: acb_step_2 marked as successful (elapsed time in seconds: 14.357756)
# 2021/05/06 02:32:51 Step ID: acb_step_3 marked as successful (elapsed time in seconds: 2.167602)
# 2021/05/06 02:32:51 Step ID: acb_step_4 marked as successful (elapsed time in seconds: 2.382920)
# 2021/05/06 02:32:51 The following dependencies were found:
# 2021/05/06 02:32:51
# - image:
#     registry: 328b44081e0a40338b99edcaa606d991.azurecr.io
#     repository: azureml/azureml_afe4946e613e4f9e0425c9b14e467d84
#     tag: latest
#     digest: sha256:4fcec070ef4de63bf77d4056efc8b0cf496ce10e966892a0e846ae3d6692c1f0
#   runtime-dependency:
#     registry: 328b44081e0a40338b99edcaa606d991.azurecr.io
#     repository: azureml/azureml_a3f23c10bf76c00df7b2e9f000cc80d6
#     tag: latest
#     digest: sha256:7af086e3e4144ec63173c3b1fa665c51cdd9beb52c86f983c5e6613bc452f5bb
#   git: {}
# - image:
#     registry: 328b44081e0a40338b99edcaa606d991.azurecr.io
#     repository: azureml/azureml_afe4946e613e4f9e0425c9b14e467d84
#     tag: "1"
#     digest: sha256:4fcec070ef4de63bf77d4056efc8b0cf496ce10e966892a0e846ae3d6692c1f0
#   runtime-dependency:
#     registry: 328b44081e0a40338b99edcaa606d991.azurecr.io
#     repository: azureml/azureml_a3f23c10bf76c00df7b2e9f000cc80d6
#     tag: latest
#     digest: sha256:7af086e3e4144ec63173c3b1fa665c51cdd9beb52c86f983c5e6613bc452f5bb
#   git: {}
# - image:
#     registry: 328b44081e0a40338b99edcaa606d991.azurecr.io
#     repository: mc-mlmodule
#     tag: "21"
#     digest: sha256:4fcec070ef4de63bf77d4056efc8b0cf496ce10e966892a0e846ae3d6692c1f0
#   runtime-dependency:
#     registry: 328b44081e0a40338b99edcaa606d991.azurecr.io
#     repository: azureml/azureml_a3f23c10bf76c00df7b2e9f000cc80d6
#     tag: latest
#     digest: sha256:7af086e3e4144ec63173c3b1fa665c51cdd9beb52c86f983c5e6613bc452f5bb
#   git: {}
#
# Run ID: de2r was successful after 2m42s
# Package creation Succeeded

# %%
print(package_service.state)
# Out:
# Succeeded

# %%
print(package_service.location)
# Out:
# lsmcdevmlwsfe4aa203.azurecr.io/nam-mlmodule@sha256:fc0690da29336cd85abbef4a4e962f9af7e3cc08c0553c65d509362df0f96d23
